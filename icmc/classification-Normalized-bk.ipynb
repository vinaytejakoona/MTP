# %%
import _pickle as pkl
import pandas as pd
import numpy as np
# pkl.dump(dev_L_S,open("dev_L_S.p","wb"))
# pkl.dump(train_L_S,open("train_L_S.p","wb"))
#pkl.dump(test_L_S,open("test_L_S.p","wb"))

# val_L_S = pkl.load( open( "val_L_S.p", "rb" ) )
# train_L_S = pkl.load( open( "train_L_S.p", "rb" ) )
# test_L_S = pkl.load( open( "test_L_S.p", "rb" ) )

# train_L_S = pkl.load( open( "train_L_S_Embeddings.p", "rb" ) )
# test_L_S = pkl.load( open( "test_L_S_Embeddings.p", "rb" )) 

# train_L_S = pkl.load( open( "train_L_S_TFIDF.p", "rb" ) )
# test_L_S = pkl.load( open( "test_L_S_TFIDF.p", "rb" )) 


# train_L_S = pkl.load( open( "train_L_S_Keywords.p", "rb" ) )
# test_L_S = pkl.load( open( "test_L_S_Keywords.p", "rb" )) 

# train_L_S = pkl.load( open( "train_L_S_Keywords_regex.p", "rb" ) )
# test_L_S = pkl.load( open( "test_L_S_Keywords_regex.p", "rb" )) 

train_L_S = pkl.load( open( "train_L_S_regex.p", "rb" ) )
test_L_S = pkl.load( open( "test_L_S_regex.p", "rb" )) 

# train_L_S = pkl.load( open( "train_L_S_Keywords_regex_extracts.p", "rb" ) )
# test_L_S = pkl.load( open( "test_L_S_Keywords_regex_extracts.p", "rb" )) 


LF_output_map = pkl.load(open("LF_output_map.p","rb"))
LF_Names = pkl.load(open("LF_Names.p","rb"))
LF_l = pkl.load(open("LF_l.p","rb"))
class_names = pkl.load(open("class_names.p","rb"))
# print(LF_Names,len(LF_Names))
# print(LF_output_map)
# print(class_names)
train_L_S_df = pd.DataFrame((np.array(train_L_S)[:,0,:]),columns=LF_Names) 
print(train_L_S_df.shape)

# train_df=pd.read_csv('./complaints_train_data_clean.csv',usecols=["category_name","complaint_title","complaint_description",],na_filter=False)

train_df=pd.read_csv('./complaints_train_validation_data_clean.csv',usecols=["index","category_name","complaint_title","complaint_description",],na_filter=False)

train_df['category_name'] = train_df["category_name"].astype('category')
train_df['true_label'] = train_df['category_name'].cat.codes

train_L_S = np.array(train_L_S,dtype=np.float64)
test_L_S = np.array(test_L_S,dtype=np.float64)
NoOfClasses = len(class_names) 
NoOfLFs = len(LF_Names) 

print(NoOfClasses,NoOfLFs)
# Out:
# (37595, 84)
# 42 84

# %%
def merge(a,b):
    c = []
    for i in range(len(a)):
        ci = []
        ci_l = a[i,0,:].tolist()+b[i,0,:].tolist()
        ci_s = a[i,1,:].tolist()+b[i,1,:].tolist()
        ci.append(ci_l)
        ci.append(ci_s)
        c.append(ci)
    return c
train_L_S_E = pkl.load( open( "train_L_S_T-D_Embeddings.p", "rb" ) )
test_L_S_E = pkl.load( open( "test_L_S_T-D_Embeddings.p", "rb" )) 

# train_L_S_K = pkl.load( open( "train_L_S_Regex.p", "rb" ) )
# test_L_S_K = pkl.load( open( "test_L_S_Regex.p", "rb" )) 

# train_L_S_K = pkl.load( open( "train_L_S_Keywords_regex.p", "rb" ) )
# test_L_S_K = pkl.load( open( "test_L_S_Keywords_regex.p", "rb" )) 

train_L_S_K = pkl.load( open( "train_L_S_Keywords_regex_extracts.p", "rb" ) )
test_L_S_K = pkl.load( open( "test_L_S_Keywords_regex_extracts.p", "rb" )) 


train_L_S = merge(np.array(train_L_S_K),np.array(train_L_S_E))
test_L_S = merge(np.array(test_L_S_K),np.array(test_L_S_E))
print(np.array(train_L_S).shape)
print(np.array(test_L_S).shape)

LF_output_map = pkl.load(open("LF_output_map.p","rb"))
LF_Names = pkl.load(open("LF_Names.p","rb"))
train_L_S_df = pd.DataFrame((np.array(train_L_S)[:,0,:]),columns=LF_Names) 

NoOfLFs = len(LF_Names) 
NoOfClasses = len(class_names)
# Out:
# (37595, 2, 245)
# (6667, 2, 245)

# %%
#load true test labels

test_df=pd.read_csv('./complaints_test_data_clean.csv',usecols=["category_name","complaint_title","complaint_description",],na_filter=False)

colsize = len(test_df['category_name'])

test_df['category_name'] = test_df["category_name"].astype('category')
test_df['true_label'] = test_df['category_name'].cat.codes

true_labels = test_df['true_label'].tolist()

# %%
#majority vote #84 # Regex
# train_L_S_df.mode(axis=1)[0].tolist()
import math
# test_L_S_df.mode(axis=1)[0].tolist()
test_L_S_df = pd.DataFrame((np.array(test_L_S)[:,0,:]),columns=LF_Names)
# test_L_S_df = test_L_S_df.astype(int)
test_L_S_df = test_L_S_df.replace(-1, np.NaN)

predicted_labels=test_L_S_df.mode(axis=1)[0].tolist()
# print(predicted_labels)
predicted_labels = [ int(x) if not math.isnan(x) else 28 for x in predicted_labels ]
Results = predictAndPrint(predicted_labels)
Results
# Out:
# acc 0.4976751162441878
# /home/vinay/snorkelEnv/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                                                     f1-score  precision  \
#  BMTC - Driver or Conductor                             0.48       0.39
#  Cattle                                                 0.64       0.47
#  Diseases                                               0.03       0.05
#  Government Land Encroachment                           0.22       1.00
#  Lakes - Others                                         0.00       0.00
#  Manholes                                               0.00       0.00
#  New Bus Shelters                                       0.29       0.95
#  No Sewage Drains                                       0.16       0.15
#  Others                                                 0.13       0.08
#  Overflow of Storm Water Drains                         0.00       0.00
#  Parking Violations                                     0.49       0.40
#  Potholes                                               0.62       0.87
#  Repair of streetlights                                 0.01       1.00
#  Sewage and Storm Water Drains - Others                 0.04       0.02
#  Stray Dogs                                             0.97       0.98
# Air Pollution                                           0.17       0.11
# Autorickshaws and Taxis                                 0.31       0.19
# BMTC - Need new Bus Route                               0.24       0.20
# BMTC - Others                                           0.45       0.37
# Bad Roads                                               0.36       0.62
# Broken Storm Water Drains                               0.00       0.00
# Clearing of Blockage of Under Ground Drainage P...      0.13       0.07
# Desilting - Lakes                                       0.19       0.11
# Electricity                                             0.64       0.78
# Flooding of Roads and Footpaths                         0.05       0.07
# Footpaths                                               0.53       0.51
# Garbage                                                 0.87       0.90
# Hawkers and Vendors                                     0.27       0.27
# Hoardings                                               0.55       0.71
# Illegal posters and Hoardings                           0.05       0.02
# Maintenance of Roads and Footpaths - Others             0.00       0.00
# Mosquitos                                               0.64       0.54
# Need New Streetlights                                   0.26       0.18
# Need New Toilets                                        0.58       0.54
# Noise Pollution                                         0.48       0.47
# Parks and playgrounds                                   0.40       0.30
# Public Nuisance                                         0.04       0.08
# Traffic                                                 0.58       0.77
# Trees, Parks and Playgrounds - Others                   0.06       0.03
# Unauthorized Construction                               0.00       0.00
# Water Leakage                                           0.00       0.00
# Water Supply                                            0.00       0.00
# avg / total                                             0.53       0.68
#
#                                                     recall  support
#  BMTC - Driver or Conductor                           0.62     26.0
#  Cattle                                               1.00      9.0
#  Diseases                                             0.02     49.0
#  Government Land Encroachment                         0.12      8.0
#  Lakes - Others                                       0.00     11.0
#  Manholes                                             0.00     13.0
#  New Bus Shelters                                     0.17    121.0
#  No Sewage Drains                                     0.16    100.0
#  Others                                               0.32    131.0
#  Overflow of Storm Water Drains                       0.00     41.0
#  Parking Violations                                   0.63     82.0
#  Potholes                                             0.48    961.0
#  Repair of streetlights                               0.00    259.0
#  Sewage and Storm Water Drains - Others               0.18     33.0
#  Stray Dogs                                           0.96    511.0
# Air Pollution                                         0.38     45.0
# Autorickshaws and Taxis                               0.83     18.0
# BMTC - Need new Bus Route                             0.30     53.0
# BMTC - Others                                         0.57    125.0
# Bad Roads                                             0.26   1008.0
# Broken Storm Water Drains                             0.00     20.0
# Clearing of Blockage of Under Ground Drainage P...    0.51     71.0
# Desilting - Lakes                                     0.80     10.0
# Electricity                                           0.54    182.0
# Flooding of Roads and Footpaths                       0.04     55.0
# Footpaths                                             0.55    217.0
# Garbage                                               0.85   1319.0
# Hawkers and Vendors                                   0.26     23.0
# Hoardings                                             0.44     27.0
# Illegal posters and Hoardings                         0.64     14.0
# Maintenance of Roads and Footpaths - Others           0.00     27.0
# Mosquitos                                             0.78     27.0
# Need New Streetlights                                 0.48     48.0
# Need New Toilets                                      0.62     21.0
# Noise Pollution                                       0.48     31.0
# Parks and playgrounds                                 0.62     34.0
# Public Nuisance                                       0.03     36.0
# Traffic                                               0.47    681.0
# Trees, Parks and Playgrounds - Others                 0.73     11.0
# Unauthorized Construction                             0.00     21.0
# Water Leakage                                         0.00     52.0
# Water Supply                                          0.00    136.0
# avg / total                                           0.50   6667.0

# %%
#  load 500 gold labels
# gold_df=pd.read_csv('./clean-gold-labels.tsv',sep='\t',usecols=["category_name","complaint_description",],na_filter=False)

# colsize = len(test_df['category_name'])

# gold_df['category_name'] = test_df["category_name"].astype('category')
# gold_df['true_label'] = test_df['category_name'].cat.codes

# true_labels = test_df['true_label'].tolist()
                    
# test_L_S = pkl.load( open( "gold-labels-clean.p", "rb" )) 
# print(np.array(test_L_S).shape)
# for i,x in enumerate(gold_df.groupby("category_name").agg({"complaint_description": np.count_nonzero}).index._data):
#     print(i,x)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from collections import defaultdict
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support

def draw2DArray(a):
    fig = plt.figure(figsize=(6, 3.2))
    ax = fig.add_subplot(111)
    ax.set_title('colorMap')
    plt.imshow(np.array(a))
    ax.set_aspect('equal')
    cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
    cax.get_xaxis().set_visible(False)
    cax.get_yaxis().set_visible(False)
    cax.patch.set_alpha(0)
    cax.set_frame_on(False)
    plt.colorbar(orientation='vertical')
    plt.show()
    
      
def report2dict(cr):
    # Parse rows
    tmp = list()
    for row in cr.split("\n"):
        parsed_row = [x for x in row.split("  ") if len(x) > 0]
        if len(parsed_row) > 0:
            tmp.append(parsed_row)
    
    # Store in dictionary
    measures = tmp[0]

    D_class_data = defaultdict(dict)
    for row in tmp[1:]:
        class_label = row[0]
        for j, m in enumerate(measures):
            D_class_data[class_label][m.strip()] = float(row[j + 1].strip())
    return pd.DataFrame(D_class_data).T

def predictAndPrint(pl):
    print("acc",accuracy_score(true_labels,pl))
#     print(precision_recall_fscore_support(true_labels,pl,average='macro'))
#     draw2DArray(confusion_matrix(true_labels,pl))
    return report2dict(classification_report(true_labels, pl, target_names=class_names))

# %%
#  title regex+ desc regex
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support

lf_stats = dict()
# index = ['coverage','overlap','conflict','accuracy']
for col1 in train_L_S_df.iteritems(): #col1[0] is name , col1[1] is column data
    coverage = col1[1].tolist().count(LF_output_map[col1[0]])
    pl = col1[1].tolist() # contains -1 and LF_output_map[col1[0]]
    tl = [-1 if x!=LF_output_map[col1[0]] else x for x in train_df['true_label'] ]
    precision,recall,f1_score,_ =  precision_recall_fscore_support(tl,pl,average='binary',pos_label=LF_output_map[col1[0]])
    lf_stats[col1[0]] = pd.Series([coverage,precision,recall,f1_score],index=['coverage','precision','recall','f1_score'])

lf_stats_df = pd.DataFrame(lf_stats,index=['coverage','precision','recall','f1_score'],columns=LF_Names).T

lf_stats_df.to_csv("lf_stats.csv")
lf_stats_df
# Out:
# /home/vinay/snorkelEnv/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                                                     coverage  precision  \
# LF_Title_Regex_AirPollution                            414.0   0.164251
# LF_Title_Regex_AutorickshawsandTaxis                   220.0   0.331818
# LF_Title_Regex_BMTCDriverorConductor                    44.0   0.545455
# LF_Title_Regex_BMTCNeednewBusRoute                      87.0   0.712644
# LF_Title_Regex_BMTCOthers                             1046.0   0.389101
# LF_Title_Regex_BadRoads                               1779.0   0.682406
# LF_Title_Regex_BrokenStormWaterDrains                   34.0   0.264706
# LF_Title_Regex_Cattle                                   86.0   0.558140
# LF_Title_Regex_ClearingofBlockageofUnderGroundD...    1777.0   0.092290
# LF_Title_Regex_DesiltingLakes                          462.0   0.188312
# LF_Title_Regex_Diseases                                 65.0   0.184615
# LF_Title_Regex_Electricity                             575.0   0.918261
# LF_Title_Regex_FloodingofRoadsandFootpaths              70.0   0.157143
# LF_Title_Regex_Footpaths                              1187.0   0.513058
# LF_Title_Regex_Garbage                                6696.0   0.927569
# LF_Title_Regex_GovernmentLandEncroachment                2.0   1.000000
# LF_Title_Regex_HawkersandVendors                       106.0   0.339623
# LF_Title_Regex_Hoardings                               122.0   0.819672
# LF_Title_Regex_IllegalpostersandHoardings             2507.0   0.013163
# LF_Title_Regex_LakesOthers                             462.0   0.160173
# LF_Title_Regex_MaintenanceofRoadsandFootpathsOt...      34.0   0.000000
# LF_Title_Regex_Manholes                                203.0   0.305419
# LF_Title_Regex_Mosquitos                               230.0   0.482609
# LF_Title_Regex_NeedNewStreetlights                     611.0   0.158756
# LF_Title_Regex_NeedNewToilets                          154.0   0.558442
# LF_Title_Regex_NewBusShelters                          121.0   0.826446
# LF_Title_Regex_NoSewageDrains                         1281.0   0.176425
# LF_Title_Regex_NoisePollution                          226.0   0.769912
# LF_Title_Regex_Others                                   14.0   0.071429
# LF_Title_Regex_OverflowofStormWaterDrains               13.0   0.307692
# ...                                                      ...        ...
# LF_Desc_Regex_FloodingofRoadsandFootpaths              671.0   0.037258
# LF_Desc_Regex_Footpaths                               1763.0   0.376064
# LF_Desc_Regex_Garbage                                 8165.0   0.794121
# LF_Desc_Regex_GovernmentLandEncroachment                 5.0   0.800000
# LF_Desc_Regex_HawkersandVendors                        343.0   0.160350
# LF_Desc_Regex_Hoardings                                160.0   0.700000
# LF_Desc_Regex_IllegalpostersandHoardings              5431.0   0.007365
# LF_Desc_Regex_LakesOthers                              901.0   0.082131
# LF_Desc_Regex_MaintenanceofRoadsandFootpathsOthers      60.0   0.016667
# LF_Desc_Regex_Manholes                                 364.0   0.175824
# LF_Desc_Regex_Mosquitos                               1303.0   0.090560
# LF_Desc_Regex_NeedNewStreetlights                     1466.0   0.072306
# LF_Desc_Regex_NeedNewToilets                           400.0   0.257500
# LF_Desc_Regex_NewBusShelters                           204.0   0.666667
# LF_Desc_Regex_NoSewageDrains                          2423.0   0.104829
# LF_Desc_Regex_NoisePollution                           545.0   0.366972
# LF_Desc_Regex_Others                                   283.0   0.035336
# LF_Desc_Regex_OverflowofStormWaterDrains                50.0   0.100000
# LF_Desc_Regex_ParkingViolations                       1520.0   0.223026
# LF_Desc_Regex_Parksandplaygrounds                     3552.0   0.052646
# LF_Desc_Regex_Potholes                                4806.0   0.671868
# LF_Desc_Regex_PublicNuisance                           488.0   0.086066
# LF_Desc_Regex_Repairofstreetlights                     228.0   0.342105
# LF_Desc_Regex_SewageandStormWaterDrainsOthers         4963.0   0.038686
# LF_Desc_Regex_StrayDogs                               3691.0   0.812246
# LF_Desc_Regex_Traffic                                 7194.0   0.369058
# LF_Desc_Regex_TreesParksandPlaygroundsOthers          4807.0   0.016434
# LF_Desc_Regex_UnauthorizedConstruction                   0.0   0.000000
# LF_Desc_Regex_WaterLeakage                             296.0   0.466216
# LF_Desc_Regex_WaterSupply                              420.0   0.776190
#
#                                                       recall  f1_score
# LF_Title_Regex_AirPollution                         0.363636  0.226290
# LF_Title_Regex_AutorickshawsandTaxis                0.663636  0.442424
# LF_Title_Regex_BMTCDriverorConductor                0.143713  0.227488
# LF_Title_Regex_BMTCNeednewBusRoute                  0.196825  0.308458
# LF_Title_Regex_BMTCOthers                           0.492736  0.434829
# LF_Title_Regex_BadRoads                             0.224399  0.337738
# LF_Title_Regex_BrokenStormWaterDrains               0.065693  0.105263
# LF_Title_Regex_Cattle                               0.786885  0.653061
# LF_Title_Regex_ClearingofBlockageofUnderGroundD...  0.384075  0.148820
# LF_Title_Regex_DesiltingLakes                       0.925532  0.312950
# LF_Title_Regex_Diseases                             0.056872  0.086957
# LF_Title_Regex_Electricity                          0.471429  0.623009
# LF_Title_Regex_FloodingofRoadsandFootpaths          0.039568  0.063218
# LF_Title_Regex_Footpaths                            0.548155  0.530026
# LF_Title_Regex_Garbage                              0.829018  0.875529
# LF_Title_Regex_GovernmentLandEncroachment           0.024096  0.047059
# LF_Title_Regex_HawkersandVendors                    0.213018  0.261818
# LF_Title_Regex_Hoardings                            0.497512  0.619195
# LF_Title_Regex_IllegalpostersandHoardings           0.452055  0.025581
# LF_Title_Regex_LakesOthers                          0.925000  0.273063
# LF_Title_Regex_MaintenanceofRoadsandFootpathsOt...  0.000000  0.000000
# LF_Title_Regex_Manholes                             0.704545  0.426117
# LF_Title_Regex_Mosquitos                            0.860465  0.618384
# LF_Title_Regex_NeedNewStreetlights                  0.527174  0.244025
# LF_Title_Regex_NeedNewToilets                       0.688000  0.616487
# LF_Title_Regex_NewBusShelters                       0.164474  0.274348
# LF_Title_Regex_NoSewageDrains                       0.479830  0.257991
# LF_Title_Regex_NoisePollution                       0.698795  0.732632
# LF_Title_Regex_Others                               0.001527  0.002990
# LF_Title_Regex_OverflowofStormWaterDrains           0.016736  0.031746
# ...                                                      ...       ...
# LF_Desc_Regex_FloodingofRoadsandFootpaths           0.089928  0.052687
# LF_Desc_Regex_Footpaths                             0.596760  0.461378
# LF_Desc_Regex_Garbage                               0.865456  0.828256
# LF_Desc_Regex_GovernmentLandEncroachment            0.048193  0.090909
# LF_Desc_Regex_HawkersandVendors                     0.325444  0.214844
# LF_Desc_Regex_Hoardings                             0.557214  0.620499
# LF_Desc_Regex_IllegalpostersandHoardings            0.547945  0.014535
# LF_Desc_Regex_LakesOthers                           0.925000  0.150866
# LF_Desc_Regex_MaintenanceofRoadsandFootpathsOthers  0.004762  0.007407
# LF_Desc_Regex_Manholes                              0.727273  0.283186
# LF_Desc_Regex_Mosquitos                             0.914729  0.164804
# LF_Desc_Regex_NeedNewStreetlights                   0.576087  0.128485
# LF_Desc_Regex_NeedNewToilets                        0.824000  0.392381
# LF_Desc_Regex_NewBusShelters                        0.223684  0.334975
# LF_Desc_Regex_NoSewageDrains                        0.539278  0.175536
# LF_Desc_Regex_NoisePollution                        0.803213  0.503778
# LF_Desc_Regex_Others                                0.015267  0.021322
# LF_Desc_Regex_OverflowofStormWaterDrains            0.020921  0.034602
# LF_Desc_Regex_ParkingViolations                     0.847500  0.353125
# LF_Desc_Regex_Parksandplaygrounds                   0.886256  0.099389
# LF_Desc_Regex_Potholes                              0.603890  0.636068
# LF_Desc_Regex_PublicNuisance                        0.187500  0.117978
# LF_Desc_Regex_Repairofstreetlights                  0.058122  0.099363
# LF_Desc_Regex_SewageandStormWaterDrainsOthers       0.831169  0.073931
# LF_Desc_Regex_StrayDogs                             0.949035  0.875328
# LF_Desc_Regex_Traffic                               0.668261  0.475508
# LF_Desc_Regex_TreesParksandPlaygroundsOthers        0.831579  0.032232
# LF_Desc_Regex_UnauthorizedConstruction              0.000000  0.000000
# LF_Desc_Regex_WaterLeakage                          0.563265  0.510166
# LF_Desc_Regex_WaterSupply                           0.422827  0.547439
#
# [84 rows x 4 columns]

# %%
# Regex 84 Unnormalized
predicted_labels=train_unl(0.01,1,tf.truncated_normal_initializer(1,0.1,12))
Results = predictAndPrint(predicted_labels)
Results.to_csv("results.csv")
Results
# Out:
# next_element Tensor("IteratorGetNext_1:0", shape=(?, 2, 84), dtype=float64)
# thetas <tf.Variable 'thetas:0' shape=(1, 84) dtype=float64_ref>
# k Tensor("Const:0", shape=(84,), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f889e0f0>
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f889e0f0>
# <tf.Variable 'alphas:0' shape=(84,) dtype=float64_ref>
# Tensor("unstack:1", shape=(?, 84), dtype=float64)
# l Tensor("unstack:0", shape=(?, 84), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f889e0f0>
# out Tensor("map_1/while/Select:0", shape=(?, 84), dtype=float64)
# nls Tensor("mul:0", shape=(?, 84), dtype=float64)
# pout Tensor("map_1/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 84), dtype=float64)
# t_pout Tensor("map_2/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 1), dtype=float64)
# t Tensor("Squeeze:0", shape=(84,), dtype=float64)
# out Tensor("map_3/while/Select:0", shape=(84,), dtype=float64)
# zy Tensor("map_3/TensorArrayStack/TensorArrayGatherV3:0", shape=(42,), dtype=float64)
# logz Tensor("Log:0", shape=(), dtype=float64)
# lsp Tensor("ReduceLogSumExp/add:0", shape=(), dtype=float64)
# normloss Tensor("Neg:0", shape=(), dtype=float64)
# marginals Tensor("transpose_1:0", shape=(42, ?, 1), dtype=float64)
# predict Tensor("ArgMax:0", shape=(?, 1), dtype=int64)
# 0 loss -3297257.674041148
# [0.31754463 0.01421453 0.20955965 0.20062431 0.30637787 0.24133855
#  0.369206   0.23120785 0.34633471 0.2647233  0.18357064 0.26661405
#  0.18238184 0.27858159 0.24081247 0.24223612 0.05334134 0.11993454
#  0.25962482 0.03641602 0.23537624 0.14143537 0.19621468 0.36301113
#  0.07373343 0.37747756 0.26808572 0.26850778 0.25747627 0.19034372
#  0.02199156 0.03837747 0.16215054 0.28407008 0.20081754 0.05785297
#  0.26707259 0.14537297 0.1048543  0.21718104 0.28321176 0.12616597
#  0.31429502 0.0863964  0.22745796 0.29568415 0.35099954 0.29810888
#  0.20629042 0.13901088 0.05940858 0.10766452 0.17473813 0.38014276
#  0.39700817 0.17087316 0.19603627 0.16858467 0.24490965 0.05639868
#  0.26852239 0.07893876 0.24100708 0.28263506 0.31951938 0.38431001
#  0.26592654 0.24531187 0.29454672 0.17417758 0.23602695 0.22370915
#  0.26280696 0.1543867  0.33688209 0.13802535 0.2324581  0.21384075
#  0.32596594 0.23165596 0.34775589 0.1425593  0.10759231 0.27399862]
# [[ 18.84367959  16.68559127   3.47389212  12.58135513  58.43837294
#    11.79681019  16.91783888  15.03898309  12.82768983  17.59823181
#     6.67193969   1.55873224   3.51349661  57.79787003 118.76076051
#     8.08493206   1.40468649 114.96881735 109.91356637 145.29275851
#    93.9090951    0.9425593    1.1363148    1.54521374]]
# {0: 521, 1: 28, 2: 6, 3: 48, 4: 187, 5: 103, 7: 2, 8: 124, 9: 3, 10: 1, 11: 97, 13: 107, 14: 1459, 16: 1, 18: 425, 19: 14, 21: 1, 22: 20, 23: 10, 24: 13, 25: 9, 26: 7, 27: 10, 28: 2, 31: 143, 32: 748, 33: 4, 35: 646, 36: 516, 37: 984, 38: 428}
# acc 0.4790760461976901
# acc 0.4790760461976901
# (0.2971344703944456, 0.24363509350121504, 0.19423660413395455, None)
# acc 0.4790760461976901
#                                                     f1-score  precision  \
#  BMTC - Driver or Conductor                             0.31       0.83
#  Cattle                                                 0.18       0.50
#  Diseases                                               0.04       1.00
#  Government Land Encroachment                           0.00       0.00
#  Lakes - Others                                         0.16       0.14
#  Manholes                                               0.00       0.00
#  New Bus Shelters                                       0.14       1.00
#  No Sewage Drains                                       0.04       0.29
#  Others                                                 0.00       0.00
#  Overflow of Storm Water Drains                         0.00       0.00
#  Parking Violations                                     0.00       0.00
#  Potholes                                               0.68       0.78
#  Repair of streetlights                                 0.00       0.00
#  Sewage and Storm Water Drains - Others                 0.08       0.04
#  Stray Dogs                                             0.97       0.97
# Air Pollution                                           0.04       0.02
# Autorickshaws and Taxis                                 0.48       0.39
# BMTC - Need new Bus Route                               0.18       0.19
# BMTC - Others                                           0.46       0.38
# Bad Roads                                               0.12       0.63
# Broken Storm Water Drains                               0.00       0.00
# Clearing of Blockage of Under Ground Drainage P...      0.02       0.02
# Desilting - Lakes                                       0.15       0.33
# Electricity                                             0.60       0.87
# Flooding of Roads and Footpaths                         0.00       0.00
# Footpaths                                               0.35       0.53
# Garbage                                                 0.87       0.83
# Hawkers and Vendors                                     0.00       0.00
# Hoardings                                               0.00       0.00
# Illegal posters and Hoardings                           0.05       0.02
# Maintenance of Roads and Footpaths - Others             0.00       0.00
# Mosquitos                                               0.60       0.70
# Need New Streetlights                                   0.07       0.20
# Need New Toilets                                        0.53       0.69
# Noise Pollution                                         0.24       0.50
# Parks and playgrounds                                   0.19       0.12
# Public Nuisance                                         0.00       0.00
# Traffic                                                 0.58       0.49
# Trees, Parks and Playgrounds - Others                   0.04       0.02
# Unauthorized Construction                               0.00       0.00
# Water Leakage                                           0.00       0.00
# Water Supply                                            0.00       0.00
# avg / total                                             0.47       0.59
#
#                                                     recall  support
#  BMTC - Driver or Conductor                           0.19     26.0
#  Cattle                                               0.11      9.0
#  Diseases                                             0.02     49.0
#  Government Land Encroachment                         0.00      8.0
#  Lakes - Others                                       0.18     11.0
#  Manholes                                             0.00     13.0
#  New Bus Shelters                                     0.07    121.0
#  No Sewage Drains                                     0.02    100.0
#  Others                                               0.00    131.0
#  Overflow of Storm Water Drains                       0.00     41.0
#  Parking Violations                                   0.00     82.0
#  Potholes                                             0.60    961.0
#  Repair of streetlights                               0.00    259.0
#  Sewage and Storm Water Drains - Others               0.85     33.0
#  Stray Dogs                                           0.98    511.0
# Air Pollution                                         0.22     45.0
# Autorickshaws and Taxis                               0.61     18.0
# BMTC - Need new Bus Route                             0.17     53.0
# BMTC - Others                                         0.57    125.0
# Bad Roads                                             0.06   1008.0
# Broken Storm Water Drains                             0.00     20.0
# Clearing of Blockage of Under Ground Drainage P...    0.03     71.0
# Desilting - Lakes                                     0.10     10.0
# Electricity                                           0.46    182.0
# Flooding of Roads and Footpaths                       0.00     55.0
# Footpaths                                             0.26    217.0
# Garbage                                               0.92   1319.0
# Hawkers and Vendors                                   0.00     23.0
# Hoardings                                             0.00     27.0
# Illegal posters and Hoardings                         0.71     14.0
# Maintenance of Roads and Footpaths - Others           0.00     27.0
# Mosquitos                                             0.52     27.0
# Need New Streetlights                                 0.04     48.0
# Need New Toilets                                      0.43     21.0
# Noise Pollution                                       0.16     31.0
# Parks and playgrounds                                 0.50     34.0
# Public Nuisance                                       0.00     36.0
# Traffic                                               0.70    681.0
# Trees, Parks and Playgrounds - Others                 0.73     11.0
# Unauthorized Construction                             0.00     21.0
# Water Leakage                                         0.00     52.0
# Water Supply                                          0.00    136.0
# avg / total                                           0.48   6667.0

# %%
# Regex 84 normalized
predicted_labels=train_nl(0.1/len(train_L_S),1,tf.truncated_normal_initializer(1,0.1,12))
Results = predictAndPrint(predicted_labels)
Results.to_csv("results.csv")
Results
# Out:
# next_element Tensor("IteratorGetNext_1:0", shape=(?, 2, 84), dtype=float64)
# thetas <tf.Variable 'thetas:0' shape=(1, 84) dtype=float64_ref>
# k Tensor("Const:0", shape=(84,), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8d6e6d8>
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8d6e6d8>
# <tf.Variable 'alphas:0' shape=(84,) dtype=float64_ref>
# Tensor("unstack:1", shape=(?, 84), dtype=float64)
# l Tensor("unstack:0", shape=(?, 84), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8d6e6d8>
# out Tensor("map_1/while/Select:0", shape=(?, 84), dtype=float64)
# nls Tensor("mul:0", shape=(?, 84), dtype=float64)
# pout Tensor("map_1/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 84), dtype=float64)
# t_pout Tensor("map_2/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 1), dtype=float64)
# t Tensor("Squeeze:0", shape=(84,), dtype=float64)
# out Tensor("map_3/while/Select:0", shape=(84,), dtype=float64)
# zy Tensor("map_3/TensorArrayStack/TensorArrayGatherV3:0", shape=(42,), dtype=float64)
# logz Tensor("Log:0", shape=(), dtype=float64)
# lsp Tensor("ReduceLogSumExp/add:0", shape=(), dtype=float64)
# normloss Tensor("Neg:0", shape=(), dtype=float64)
# marginals Tensor("transpose_1:0", shape=(42, ?, 1), dtype=float64)
# predict Tensor("ArgMax:0", shape=(?, 1), dtype=int64)
# 0 loss 2228793.207535685
# [0.31754463 0.01421453 0.20955965 0.20062431 0.30637787 0.24133855
# Hoardings                                               0.00       0.00
# Illegal posters and Hoardings                           0.04       0.02
# Maintenance of Roads and Footpaths - Others             0.00       0.00
# Mosquitos                                               0.63       0.50
# Need New Streetlights                                   0.25       0.17
# Need New Toilets                                        0.60       0.54
# Noise Pollution                                         0.56       0.65
# Parks and playgrounds                                   0.46       0.36
# Public Nuisance                                         0.00       0.00
# Traffic                                                 0.61       0.69
# Trees, Parks and Playgrounds - Others                   0.04       0.02
# Unauthorized Construction                               0.00       0.00
# Water Leakage                                           0.14       0.80
# Water Supply                                            0.37       0.94
# avg / total                                             0.53       0.65
#
#                                                     recall  support
#  BMTC - Driver or Conductor                           0.31     26.0
#  Cattle                                               0.56      9.0
#  Diseases                                             0.02     49.0
#  Government Land Encroachment                         0.12      8.0
#  Lakes - Others                                       0.00     11.0
#  Manholes                                             0.00     13.0
#  New Bus Shelters                                     0.18    121.0
#  No Sewage Drains                                     0.38    100.0
#  Others                                               0.00    131.0
#  Overflow of Storm Water Drains                       0.00     41.0
#  Parking Violations                                   0.52     82.0
#  Potholes                                             0.58    961.0
#  Repair of streetlights                               0.00    259.0
#  Sewage and Storm Water Drains - Others               0.21     33.0
#  Stray Dogs                                           0.98    511.0
# Air Pollution                                         0.40     45.0
# Autorickshaws and Taxis                               0.78     18.0
# BMTC - Need new Bus Route                             0.25     53.0
# BMTC - Others                                         0.63    125.0
# Bad Roads                                             0.14   1008.0
# Broken Storm Water Drains                             0.00     20.0
# Clearing of Blockage of Under Ground Drainage P...    0.11     71.0
# Desilting - Lakes                                     0.70     10.0
# Electricity                                           0.54    182.0
# Flooding of Roads and Footpaths                       0.04     55.0
# Footpaths                                             0.54    217.0
# Garbage                                               0.85   1319.0
# Hawkers and Vendors                                   0.17     23.0
# Hoardings                                             0.00     27.0
# Illegal posters and Hoardings                         0.79     14.0
# Maintenance of Roads and Footpaths - Others           0.00     27.0
# Mosquitos                                             0.85     27.0
# Need New Streetlights                                 0.48     48.0
# Need New Toilets                                      0.67     21.0
# Noise Pollution                                       0.48     31.0
# Parks and playgrounds                                 0.62     34.0
# Public Nuisance                                       0.00     36.0
# Traffic                                               0.54    681.0
# Trees, Parks and Playgrounds - Others                 0.73     11.0
# Unauthorized Construction                             0.00     21.0
# Water Leakage                                         0.08     52.0
# Water Supply                                          0.23    136.0
# avg / total                                           0.50   6667.0

# %%
# Regex 84 normalized run 2 
predicted_labels=train_nl(0.1/len(train_L_S),5,tf.truncated_normal_initializer(1,0.1,12))
Results = predictAndPrint(predicted_labels)
Results.to_csv("results.csv")
Results
# Out:
# next_element Tensor("IteratorGetNext_1:0", shape=(?, 2, 84), dtype=float64)
# thetas <tf.Variable 'thetas:0' shape=(1, 84) dtype=float64_ref>
# k Tensor("Const:0", shape=(84,), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f822b0>
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f822b0>
# <tf.Variable 'alphas:0' shape=(84,) dtype=float64_ref>
# Tensor("unstack:1", shape=(?, 84), dtype=float64)
# l Tensor("unstack:0", shape=(?, 84), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f822b0>
# out Tensor("map_1/while/Select:0", shape=(?, 84), dtype=float64)
# nls Tensor("mul:0", shape=(?, 84), dtype=float64)
# pout Tensor("map_1/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 84), dtype=float64)
# t_pout Tensor("map_2/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 1), dtype=float64)
# t Tensor("Squeeze:0", shape=(84,), dtype=float64)
# out Tensor("map_3/while/Select:0", shape=(84,), dtype=float64)
# zy Tensor("map_3/TensorArrayStack/TensorArrayGatherV3:0", shape=(42,), dtype=float64)
# logz Tensor("Log:0", shape=(), dtype=float64)
# lsp Tensor("ReduceLogSumExp/add:0", shape=(), dtype=float64)
# normloss Tensor("Neg:0", shape=(), dtype=float64)
# marginals Tensor("transpose_1:0", shape=(42, ?, 1), dtype=float64)
# predict Tensor("ArgMax:0", shape=(?, 1), dtype=int64)
# 0 loss 2228793.207535685
# [0.31754463 0.01421453 0.20955965 0.20062431 0.30637787 0.24133855
#  0.369206   0.23120785 0.34633471 0.2647233  0.18357064 0.26661405
#  0.18238184 0.27858159 0.24081247 0.24223612 0.05334134 0.11993454
#  0.25962482 0.03641602 0.23537624 0.14143537 0.19621468 0.36301113
#  0.07373343 0.37747756 0.26808572 0.26850778 0.25747627 0.19034372
#  0.02199156 0.03837747 0.16215054 0.28407008 0.20081754 0.05785297
#  0.26707259 0.14537297 0.1048543  0.21718104 0.28321176 0.12616597
#  0.31429502 0.0863964  0.22745796 0.29568415 0.35099954 0.29810888
#  0.20629042 0.13901088 0.05940858 0.10766452 0.17473813 0.38014276
#  0.39700817 0.17087316 0.19603627 0.16858467 0.24490965 0.05639868
#  0.26852239 0.07893876 0.24100708 0.28263506 0.31951938 0.38431001
#  0.26592654 0.24531187 0.29454672 0.17417758 0.23602695 0.22370915
#  0.26280696 0.1543867  0.33688209 0.13802535 0.2324581  0.21384075
#  0.32596594 0.23165596 0.34775589 0.1425593  0.10759231 0.27399862]
# [[1.03710943 0.72891069 0.91256307 0.9065573  1.04359179 0.99179506
#   1.07033153 0.93697395 1.09931246 0.98664338 0.88710382 1.00020554
#   0.8844131  1.0257479  1.05320124 0.94250273 0.75971955 0.82706024
#   1.02566678 0.75808689 0.93623337 0.85304691 0.91144645 1.0890069
#   0.78471138 1.08629106 1.01363184 0.98196969 0.9578832  0.890922
#   0.75897035 0.79083164 0.94504572 0.98910501 0.90256731 0.83399044
#   1.0526879  0.91296422 0.87918072 0.91735828 0.99442894 0.84282007
#   1.04270585 0.80845978 0.93485408 1.01116604 1.08801828 1.05492529
#   0.9081924  0.84715166 0.83377025 0.83439804 0.88535814 1.1166286
#   1.10502333 0.92236289 1.01219273 0.86888731 0.95393976 0.76423516
#   1.04786037 0.80500049 0.94208612 0.99527191 1.04370474 1.11600129
#   0.9791124  0.95540789 1.0464887  0.89115602 0.93954564 0.9246477
#   1.00317469 0.91967407 1.12446706 0.84673924 0.9362469  0.99849333
#   1.11282625 1.02320935 1.12996779 0.84274034 0.82023684 0.99097614]]
# acc 0.5003749812509375
# (0.37501114579154465, 0.34497603212284494, 0.2827689761697568, None)
# /home/vinay/snorkelEnv/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
#  No Sewage Drains                                       0.08       0.16
#  Others                                                 0.00       0.00
#  Overflow of Storm Water Drains                         0.00       0.00
#  Parking Violations                                     0.00       0.00
#  Potholes                                               0.67       0.77
#  Repair of streetlights                                 0.00       0.00
#  Sewage and Storm Water Drains - Others                 0.10       0.05
#  Stray Dogs                                             0.97       0.97
# Air Pollution                                           0.05       0.03
# Autorickshaws and Taxis                                 0.51       0.44
# BMTC - Need new Bus Route                               0.21       0.22
# BMTC - Others                                           0.46       0.38
# Bad Roads                                               0.18       0.60
# Broken Storm Water Drains                               0.00       0.00
# Clearing of Blockage of Under Ground Drainage P...      0.04       0.03
# Desilting - Lakes                                       0.34       0.23
# Electricity                                             0.63       0.83
# Flooding of Roads and Footpaths                         0.00       0.00
# Footpaths                                               0.56       0.58
# Garbage                                                 0.88       0.86
# Hawkers and Vendors                                     0.24       0.40
# Hoardings                                               0.00       0.00
# Illegal posters and Hoardings                           0.05       0.02
# Maintenance of Roads and Footpaths - Others             0.00       0.00
# Mosquitos                                               0.71       0.66
# Need New Streetlights                                   0.12       0.16
# Need New Toilets                                        0.63       0.65
# Noise Pollution                                         0.45       0.61
# Parks and playgrounds                                   0.22       0.13
# Public Nuisance                                         0.00       0.00
# Traffic                                                 0.60       0.59
# Trees, Parks and Playgrounds - Others                   0.04       0.02
# Unauthorized Construction                               0.00       0.00
# Water Leakage                                           0.00       0.00
# Water Supply                                            0.00       0.00
# avg / total                                             0.50       0.60
#
#                                                     recall  support
#  BMTC - Driver or Conductor                           0.23     26.0
#  Cattle                                               0.44      9.0
#  Diseases                                             0.02     49.0
#  Government Land Encroachment                         0.12      8.0
#  Lakes - Others                                       0.00     11.0
#  Manholes                                             0.00     13.0
#  New Bus Shelters                                     0.17    121.0
#  No Sewage Drains                                     0.05    100.0
#  Others                                               0.00    131.0
#  Overflow of Storm Water Drains                       0.00     41.0
#  Parking Violations                                   0.00     82.0
#  Potholes                                             0.60    961.0
#  Repair of streetlights                               0.00    259.0
#  Sewage and Storm Water Drains - Others               0.82     33.0
#  Stray Dogs                                           0.98    511.0
# Air Pollution                                         0.33     45.0
# Autorickshaws and Taxis                               0.61     18.0
# BMTC - Need new Bus Route                             0.21     53.0
# BMTC - Others                                         0.59    125.0
# Bad Roads                                             0.11   1008.0
# Broken Storm Water Drains                             0.00     20.0
# Clearing of Blockage of Under Ground Drainage P...    0.07     71.0
# Desilting - Lakes                                     0.70     10.0
# Electricity                                           0.51    182.0
# Flooding of Roads and Footpaths                       0.00     55.0
# Footpaths                                             0.53    217.0
# Garbage                                               0.91   1319.0
# Hawkers and Vendors                                   0.17     23.0
# Hoardings                                             0.00     27.0
# Illegal posters and Hoardings                         0.79     14.0
# Maintenance of Roads and Footpaths - Others           0.00     27.0
# Mosquitos                                             0.78     27.0
# Need New Streetlights                                 0.10     48.0
# Need New Toilets                                      0.62     21.0
# Noise Pollution                                       0.35     31.0
# Parks and playgrounds                                 0.65     34.0
# Public Nuisance                                       0.00     36.0
# Traffic                                               0.60    681.0
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f2b0>
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f2b0>
# <tf.Variable 'alphas:0' shape=(84,) dtype=float64_ref>
# Tensor("unstack:1", shape=(?, 84), dtype=float64)
# l Tensor("unstack:0", shape=(?, 84), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f2b0>
# out Tensor("map_1/while/Select:0", shape=(?, 84), dtype=float64)
# nls Tensor("mul:0", shape=(?, 84), dtype=float64)
# pout Tensor("map_1/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 84), dtype=float64)
# t_pout Tensor("map_2/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 1), dtype=float64)
# t Tensor("Squeeze:0", shape=(84,), dtype=float64)
# out Tensor("map_3/while/Select:0", shape=(84,), dtype=float64)
# zy Tensor("map_3/TensorArrayStack/TensorArrayGatherV3:0", shape=(42,), dtype=float64)
# logz Tensor("Log:0", shape=(), dtype=float64)
# lsp Tensor("ReduceLogSumExp/add:0", shape=(), dtype=float64)
# normloss Tensor("Neg:0", shape=(), dtype=float64)
# marginals Tensor("transpose_1:0", shape=(42, ?, 1), dtype=float64)
# predict Tensor("ArgMax:0", shape=(?, 1), dtype=int64)
# 0 loss 2261096.5187480315
# [0.31754463 0.01421453 0.20955965 0.20062431 0.30637787 0.24133855
#  0.369206   0.23120785 0.34633471 0.2647233  0.18357064 0.26661405
#  0.18238184 0.27858159 0.24081247 0.24223612 0.05334134 0.11993454
#  0.25962482 0.03641602 0.23537624 0.14143537 0.19621468 0.36301113
#  0.07373343 0.37747756 0.26808572 0.26850778 0.25747627 0.19034372
#  0.02199156 0.03837747 0.16215054 0.28407008 0.20081754 0.05785297
#  0.26707259 0.14537297 0.1048543  0.21718104 0.28321176 0.12616597
#  0.31429502 0.0863964  0.22745796 0.29568415 0.35099954 0.29810888
#  0.20629042 0.13901088 0.05940858 0.10766452 0.17473813 0.38014276
#  0.39700817 0.17087316 0.19603627 0.16858467 0.24490965 0.05639868
#  0.26852239 0.07893876 0.24100708 0.28263506 0.31951938 0.38431001
#  0.26592654 0.24531187 0.29454672 0.17417758 0.23602695 0.22370915
#  0.26280696 0.1543867  0.33688209 0.13802535 0.2324581  0.21384075
#  0.32596594 0.23165596 0.34775589 0.1425593  0.10759231 0.27399862]
# [[1.76391407 1.77304495 1.7848715  1.77938939 1.78129927 1.76980842
#   1.77524435 1.75907887 1.77375708 1.7745302  1.76926712 1.79177162
#   1.78721798 1.78094109 1.88356196 1.76914226 1.7772291  1.76108504
#   1.7722165  1.75878418 1.76976999 1.76887736 1.77399554 1.76549331
#   1.78808644 1.77207588 1.78528475 1.77355378 1.7500354  1.77137777
#   1.75345954 1.76596083 1.81794025 1.76172259 1.76714155 1.77776216
#   1.84133602 1.79961557 1.79040711 1.77337357 1.77285101 1.76600442
#   1.74862096 1.75324132 1.76868399 1.75619019 1.77383857 1.74421596
#   1.76685781 1.7788041  1.68889425 1.76130573 1.75325194 1.78268162
#   1.75035281 1.7741238  1.85280534 1.78029708 1.77180978 1.76533835
#   1.7162663  1.75608436 1.77917854 1.76001671 1.74394764 1.75558926
#   1.77838364 1.78734113 1.75061305 1.77093851 1.7628243  1.75981107
#   1.75929945 1.70822246 1.7956218  1.76581912 1.76846226 1.72687966
#   1.84166082 1.69852702 1.74311663 1.76398722 1.77343838 1.76645124]]
# {0: 559, 1: 45, 2: 22, 3: 59, 4: 219, 5: 250, 6: 4, 7: 10, 8: 119, 9: 57, 10: 9, 11: 139, 12: 15, 13: 242, 14: 1399, 15: 1, 16: 22, 17: 18, 18: 330, 21: 23, 22: 33, 23: 41, 24: 33, 25: 38, 26: 237, 27: 50, 28: 11, 29: 3, 30: 130, 31: 70, 32: 799, 33: 14, 34: 12, 35: 242, 36: 517, 37: 451, 38: 369, 40: 34, 41: 41}
# acc 0.5302234888255587
# acc 0.5302234888255587
# (0.3689297518671916, 0.39182625738738835, 0.318719889962973, None)
# next_element Tensor("IteratorGetNext_1:0", shape=(?, 2, 84), dtype=float64)
# thetas Tensor("Const:0", shape=(1, 84), dtype=float64)
# k Tensor("Const_1:0", shape=(84,), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f400>
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f400>
# <tf.Variable 'alphas:0' shape=(84,) dtype=float64_ref>
# Tensor("unstack:1", shape=(?, 84), dtype=float64)
# l Tensor("unstack:0", shape=(?, 84), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f400>
# out Tensor("map_1/while/Select:0", shape=(?, 84), dtype=float64)
# nls Tensor("mul:0", shape=(?, 84), dtype=float64)
# pout Tensor("map_1/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 84), dtype=float64)
# t_pout Tensor("map_2/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 1), dtype=float64)
# t Tensor("Squeeze:0", shape=(84,), dtype=float64)
# out Tensor("map_3/while/Select:0", shape=(84,), dtype=float64)
# zy Tensor("map_3/TensorArrayStack/TensorArrayGatherV3:0", shape=(42,), dtype=float64)
# logz Tensor("Log:0", shape=(), dtype=float64)
# lsp Tensor("ReduceLogSumExp/add:0", shape=(), dtype=float64)
# normloss Tensor("Neg:0", shape=(), dtype=float64)
# marginals Tensor("transpose_1:0", shape=(42, ?, 1), dtype=float64)
# predict Tensor("ArgMax:0", shape=(?, 1), dtype=int64)
# /home/vinay/snorkelEnv/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0 loss 8171012.24597436
# [0.31754463 0.01421453 0.20955965 0.20062431 0.30637787 0.24133855
#  0.369206   0.23120785 0.34633471 0.2647233  0.18357064 0.26661405
#  0.18238184 0.27858159 0.24081247 0.24223612 0.05334134 0.11993454
#  0.25962482 0.03641602 0.23537624 0.14143537 0.19621468 0.36301113
#  0.07373343 0.37747756 0.26808572 0.26850778 0.25747627 0.19034372
#  0.02199156 0.03837747 0.16215054 0.28407008 0.20081754 0.05785297
#  0.26707259 0.14537297 0.1048543  0.21718104 0.28321176 0.12616597
       1.7162663 , 1.75608436, 1.77917854, 1.76001671, 1.74394764,
       1.75558926, 1.77838364, 1.78734113, 1.75061305, 1.77093851,
       1.7628243 , 1.75981107, 1.75929945, 1.70822246, 1.7956218 ,
       1.76581912, 1.76846226, 1.72687966, 1.84166082, 1.69852702,
       1.74311663, 1.76398722, 1.77343838, 1.76645124]],dtype=np.float64))

#normalized thetas
getUNLObjValue(np.array([[1.03710943, 0.72891069, 0.91256307, 0.9065573 , 1.04359179, 0.99179506,
  1.07033153, 0.93697395, 1.09931246, 0.98664338, 0.88710382, 1.00020554,
  0.8844131 , 1.0257479 , 1.05320124, 0.94250273, 0.75971955, 0.82706024,
  1.02566678, 0.75808689, 0.93623337, 0.85304691, 0.91144645, 1.0890069,
  0.78471138, 1.08629106, 1.01363184, 0.98196969, 0.9578832 , 0.890922,
  0.75897035, 0.79083164, 0.94504572, 0.98910501, 0.90256731, 0.83399044,
  1.0526879 , 0.91296422, 0.87918072, 0.91735828, 0.99442894, 0.84282007,
  1.04270585, 0.80845978, 0.93485408, 1.01116604, 1.08801828, 1.05492529,
  0.9081924 , 0.84715166, 0.83377025, 0.83439804, 0.88535814, 1.1166286,
  1.10502333, 0.92236289, 1.01219273, 0.86888731, 0.95393976, 0.76423516,
  1.04786037, 0.80500049, 0.94208612, 0.99527191, 1.04370474, 1.11600129,
  0.9791124 , 0.95540789, 1.0464887 , 0.89115602, 0.93954564, 0.9246477,
  1.00317469, 0.91967407, 1.12446706, 0.84673924, 0.9362469 , 0.99849333,
  1.11282625, 1.02320935, 1.12996779, 0.84274034, 0.82023684, 0.99097614]],dtype=np.float64))
# Out:
# next_element Tensor("IteratorGetNext_1:0", shape=(?, 2, 84), dtype=float64)
# thetas Tensor("Const:0", shape=(1, 84), dtype=float64)
# k Tensor("Const_1:0", shape=(84,), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f8d0>
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f8d0>
# <tf.Variable 'alphas:0' shape=(84,) dtype=float64_ref>
# Tensor("unstack:1", shape=(?, 84), dtype=float64)
# l Tensor("unstack:0", shape=(?, 84), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f8f5f8d0>
# out Tensor("map_1/while/Select:0", shape=(?, 84), dtype=float64)
# nls Tensor("mul:0", shape=(?, 84), dtype=float64)
# pout Tensor("map_1/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 84), dtype=float64)
# t_pout Tensor("map_2/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 1), dtype=float64)
# t Tensor("Squeeze:0", shape=(84,), dtype=float64)
# out Tensor("map_3/while/Select:0", shape=(84,), dtype=float64)
# zy Tensor("map_3/TensorArrayStack/TensorArrayGatherV3:0", shape=(42,), dtype=float64)
# logz Tensor("Log:0", shape=(), dtype=float64)
# lsp Tensor("ReduceLogSumExp/add:0", shape=(), dtype=float64)
# normloss Tensor("Neg:0", shape=(), dtype=float64)
# k Tensor("Const_1:0", shape=(84,), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f95b6048>
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f95b6048>
# <tf.Variable 'alphas:0' shape=(84,) dtype=float64_ref>
# Tensor("unstack:1", shape=(?, 84), dtype=float64)
# l Tensor("unstack:0", shape=(?, 84), dtype=float64)
# <tensorflow.python.framework.ops.Graph object at 0x7fe3f95b6048>
# out Tensor("map_1/while/Select:0", shape=(?, 84), dtype=float64)
# nls Tensor("mul:0", shape=(?, 84), dtype=float64)
# pout Tensor("map_1/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 84), dtype=float64)
# t_pout Tensor("map_2/TensorArrayStack/TensorArrayGatherV3:0", shape=(42, ?, 1), dtype=float64)
# t Tensor("Squeeze:0", shape=(84,), dtype=float64)
# out Tensor("map_3/while/Select:0", shape=(84,), dtype=float64)
# zy Tensor("map_3/TensorArrayStack/TensorArrayGatherV3:0", shape=(42,), dtype=float64)
# logz Tensor("Log:0", shape=(), dtype=float64)
# lsp Tensor("ReduceLogSumExp/add:0", shape=(), dtype=float64)
# normloss Tensor("Neg:0", shape=(), dtype=float64)
# /home/vinay/snorkelEnv/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# marginals Tensor("transpose_1:0", shape=(42, ?, 1), dtype=float64)
# predict Tensor("ArgMax:0", shape=(?, 1), dtype=int64)
# 0 loss -146494.0264749541
# [0.31754463 0.01421453 0.20955965 0.20062431 0.30637787 0.24133855
#  0.369206   0.23120785 0.34633471 0.2647233  0.18357064 0.26661405
#  0.18238184 0.27858159 0.24081247 0.24223612 0.05334134 0.11993454
#  0.25962482 0.03641602 0.23537624 0.14143537 0.19621468 0.36301113
#  0.07373343 0.37747756 0.26808572 0.26850778 0.25747627 0.19034372
#  0.02199156 0.03837747 0.16215054 0.28407008 0.20081754 0.05785297
#  0.26707259 0.14537297 0.1048543  0.21718104 0.28321176 0.12616597
#  0.31429502 0.0863964  0.22745796 0.29568415 0.35099954 0.29810888
#  0.20629042 0.13901088 0.05940858 0.10766452 0.17473813 0.38014276
#  0.39700817 0.17087316 0.19603627 0.16858467 0.24490965 0.05639868
#  0.26852239 0.07893876 0.24100708 0.28263506 0.31951938 0.38431001
#  0.26592654 0.24531187 0.29454672 0.17417758 0.23602695 0.22370915
#  0.26280696 0.1543867  0.33688209 0.13802535 0.2324581  0.21384075
#  0.32596594 0.23165596 0.34775589 0.1425593  0.10759231 0.27399862]
# [[1.03710943 0.72891069 0.91256307 0.9065573  1.04359179 0.99179506
#   1.07033153 0.93697395 1.09931246 0.98664338 0.88710382 1.00020554
#   0.8844131  1.0257479  1.05320124 0.94250273 0.75971955 0.82706024
#   1.02566678 0.75808689 0.93623337 0.85304691 0.91144645 1.0890069
#   0.78471138 1.08629106 1.01363184 0.98196969 0.9578832  0.890922
#   0.75897035 0.79083164 0.94504572 0.98910501 0.90256731 0.83399044
#   1.0526879  0.91296422 0.87918072 0.91735828 0.99442894 0.84282007
#   1.04270585 0.80845978 0.93485408 1.01116604 1.08801828 1.05492529
#   0.9081924  0.84715166 0.83377025 0.83439804 0.88535814 1.1166286
#   1.10502333 0.92236289 1.01219273 0.86888731 0.95393976 0.76423516
#   1.04786037 0.80500049 0.94208612 0.99527191 1.04370474 1.11600129
#   0.9791124  0.95540789 1.0464887  0.89115602 0.93954564 0.9246477
#   1.00317469 0.91967407 1.12446706 0.84673924 0.9362469  0.99849333
#   1.11282625 1.02320935 1.12996779 0.84274034 0.82023684 0.99097614]]
# {0: 587, 1: 31, 2: 11, 3: 54, 4: 234, 5: 242, 7: 9, 8: 168, 9: 32, 10: 1, 11: 136, 12: 28, 13: 202, 14: 1238, 15: 1, 16: 15, 18: 531, 21: 8, 22: 46, 23: 134, 24: 26, 25: 23, 26: 250, 27: 23, 28: 2, 30: 98, 31: 58, 32: 726, 33: 7, 34: 1, 35: 250, 36: 530, 37: 538, 38: 389, 40: 5, 41: 33}
# acc 0.5003749812509375
# acc 0.5003749812509375
# (0.37501114579154465, 0.34497603212284494, 0.2827689761697568, None)

# %%
def drawLossVsAcc(y_loss,x_f1s,text,title):
    fig, ax = plt.subplots()
    ax.scatter(x_f1s, y_loss)

    plt.xlabel('accuracy')
    plt.ylabel('loss')
    plt.title(title)
    
    for i, txt in enumerate(text):
        ax.annotate(txt, (x_f1s[i],y_loss[i]))
        
    plt.savefig(title+".png")

# %%
#normalized
y_loss=[2228793.20,2261096.51,8171012.24]
x_f1s =[50.0,53.02,47.9]
text=["normalized-trained-thetas","snorkel-thetas","un-normalized-thetas"]
drawLossVsAcc(y_loss,x_f1s,text,"ICMC-Normalized-Loss")

# %%
# un-normalized
y_loss=[-3297257.67,-161207.29,-146494.02]
x_f1s =[47.9,53.02,50.03]
text=["un-normalized-trained-thetas","snorkel-thetas","normalized-thetas"]
drawLossVsAcc(y_loss,x_f1s,text,"ICMC-Un-Normalized-Loss")

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf

# %%
## Un normalized training with different params

def train_unl(lr,ep,th):
    
    BATCH_SIZE = 1
    tf.reset_default_graph()


    seed = 12
    with tf.Graph().as_default():

        train_dataset = tf.data.Dataset.from_tensor_slices(train_L_S).batch(BATCH_SIZE)
        dev_dataset = tf.data.Dataset.from_tensor_slices(test_L_S).batch(len(test_L_S))

     
        iterator = tf.data.Iterator.from_structure(train_dataset.output_types,
                                               train_dataset.output_shapes)
        next_element = iterator.get_next()

        train_init_op = iterator.make_initializer(train_dataset)
        dev_init_op = iterator.make_initializer(dev_dataset)

        next_element = iterator.get_next()
        print("next_element",next_element)

        alphas = tf.get_variable('alphas', [NoOfLFs],\
                                 initializer=tf.truncated_normal_initializer(0.2,0.1,seed),\
                                 dtype=tf.float64)

    #     thetas = tf.get_variable('thetas', [1,NoOfLFs],\
    #                              initializer=tf.truncated_normal_initializer(1,0.1,seed),\
    #                              dtype=tf.float64)

        thetas = tf.get_variable('thetas',[1,NoOfLFs],\
                                initializer=th,\
                        dtype=tf.float64)

        print("thetas",thetas)
        k = tf.convert_to_tensor(LF_l, dtype=tf.float64)
        print("k",k)
        print(alphas.graph)
        print(thetas.graph)
        l,s =  tf.unstack(next_element,axis=1)
        print(alphas)
        print(s)
        print("l",l)
        print(s.graph)

        s_ = tf.map_fn(lambda x : tf.maximum(tf.subtract(x,alphas), 0), s)


        def iskequalsy(v,s):
            out = tf.where(tf.equal(v,s),tf.ones_like(v),\
                           tf.zeros_like(v))
            print("out",out)
            return out

        ls_ = tf.multiply(l,s_)

        nls_ = tf.multiply(l,s_)*-1

        pout = tf.map_fn(lambda c: iskequalsy(l,c),np.arange(NoOfClasses,dtype=np.float64))
#         pout = tf.map_fn(lambda c: tf.equal(l,c),np.arange(NoOfClasses,dtype=np.float64))
       
        print("nls",nls_)


    #     lst = tf.matmul(ls_,thetas)
    #     print("lst",lst)
        t_pout = tf.map_fn(lambda x: tf.matmul(x,thetas,transpose_b=True),pout)
        print("pout",pout)

        print("t_pout",t_pout)

        t =  tf.squeeze(thetas)
        print("t",t)
        
        
        zy = tf.map_fn(lambda y: tf.reduce_prod(1+tf.exp(t*iskequalsy(k,y)),axis=0),np.arange(NoOfClasses,dtype=np.float64))

        logz = tf.log(tf.reduce_sum(zy,axis=0))
        print("zy",zy)
        print("logz",logz)

        lsp = tf.reduce_logsumexp(t_pout)
        print("lsp",lsp)

    #     normloss = tf.negative(tf.reduce_sum(tf.reduce_logsumexp(t_pout,axis=0)) - logz)  # add z

        normloss = tf.negative(tf.reduce_sum(tf.reduce_logsumexp(t_pout,axis=0)))


        print("normloss",normloss)
        marginals = tf.nn.softmax(t_pout,axis=0)

        print("marginals",marginals)
        predict = tf.argmax(marginals,axis=0)
        print("predict",predict)

    #     pre = tf.metrics.precision(labels,predict)
    #     rec = tf.metrics.recall(labels,predict)
    #     print("loss",loss)
    #     print("nls_",nls_)

    #     global_step = tf.Variable(0, trainable=False,dtype=tf.float64)
    #     starter_learning_rate = 1.0
    #     learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
    #                                            10, 0.96, staircase=True)
    #     train_step = tf.train.AdamOptimizer(learning_rate).minimize(normloss, global_step=global_step) 


    #     train_step = tf.train.AdamOptimizer(0.001).minimize(normloss)
    #     reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    #     reg_constant = 5.0  # Choose an appropriate one.
    #     totalloss = normloss + reg_constant * sum(reg_losses)
        train_step = tf.train.AdamOptimizer(lr).minimize(normloss) 
    #     train_step = tf.train.AdagradOptimizer(0.01).minimize(normloss) 
    #     train_step = tf.train.MomentumOptimizer(0.01,0.2).minimize(normloss) 

    #     train_step = tf.train.GradientDescentOptimizer(0.1).minimize(normloss)

        init_g = tf.global_variables_initializer()
        init_l = tf.local_variables_initializer()
        with tf.Session() as sess:
            sess.run(init_g)
            sess.run(init_l)

            # Initialize an iterator over the training dataset.
            for it in range(ep):
                sess.run(train_init_op)
                tl = 0
                try:
                    while True:
                        _,ls = sess.run([train_step,normloss])
                        tl = tl + ls
                except tf.errors.OutOfRangeError:
                    pass
                print(it,"loss",tl)

                sess.run(dev_init_op)
                a,t,m,pl = sess.run([alphas,thetas,marginals,predict])
                print(a)
                print(t)


#                 unique, counts = np.unique(pl, return_counts=True)
#                 print(dict(zip(unique, counts)))
                print("acc",accuracy_score(true_labels,pl))
                print(precision_recall_fscore_support(np.array(true_labels),np.array(pl),average="macro"))
                print()

            # Initialize an iterator over the validation dataset.
            sess.run(dev_init_op)
            a,t,m,pl = sess.run([alphas,thetas,marginals,predict])
            print(a)
            print(t)

      
            unique, counts = np.unique(pl, return_counts=True)
            print(dict(zip(unique, counts)))

            print("acc",accuracy_score(true_labels,pl))

            predictAndPrint(pl)
            print(precision_recall_fscore_support(np.array(true_labels),np.array(pl),average="macro"))
#             cf = confusion_matrix(true_labels,pl)
#             print(cf)
    return pl

# %%
## Un normalized training with different params

def getUNLObjValue(th):
    
    BATCH_SIZE = 1
    tf.reset_default_graph()


    seed = 12
    with tf.Graph().as_default():

        train_dataset = tf.data.Dataset.from_tensor_slices(train_L_S).batch(BATCH_SIZE)
        dev_dataset = tf.data.Dataset.from_tensor_slices(test_L_S).batch(len(test_L_S))

     
        iterator = tf.data.Iterator.from_structure(train_dataset.output_types,
                                               train_dataset.output_shapes)
        next_element = iterator.get_next()

        train_init_op = iterator.make_initializer(train_dataset)
        dev_init_op = iterator.make_initializer(dev_dataset)

        next_element = iterator.get_next()
        print("next_element",next_element)

        alphas = tf.get_variable('alphas', [NoOfLFs],\
                                 initializer=tf.truncated_normal_initializer(0.2,0.1,seed),\
                                 dtype=tf.float64)

    #     thetas = tf.get_variable('thetas', [1,NoOfLFs],\
    #                              initializer=tf.truncated_normal_initializer(1,0.1,seed),\
    #                              dtype=tf.float64)

        thetas = tf.convert_to_tensor(th)

        print("thetas",thetas)
        k = tf.convert_to_tensor(LF_l, dtype=tf.float64)
        print("k",k)
        print(alphas.graph)
        print(thetas.graph)
        l,s =  tf.unstack(next_element,axis=1)
        print(alphas)
        print(s)
        print("l",l)
        print(s.graph)

        s_ = tf.map_fn(lambda x : tf.maximum(tf.subtract(x,alphas), 0), s)


        def iskequalsy(v,s):
            out = tf.where(tf.equal(v,s),tf.ones_like(v),\
                           tf.zeros_like(v))
            print("out",out)
            return out

        ls_ = tf.multiply(l,s_)

        nls_ = tf.multiply(l,s_)*-1

        pout = tf.map_fn(lambda c: iskequalsy(l,c),np.arange(NoOfClasses,dtype=np.float64))
#         pout = tf.map_fn(lambda c: tf.equal(l,c),np.arange(NoOfClasses,dtype=np.float64))
       
        print("nls",nls_)


    #     lst = tf.matmul(ls_,thetas)
    #     print("lst",lst)
        t_pout = tf.map_fn(lambda x: tf.matmul(x,thetas,transpose_b=True),pout)
        print("pout",pout)

        print("t_pout",t_pout)

        t =  tf.squeeze(thetas)
        print("t",t)
        
        
        zy = tf.map_fn(lambda y: tf.reduce_prod(1+tf.exp(t*iskequalsy(k,y)),axis=0),np.arange(NoOfClasses,dtype=np.float64))

        logz = tf.log(tf.reduce_sum(zy,axis=0))
        print("zy",zy)
        print("logz",logz)

        lsp = tf.reduce_logsumexp(t_pout)
        print("lsp",lsp)

    #     normloss = tf.negative(tf.reduce_sum(tf.reduce_logsumexp(t_pout,axis=0)) - logz)  # add z

        normloss = tf.negative(tf.reduce_sum(tf.reduce_logsumexp(t_pout,axis=0)))


        print("normloss",normloss)
        marginals = tf.nn.softmax(t_pout,axis=0)

        print("marginals",marginals)
        predict = tf.argmax(marginals,axis=0)
        print("predict",predict)

    #     pre = tf.metrics.precision(labels,predict)
    #     rec = tf.metrics.recall(labels,predict)
    #     print("loss",loss)
    #     print("nls_",nls_)

    #     global_step = tf.Variable(0, trainable=False,dtype=tf.float64)
    #     starter_learning_rate = 1.0
    #     learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
    #                                            10, 0.96, staircase=True)
    #     train_step = tf.train.AdamOptimizer(learning_rate).minimize(normloss, global_step=global_step) 


    #     train_step = tf.train.AdamOptimizer(0.001).minimize(normloss)
    #     reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    #     reg_constant = 5.0  # Choose an appropriate one.
    #     totalloss = normloss + reg_constant * sum(reg_losses)
#         train_step = tf.train.AdamOptimizer(lr).minimize(normloss) 
    #     train_step = tf.train.AdagradOptimizer(0.01).minimize(normloss) 
    #     train_step = tf.train.MomentumOptimizer(0.01,0.2).minimize(normloss) 

    #     train_step = tf.train.GradientDescentOptimizer(0.1).minimize(normloss)

        init_g = tf.global_variables_initializer()
        init_l = tf.local_variables_initializer()
        with tf.Session() as sess:
            sess.run(init_g)
            sess.run(init_l)

            # Initialize an iterator over the training dataset.
            for it in range(1):
                sess.run(train_init_op)
                tl = 0
                try:
                    while True:
                        ls = sess.run(normloss)
                        tl = tl + ls
                except tf.errors.OutOfRangeError:
                    pass
                print(it,"loss",tl)

#                 sess.run(dev_init_op)
#                 a,t,m,pl = sess.run([alphas,thetas,marginals,predict])
#                 print(a)
#                 print(t)


#                 unique, counts = np.unique(pl, return_counts=True)
#                 print(dict(zip(unique, counts)))
#                 print("acc",accuracy_score(true_labels,pl))
#                 print(precision_recall_fscore_support(np.array(true_labels),np.array(pl),average="macro"))
#                 print()

            # Initialize an iterator over the validation dataset.
            sess.run(dev_init_op)
            a,t,m,pl = sess.run([alphas,thetas,marginals,predict])
            print(a)
            print(t)

      
            unique, counts = np.unique(pl, return_counts=True)
            print(dict(zip(unique, counts)))

            print("acc",accuracy_score(true_labels,pl))

            predictAndPrint(pl)
            print(precision_recall_fscore_support(np.array(true_labels),np.array(pl),average="macro"))
#             cf = confusion_matrix(true_labels,pl)
#             print(cf)

# %%
## Un normalized training with different params

def getNLObjValue(th):
    
    BATCH_SIZE = 1
    tf.reset_default_graph()


    seed = 12
    with tf.Graph().as_default():

        train_dataset = tf.data.Dataset.from_tensor_slices(train_L_S).batch(BATCH_SIZE)
        dev_dataset = tf.data.Dataset.from_tensor_slices(test_L_S).batch(len(test_L_S))

     
        iterator = tf.data.Iterator.from_structure(train_dataset.output_types,
                                               train_dataset.output_shapes)
        next_element = iterator.get_next()

        train_init_op = iterator.make_initializer(train_dataset)
        dev_init_op = iterator.make_initializer(dev_dataset)

        next_element = iterator.get_next()
        print("next_element",next_element)

        alphas = tf.get_variable('alphas', [NoOfLFs],\
                                 initializer=tf.truncated_normal_initializer(0.2,0.1,seed),\
                                 dtype=tf.float64)

    #     thetas = tf.get_variable('thetas', [1,NoOfLFs],\
    #                              initializer=tf.truncated_normal_initializer(1,0.1,seed),\
    #                              dtype=tf.float64)

        thetas = tf.convert_to_tensor(th)

        print("thetas",thetas)
        k = tf.convert_to_tensor(LF_l, dtype=tf.float64)
        print("k",k)
        print(alphas.graph)
        print(thetas.graph)
        l,s =  tf.unstack(next_element,axis=1)
        print(alphas)
        print(s)
        print("l",l)
        print(s.graph)

        s_ = tf.map_fn(lambda x : tf.maximum(tf.subtract(x,alphas), 0), s)


        def iskequalsy(v,s):
            out = tf.where(tf.equal(v,s),tf.ones_like(v),\
                           tf.zeros_like(v))
            print("out",out)
            return out

        ls_ = tf.multiply(l,s_)

        nls_ = tf.multiply(l,s_)*-1

        pout = tf.map_fn(lambda c: iskequalsy(l,c),np.arange(NoOfClasses,dtype=np.float64))
#         pout = tf.map_fn(lambda c: tf.equal(l,c),np.arange(NoOfClasses,dtype=np.float64))
       
        print("nls",nls_)


    #     lst = tf.matmul(ls_,thetas)
    #     print("lst",lst)
        t_pout = tf.map_fn(lambda x: tf.matmul(x,thetas,transpose_b=True),pout)
        print("pout",pout)

        print("t_pout",t_pout)

        t =  tf.squeeze(thetas)
        print("t",t)
        
        
        zy = tf.map_fn(lambda y: tf.reduce_prod(1+tf.exp(t*iskequalsy(k,y)),axis=0),np.arange(NoOfClasses,dtype=np.float64))

        logz = tf.log(tf.reduce_sum(zy,axis=0))
        print("zy",zy)
        print("logz",logz)

        lsp = tf.reduce_logsumexp(t_pout)
        print("lsp",lsp)

    #     normloss = tf.negative(tf.reduce_sum(tf.reduce_logsumexp(t_pout,axis=0)) - logz)  # add z

        normloss = tf.negative(tf.reduce_sum(tf.reduce_logsumexp(t_pout,axis=0) -logz ))


        print("normloss",normloss)
        marginals = tf.nn.softmax(t_pout,axis=0)

        print("marginals",marginals)
        predict = tf.argmax(marginals,axis=0)
        print("predict",predict)

    #     pre = tf.metrics.precision(labels,predict)
    #     rec = tf.metrics.recall(labels,predict)
    #     print("loss",loss)
    #     print("nls_",nls_)

    #     global_step = tf.Variable(0, trainable=False,dtype=tf.float64)
    #     starter_learning_rate = 1.0
    #     learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
    #                                            10, 0.96, staircase=True)
    #     train_step = tf.train.AdamOptimizer(learning_rate).minimize(normloss, global_step=global_step) 


    #     train_step = tf.train.AdamOptimizer(0.001).minimize(normloss)
    #     reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    #     reg_constant = 5.0  # Choose an appropriate one.
    #     totalloss = normloss + reg_constant * sum(reg_losses)
#         train_step = tf.train.AdamOptimizer(lr).minimize(normloss) 
    #     train_step = tf.train.AdagradOptimizer(0.01).minimize(normloss) 
    #     train_step = tf.train.MomentumOptimizer(0.01,0.2).minimize(normloss) 

    #     train_step = tf.train.GradientDescentOptimizer(0.1).minimize(normloss)

        init_g = tf.global_variables_initializer()
        init_l = tf.local_variables_initializer()
        with tf.Session() as sess:
            sess.run(init_g)
            sess.run(init_l)

            # Initialize an iterator over the training dataset.
            for it in range(1):
                sess.run(train_init_op)
                tl = 0
                try:
                    while True:
                        ls = sess.run(normloss)
                        tl = tl + ls
                except tf.errors.OutOfRangeError:
                    pass
                print(it,"loss",tl)

#                 sess.run(dev_init_op)
#                 a,t,m,pl = sess.run([alphas,thetas,marginals,predict])
#                 print(a)
#                 print(t)


#                 unique, counts = np.unique(pl, return_counts=True)
#                 print(dict(zip(unique, counts)))
#                 print("acc",accuracy_score(true_labels,pl))
#                 print(precision_recall_fscore_support(np.array(true_labels),np.array(pl),average="macro"))
#                 print()

            # Initialize an iterator over the validation dataset.
            sess.run(dev_init_op)
            a,t,m,pl = sess.run([alphas,thetas,marginals,predict])
            print(a)
            print(t)

      
            unique, counts = np.unique(pl, return_counts=True)
            print(dict(zip(unique, counts)))

            print("acc",accuracy_score(true_labels,pl))

            predictAndPrint(pl)
            print(precision_recall_fscore_support(np.array(true_labels),np.array(pl),average="macro"))
#             cf = confusion_matrix(true_labels,pl)
#             print(cf)

# %%
## Un normalized training with different params

def train_nl(lr,ep,th):
    
    BATCH_SIZE = 1
    tf.reset_default_graph()


    seed = 12
    with tf.Graph().as_default():

        train_dataset = tf.data.Dataset.from_tensor_slices(train_L_S).batch(BATCH_SIZE)
        dev_dataset = tf.data.Dataset.from_tensor_slices(test_L_S).batch(len(test_L_S))

     
        iterator = tf.data.Iterator.from_structure(train_dataset.output_types,
                                               train_dataset.output_shapes)
        next_element = iterator.get_next()

        train_init_op = iterator.make_initializer(train_dataset)
        dev_init_op = iterator.make_initializer(dev_dataset)

        next_element = iterator.get_next()
        print("next_element",next_element)

        alphas = tf.get_variable('alphas', [NoOfLFs],\
                                 initializer=tf.truncated_normal_initializer(0.2,0.1,seed),\
                                 dtype=tf.float64)

    #     thetas = tf.get_variable('thetas', [1,NoOfLFs],\
    #                              initializer=tf.truncated_normal_initializer(1,0.1,seed),\
    #                              dtype=tf.float64)

        thetas = tf.get_variable('thetas',[1,NoOfLFs],\
                                initializer=th,\
                        dtype=tf.float64)

        print("thetas",thetas)
        k = tf.convert_to_tensor(LF_l, dtype=tf.float64)
        print("k",k)
        print(alphas.graph)
        print(thetas.graph)
        l,s =  tf.unstack(next_element,axis=1)
        print(alphas)
        print(s)
        print("l",l)
        print(s.graph)

        s_ = tf.map_fn(lambda x : tf.maximum(tf.subtract(x,alphas), 0), s)


        def iskequalsy(v,s):
            out = tf.where(tf.equal(v,s),tf.ones_like(v),\
                           tf.zeros_like(v))
            print("out",out)
            return out

        ls_ = tf.multiply(l,s_)

        nls_ = tf.multiply(l,s_)*-1

        pout = tf.map_fn(lambda c: iskequalsy(l,c),np.arange(NoOfClasses,dtype=np.float64))
       
        print("nls",nls_)


    #     lst = tf.matmul(ls_,thetas)
    #     print("lst",lst)
        t_pout = tf.map_fn(lambda x: tf.matmul(x,thetas,transpose_b=True),pout)
        print("pout",pout)

        print("t_pout",t_pout)

        t =  tf.squeeze(thetas)
        print("t",t)
        
        
        zy = tf.map_fn(lambda y: tf.reduce_prod(1+tf.exp(t*iskequalsy(k,y)),axis=0),np.arange(NoOfClasses,dtype=np.float64))

        logz = tf.log(tf.reduce_sum(zy,axis=0))
        print("zy",zy)
        print("logz",logz)

        lsp = tf.reduce_logsumexp(t_pout)
        print("lsp",lsp)

    #     normloss = tf.negative(tf.reduce_sum(tf.reduce_logsumexp(t_pout,axis=0)) - logz)  # add z

        normloss = tf.negative(tf.reduce_sum(tf.reduce_logsumexp(t_pout,axis=0) - logz ))


        print("normloss",normloss)
        marginals = tf.nn.softmax(t_pout,axis=0)

        print("marginals",marginals)
        predict = tf.argmax(marginals,axis=0)
        print("predict",predict)

    #     pre = tf.metrics.precision(labels,predict)
    #     rec = tf.metrics.recall(labels,predict)
    #     print("loss",loss)
    #     print("nls_",nls_)

    #     global_step = tf.Variable(0, trainable=False,dtype=tf.float64)
    #     starter_learning_rate = 1.0
    #     learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
    #                                            10, 0.96, staircase=True)
    #     train_step = tf.train.AdamOptimizer(learning_rate).minimize(normloss, global_step=global_step) 


    #     train_step = tf.train.AdamOptimizer(0.001).minimize(normloss)
    #     reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    #     reg_constant = 5.0  # Choose an appropriate one.
    #     totalloss = normloss + reg_constant * sum(reg_losses)
        train_step = tf.train.AdamOptimizer(lr).minimize(normloss) 
    #     train_step = tf.train.AdagradOptimizer(0.01).minimize(normloss) 
    #     train_step = tf.train.MomentumOptimizer(0.01,0.2).minimize(normloss) 

    #     train_step = tf.train.GradientDescentOptimizer(0.1).minimize(normloss)

        init_g = tf.global_variables_initializer()
        init_l = tf.local_variables_initializer()
        with tf.Session() as sess:
            sess.run(init_g)
            sess.run(init_l)

            # Initialize an iterator over the training dataset.
            for it in range(ep):
                sess.run(train_init_op)
                tl = 0
                try:
                    while True:
                        _,ls = sess.run([train_step,normloss])
                        tl = tl + ls
                except tf.errors.OutOfRangeError:
                    pass
                print(it,"loss",tl)

                sess.run(dev_init_op)
                a,t,m,pl = sess.run([alphas,thetas,marginals,predict])
                print(a)
                print(t)

#                 unique, counts = np.unique(pl, return_counts=True)
#                 print(dict(zip(unique, counts)))
                print("acc",accuracy_score(true_labels,pl))
                print(precision_recall_fscore_support(np.array(true_labels),np.array(pl),average="macro"))
                print()

            # Initialize an iterator over the validation dataset.
            sess.run(dev_init_op)
            a,t,m,pl = sess.run([alphas,thetas,marginals,predict])
            print(a)
            print(t)

            unique, counts = np.unique(pl, return_counts=True)
            print(dict(zip(unique, counts)))

            print("acc",accuracy_score(true_labels,pl))

            predictAndPrint(pl)
            print(precision_recall_fscore_support(np.array(true_labels),np.array(pl),average="macro"))
#             cf = confusion_matrix(true_labels,pl)
#             print(cf)
    return pl
