# %%
import pandas as pd
import numpy as np

import _pickle as pkl

# train_df=pd.read_csv('./complaints_train_data_clean.csv',usecols=["category_name","complaint_title","complaint_description",],na_filter=False)

from gensim.parsing.preprocessing import STOPWORDS
def remove_stopwords(tokens):
    # input and outputs a list of words
    return [word for word in tokens if word not in STOPWORDS]

train_df=pd.read_csv('./complaints_train_validation_data_clean.csv',usecols=["index","category_name","complaint_title","complaint_description",],na_filter=False)

whitelist = set('abcdefghijklmnopqrstuvwxyz ABCDEFGHIJKLMNOPQRSTUVWXYZ')

sentences = (train_df['complaint_title']+" "+train_df['complaint_description']).tolist()
sentences = [''.join(filter(whitelist.__contains__, x)).lower() for x in sentences]
sentences = [x.split() for x in sentences]
sentences = list(map(remove_stopwords, sentences))
train_df.insert(1,"complaint_text",sentences)


val_df=pd.read_csv('./complaints_validation_data_clean.csv',usecols=["category_name","complaint_title","complaint_description",],na_filter=False)

test_df=pd.read_csv('./complaints_test_data_clean.csv',usecols=["category_name","complaint_title","complaint_description",],na_filter=False)

## gold labels
gold_df=pd.read_csv('./clean-gold-labels.tsv',sep='\t',usecols=["category_name","complaint_description",],na_filter=False)
gold_df['complaint_title'] = gold_df['complaint_description']
sentences = (gold_df['complaint_description']).tolist()
sentences = [''.join(filter(whitelist.__contains__, x)).lower() for x in sentences]
sentences = [x.split() for x in sentences]
sentences = list(map(remove_stopwords, sentences))
gold_df.insert(1,"complaint_text",sentences)
######

sentences = (test_df['complaint_title']+" "+test_df['complaint_description']).tolist()
sentences = [''.join(filter(whitelist.__contains__, x)).lower() for x in sentences]
sentences = [x.split() for x in sentences]
sentences = list(map(remove_stopwords, sentences))
test_df.insert(1,"complaint_text",sentences)

gold_df.head()
# Out:
#                              category_name  \
# 0                                  Garbage
# 1                         New Bus Shelters
# 2                              Electricity
# 3                                Bad Roads
# 4  Land and Property Encroachment - Others
#
#                                       complaint_text  \
# 0  [garbage, collector, coming, collect, househol...
# 1  [provide, bus, shelters, minimal, request, com...
# 2  [days, complete, power, cut, annasandra, palya...
# 3  [roads, dug, lay, drainage, pipes, laying, pip...
# 4  [place, sites, connects, roads, sites, illegal...
#
#                                complaint_description  \
# 0  Garbage collector is not coming to collect hou...
# 1  Please provide bus shelters. Its the most mini...
# 2  2 days complete power cut in Annasandra Palya ...
# 3  The roads were dug to lay the drainage pipes a...
# 4  Next to my place there are 2 sites which conne...
#
#                                      complaint_title
# 0  Garbage collector is not coming to collect hou...
# 1  Please provide bus shelters. Its the most mini...
# 2  2 days complete power cut in Annasandra Palya ...
# 3  The roads were dug to lay the drainage pipes a...
# 4  Next to my place there are 2 sites which conne...

# %%
colsize = len(train_df['category_name'])
train_df['category_name'] = train_df["category_name"].astype('category')
#train_df['true_label'] = pd.Series(np.zeros(colsize), index=train_df.index)
train_df['predicted_label'] = pd.Series(np.zeros(colsize), index=train_df.index)

# train_df['true_label'] = train_df['category_name'].cat.codes
# for i in range(colsize):
#     if(train_df['true_label'][i]==5):
#         print(train_df['true_label'][i],train_df['category_name'][i])

# %%
train_df.groupby("category_name").agg({"complaint_title": np.count_nonzero})
# Out:
#                                                     complaint_title
# category_name
# Air Pollution                                                   187
# Autorickshaws and Taxis                                         110
# BMTC - Driver or Conductor                                      167
# BMTC - Need new Bus Route                                       315
# BMTC - Others                                                   826
# Bad Roads                                                      5410
# Broken Storm Water Drains                                       137
# Cattle                                                           61
# Clearing of Blockage of Under Ground Drainage P...              427
# Desilting - Lakes                                                94
# Diseases                                                        211
# Electricity                                                    1120
# Flooding of Roads and Footpaths                                 278
# Footpaths                                                      1111
# Garbage                                                        7492
# Government Land Encroachment                                     83
# Hawkers and Vendors                                             169
# Hoardings                                                       201
# Illegal posters and Hoardings                                    73
# Lakes - Others                                                   80
# Maintenance of Roads and Footpaths - Others                     210
# Manholes                                                         88
# Mosquitos                                                       129
# Need New Streetlights                                           184
# Need New Toilets                                                125
# New Bus Shelters                                                608
# No Sewage Drains                                                471
# Noise Pollution                                                 249
# Others                                                          655
# Overflow of Storm Water Drains                                  239
# Parking Violations                                              400
# Parks and playgrounds                                           211
# Potholes                                                       5347
# Public Nuisance                                                 224
# Repair of streetlights                                         1342
# Sewage and Storm Water Drains - Others                          231
# Stray Dogs                                                     3159
# Traffic                                                        3973
# Trees, Parks and Playgrounds - Others                            95
# Unauthorized Construction                                        87
# Water Leakage                                                   245
# Water Supply                                                    771

# %%
for i,x in enumerate(train_df.groupby("category_name").agg({"complaint_title": np.count_nonzero}).index._data):
    print(i,x)
# Out:
# 0 Air Pollution
# 1 Autorickshaws and Taxis
# 2 BMTC - Driver or Conductor
# 3 BMTC - Need new Bus Route
# 4 BMTC - Others
# 5 Bad Roads
# 6 Broken Storm Water Drains
# 7 Cattle
# 8 Clearing of Blockage of Under Ground Drainage Pipelines and Replacement of Damaged or Missing Manhole Cover
# 9 Desilting - Lakes
# 10 Diseases
# 11 Electricity
# 12 Flooding of Roads and Footpaths
# 13 Footpaths
# 14 Garbage
# 15 Government Land Encroachment
# 16 Hawkers and Vendors
# 17 Hoardings
# 18 Illegal posters and Hoardings
# 19 Lakes - Others
# 20 Maintenance of Roads and Footpaths - Others
# 21 Manholes
# 22 Mosquitos
# 23 Need New Streetlights
# 24 Need New Toilets
# 25 New Bus Shelters
# 26 No Sewage Drains
# 27 Noise Pollution
# 28 Others
# 29 Overflow of Storm Water Drains
# 30 Parking Violations
# 31 Parks and playgrounds
# 32 Potholes
# 33 Public Nuisance
# 34 Repair of streetlights
# 35 Sewage and Storm Water Drains - Others
# 36 Stray Dogs
# 37 Traffic
# 38 Trees, Parks and Playgrounds - Others
# 39 Unauthorized Construction
# 40 Water Leakage
# 41 Water Supply

# %%
class_names = train_df.groupby("category_name").agg({"complaint_title": np.count_nonzero}).index.tolist()

pkl.dump(class_names,open("class_names.p","wb"))

noOfClasses = len(train_df.groupby("category_name").agg({"complaint_title": np.count_nonzero}).index)

print(class_names)
# Out:
# ['Air Pollution', 'Autorickshaws and Taxis', 'BMTC - Driver or Conductor', 'BMTC - Need new Bus Route', 'BMTC - Others', 'Bad Roads', 'Broken Storm Water Drains', 'Cattle', 'Clearing of Blockage of Under Ground Drainage Pipelines and Replacement of Damaged or Missing Manhole Cover', 'Desilting - Lakes', 'Diseases', 'Electricity', 'Flooding of Roads and Footpaths', 'Footpaths', 'Garbage', 'Government Land Encroachment', 'Hawkers and Vendors', 'Hoardings', 'Illegal posters and Hoardings', 'Lakes - Others', 'Maintenance of Roads and Footpaths - Others', 'Manholes', 'Mosquitos', 'Need New Streetlights', 'Need New Toilets ', 'New Bus Shelters', 'No Sewage Drains', 'Noise Pollution', 'Others', 'Overflow of Storm Water Drains', 'Parking Violations', 'Parks and playgrounds', 'Potholes', 'Public Nuisance', 'Repair of streetlights', 'Sewage and Storm Water Drains - Others', 'Stray Dogs', 'Traffic', 'Trees, Parks and Playgrounds - Others', 'Unauthorized Construction', 'Water Leakage', 'Water Supply ']

# %%
train_df.iloc[3]['complaint_title']+" "+train_df.iloc[3]['complaint_description']
# Out:
# 'Road Condition of Ejipura after the sewage pipe line work Dear All,\\n\\nI am writing this email to you as a resident of Ejipura location in distress for more than 3 weeks.\\nI know for the fact that BBMP / BWSSB has taken initiative to lay new drainage pipe lines for most locations in Ejipura. However it looks like there is no progress at all.\\n\\nThe pipelines are layed, however the work is half done. No one really bothers how the residents manage the rest of the day and even in case of any emergency, we cannot take our car or ambulances inside. We have many senior citizens and children\\\'s living here and they have horrible time trying to cross these broken road & potholes. It\\\'s only matter of time when something bad happens & we are in the \\"TV News\\"!!\\n\\nI am sharing some of the pictures taken at Ejipura, Sri Rama Temple Road - 20th C Cross (beside ICICI ATM), the work is as it is and no one is really bothered to fix the problem. I have raised a complaint in both BWSSB and BBMP grievances site, there has been no response or calls whatsoever.\\n\\nMy humble request is to please have this road fixed as quickly as possible. We have been trying to manage our lives with this road conditions allover Bangalore, but this is worst. Our vechicals and cars are getting damaged and even sometimes stuck in muddy poth holes.'

# %%
keywords = {'Air Pollution':['dust|smoke|burn'],
 'Autorickshaws and Taxis':['taxi','auto','autorickshaw'],
 'BMTC - Driver or Conductor':['rude','behaviour'],
 'BMTC - Need new Bus Route':['frequency'],
 'BMTC - Others':[],
 'Bad Roads':['road'],
 'Broken Storm Water Drains':['overflow','drainage'],
 'Cattle':['cows','buffaloes','goats','cow'],
 'Clearing of Blockage of Under Ground Drainage Pipelines and Replacement of Damaged or Missing Manhole Cover':[],
 'Desilting - Lakes':['lake'],
 'Diseases':['malaria','dengue','cholera','fever','disease','hospital','epidemic'],
 'Electricity':['power','current','power cut'],
 'Flooding of Roads and Footpaths':['water','flood','floods'],
 'Footpaths':['footpath'],
 'Garbage':['waste','plastic','dirt'],
 'Government Land Encroachment':['occupy','illegal'],
 'Hawkers and Vendors':[],
 'Hoardings':['advertise'],
 'Illegal posters and Hoardings':['banner', 'ads ','advertise'],
 'Lakes - Others':['lake'],
 'Maintenance of Roads and Footpaths - Others':[],
 'Manholes':['manhole','man hole'],
 'Mosquitos':['mosquito','mosquitoe','mosquitoes','dengue','malaria'],
 'Need New Streetlights':['streetlight','light','new streetlight'],
 'Need New Toilets ':['toilet','urinal','urinate'],
 'New Bus Shelters':['shelter'],
 'No Sewage Drains':['drainage'],
 'Noise Pollution':['siren','speakers','speakers','loud'],
 'Others':[],
 'Overflow of Storm Water Drains':['pipes'],
 'Parking Violations':['parked','parker'],
 'Parks and playgrounds':['park','play','playground'],
 'Potholes':['holes','pothole'],
 'Public Nuisance':[],
 'Repair of streetlights':['streetlight','light','broken','damaged'],
 'Sewage and Storm Water Drains - Others':['drainage'],
 'Stray Dogs':['dog'],
 'Traffic':['vehicles'],
 'Trees, Parks and Playgrounds - Others':['tree'],
 'Unauthorized Construction':['encroach','building','built'],
 'Water Leakage':[],
 'Water Supply ':[]}

# %%
regexPatterns = {'Air Pollution':['air.*pollution|pollution|dust'],
 'Autorickshaws and Taxis':['autorickshaws|taxis|taxi|auto|autorickshaw'],
 'BMTC - Driver or Conductor':['bmtc.*driver|bmtc.*conductor|bus.*driver|bus.*conductor'],
 'BMTC - Need new Bus Route':['bus.*route'],
 'BMTC - Others':['bmtc'],
 'Bad Roads':['bad.*road|road.*bad'],
 'Broken Storm Water Drains':['(broken|damage).*(drain)'],
 'Cattle':['(cattle|cows|buffaloes|goats)'],
 'Clearing of Blockage of Under Ground Drainage Pipelines and Replacement of Damaged or Missing Manhole Cover':['clearing|blockage|under|ground|drainage|pipelines|replacement|damaged|missing|manhole|cover'],
 'Desilting - Lakes':['lake'],
 'Diseases':['diseases|malaria|dengue|cholera'],
 'Electricity':['electricity|power|current|power.*cut'],
 'Flooding of Roads and Footpaths':['((water|flood|flow).*(roads|footpaths))|((roads|footpaths).*(water|flood|flow))'],
 'Footpaths':['footpath'],
 'Garbage':['garbage|waste|plastic|dirt'],
 'Government Land Encroachment':['(government.*land).*(encroach|occupy|illegal)'],
 'Hawkers and Vendors':['(hawkers|vendors)'],
 'Hoardings':['(hoardings|advertisements)'],
 'Illegal posters and Hoardings':['posters|hoardings|banner|ads|advertise'],
 'Lakes - Others':['lake'],
 'Maintenance of Roads and Footpaths - Others':['(maintenance).*(roads|footpaths)'],
 'Manholes':['(manholes|manhole|man hole)'],
 'Mosquitos':['mosquito|mosquitoe|mosquitoes|dengue|malaria'],
 'Need New Streetlights':['(need|no|new).*(streetlight|light)'],
 'Need New Toilets ':['toilets|toilet|urinal|urinate'],
 'New Bus Shelters':['bus.*shelter|shelter.*bus'],
 'No Sewage Drains':['drain'],
 'Noise Pollution':['noise|noise.*pollution|siren|speakers|speakers|loud'],
 'Others':['others'],
 'Overflow of Storm Water Drains':['overflow.*(drains|pipes)'],
 'Parking Violations':['parking|parked|parker'],
 'Parks and playgrounds':['(parks|playgrounds|park|play|playground)'],
 'Potholes':['(pot hole|holes|pothole)'],
 'Public Nuisance':['(public.*nuisance|nuisance)'],
 'Repair of streetlights':['((light).*(repair|broke|damage))|((repair|broke|damage).*(light))'],
 'Sewage and Storm Water Drains - Others':['(sewage|storm|water|drains|drainage)'],
 'Stray Dogs':['(stray|dogs|dog)'],
 'Traffic':['(traffic|vehicles)'],
 'Trees, Parks and Playgrounds - Others':['(trees|parks|playgrounds|tree)'],
 'Unauthorized Construction':['encroach','building','built'],
 'Water Leakage':['water.*leak|leak.*water'],
 'Water Supply ':['water.*supply|supply.*water']}

# %%
extracts_df=pd.read_csv('./p.tsv',sep='\t',usecols=["category_name","Entity","complaint words",],na_filter=False)

extracts_df = extracts_df[extracts_df['category_name'].isin(class_names)]
# extracts_df
def combine(x):
    x = x.tolist()
    x = set(x)
    x = '|'.join(list(x)).lower()
    return x
extracts_df = extracts_df.groupby("category_name").agg({"Entity": combine,"complaint words":combine })
extracts_df.to_csv("extracts.csv")
extracts_df
# Out:
#                                                                                                Entity  \
# category_name
# Air Pollution                                                                             bus|garbage
# BMTC - Driver or Conductor                                                                       gbus
# BMTC - Need new Bus Route                                                                         bus
# BMTC - Others                                                                             bus|traffic
# Bad Roads                                                  roads|footpath|permit|pothole|roads|sewage
# Broken Storm Water Drains                                                                       drain
# Clearing of Blockage of Under Ground Drainage P...                                        tank|sewage
# Desilting - Lakes                                                                                lake
# Diseases                                                                                  garbage|cat
# Electricity                                          transformer|electricity|street light|electricity
# Flooding of Roads and Footpaths                                    water|roads|footpath|pothole|roads
# Footpaths                                                                      garbage|footpath|drain
# Garbage                                             clan|garbage|pothole|dump|roads|garbage|dustbi...
# Hawkers and Vendors                                                                          footpath
# Illegal posters and Hoardings                                                           trees|parking
# Lakes - Others                                                                                   lake
# Maintenance of Roads and Footpaths - Others                                                     roads
# Manholes                                                                                      manhole
# Mosquitos                                                                                  mosquitoes
# Need New Streetlights                                                             street light|lightd
# New Bus Shelters                                                                              bus|bus
# No Sewage Drains                                                           drain|garbage|roads|sewage
# Noise Pollution                                                                                   dog
# Others                                                      traffic|bus|footpath|drain|center|bribery
# Overflow of Storm Water Drains                                                           drain|sewage
# Parking Violations                                                             parking|footpath|roads
# Parks and playgrounds                                                                      trees|park
# Potholes                                                      roads|water|pothole|land|potholes|drain
# Public Nuisance                                                                      public|house|bar
# Repair of streetlights                                                                   street light
# Sewage and Storm Water Drains - Others                                                        manhole
# Stray Dogs                                                     dog|dog|dogs,light|stray dogs|hoarding
# Traffic                                             traffic|subway|skywalk|bus|roads|footpath|garb...
# Trees, Parks and Playgrounds - Others                                                            park
# Water Leakage                                                                                   water
#
#                                                                                       complaint words
# category_name
# Air Pollution                                       wood or garbage burnt|lot of dust due to speed...
# BMTC - Driver or Conductor                                                             rude behavious
# BMTC - Need new Bus Route                                                 increase frequency of buses
# BMTC - Others                                       need more bmtc buses|buses at regular interval...
# Bad Roads                                           worst road|road broken,road repair|road bad to...
# Broken Storm Water Drains                           drainage left open|no proper drainage system|n...
# Clearing of Blockage of Under Ground Drainage P...  sewage pipies narrow|sewage drain blocked|conn...
# Desilting - Lakes                                                                         clean lajke
# Diseases                                            waste dumped|garbage dump|garbage dumped|dead ...
# Electricity                                         complete power cut|street  light not working|s...
# Flooding of Roads and Footpaths                     roads badly designed|footpath|not aintained ro...
# Footpaths                                           footpath enroached|no footpath|footpath drivin...
# Garbage                                             dumping garbage|dump yard|garbage collector  i...
# Hawkers and Vendors                                             footpath enroached|stores on footpath
# Illegal posters and Hoardings                          unauthorized no parking board|posters on trees
# Lakes - Others                                      lake polluted|lake in bad condition|lake in ba...
# Maintenance of Roads and Footpaths - Others                                    install a road divider
# Manholes                                                           open manhole|road full of manholes
# Mosquitos                                                                                  mosquitoes
# Need New Streetlights                               lights gone off|streetlight went off|no proper...
# New Bus Shelters                                    private bus operators are creating havoc near ...
# No Sewage Drains                                    sewage water causing smell|flooded road|draina...
# Noise Pollution                                                                             dog barks
# Others                                              drainage problems|enroachment of ffotpath|no u...
# Overflow of Storm Water Drains                      sewage/storm water drain overflow|poor drainag...
# Parking Violations                                  commuting nightmare|no parking zone|car parked...
# Parks and playgrounds                                                       tree collapse|plan a park
# Potholes                                            potholes filled with water and mud|road repair...
# Public Nuisance                                     bar in residential area|nuisance by house cons...
# Repair of streetlights                              not functioning,install more street light|non ...
# Sewage and Storm Water Drains - Others                                            manhole overflowing
# Stray Dogs                                          dogs are scaring publics|straydogs|sterlize st...
# Traffic                                             traffic signals,zebra crossings at junctions|m...
# Trees, Parks and Playgrounds - Others                                  no public park and plackground
# Water Leakage                                                  water leakage|water provided in nights

# %%
import re
class_words = [ re.sub('-','',x).lower().split() + keywords[x] for x in class_names ]
print(class_words,len(class_words))
# Out:
# [['air', 'pollution', 'dust|smoke|burn'], ['autorickshaws', 'and', 'taxis', 'taxi', 'auto', 'autorickshaw'], ['bmtc', 'driver', 'or', 'conductor', 'rude', 'behaviour'], ['bmtc', 'need', 'new', 'bus', 'route', 'frequency'], ['bmtc', 'others'], ['bad', 'roads', 'road'], ['broken', 'storm', 'water', 'drains', 'overflow', 'drainage'], ['cattle', 'cows', 'buffaloes', 'goats', 'cow'], ['clearing', 'of', 'blockage', 'of', 'under', 'ground', 'drainage', 'pipelines', 'and', 'replacement', 'of', 'damaged', 'or', 'missing', 'manhole', 'cover'], ['desilting', 'lakes', 'lake'], ['diseases', 'malaria', 'dengue', 'cholera', 'fever', 'disease', 'hospital', 'epidemic'], ['electricity', 'power', 'current', 'power cut'], ['flooding', 'of', 'roads', 'and', 'footpaths', 'water', 'flood', 'floods'], ['footpaths', 'footpath'], ['garbage', 'waste', 'plastic', 'dirt'], ['government', 'land', 'encroachment', 'occupy', 'illegal'], ['hawkers', 'and', 'vendors'], ['hoardings', 'advertise'], ['illegal', 'posters', 'and', 'hoardings', 'banner', 'ads ', 'advertise'], ['lakes', 'others', 'lake'], ['maintenance', 'of', 'roads', 'and', 'footpaths', 'others'], ['manholes', 'manhole', 'man hole'], ['mosquitos', 'mosquito', 'mosquitoe', 'mosquitoes', 'dengue', 'malaria'], ['need', 'new', 'streetlights', 'streetlight', 'light', 'new streetlight'], ['need', 'new', 'toilets', 'toilet', 'urinal', 'urinate'], ['new', 'bus', 'shelters', 'shelter'], ['no', 'sewage', 'drains', 'drainage'], ['noise', 'pollution', 'siren', 'speakers', 'speakers', 'loud'], ['others'], ['overflow', 'of', 'storm', 'water', 'drains', 'pipes'], ['parking', 'violations', 'parked', 'parker'], ['parks', 'and', 'playgrounds', 'park', 'play', 'playground'], ['potholes', 'holes', 'pothole'], ['public', 'nuisance'], ['repair', 'of', 'streetlights', 'streetlight', 'light', 'broken', 'damaged'], ['sewage', 'and', 'storm', 'water', 'drains', 'others', 'drainage'], ['stray', 'dogs', 'dog'], ['traffic', 'vehicles'], ['trees,', 'parks', 'and', 'playgrounds', 'others', 'tree'], ['unauthorized', 'construction', 'encroach', 'building', 'built'], ['water', 'leakage'], ['water', 'supply']] 42

# %%
for v in (train_df.loc[train_df['category_name'] =='Air Pollution']).iterrows():
    print(v[0])
#     print(v[1]['category_name'])
    print(v[1]['complaint_title'])
    print(v[1]['complaint_description'])
# Out:
# 94
# Smoking in Public Place
# Many people are still smoking in public place, particularly in front of tea/bakery shops. Panathur Main Road, Munnireddy Layout Near SBM bank branch.
# 525
# Cement piled up on the road. toxic to kids and elders in the neighbour hood
# Cement is not stored in container n bags . it left out in open in huge quantity. can cause serious chronic lung diseases to babies and kids in nearby houses and apartments.
# 731
# Fine Dust Behind Graphite India road
# The strech between graphite India towards ORR thru big basket warehouse has air pollution.This stretch has lot of fine sand and dust  and when vehicles commute makes the road worst for the commuters to breath. Please take necessary action at earliest. Thanks
# 883
# Pollution due to VMR granite factory
# Dear Sir,\n\nI being a sufferer of a public nuisance am helpless to report an issue which is causing serious threat to my and my families\'s health on a regular basis and which is not taken care of seriously till now.\n\nAt 4:00 AM everyday, they start their business and is breaking down my and my familiy\'s health - gradually raising serious health problems.\n\nI am taking about VMR Granites large granite cutting factory just beside my apartment in Vandana Earls Court in Kudlu Main Road, behind VGP Layout. The amount of noise the factory produces is tremendous. And I am sure you would not have wanted such a huge noisy environment beside your family, especially if you have children and parents. It is posing serious threat due to the following:\n\nAs per the directions provided by KSPCB, they were asked to build extra walls and the entrance facing away from the apartments. Also, they were asked to operate 10 - 12 hours daily.\n\nHowever, they are violating the norms without any heed to the authorities, and breaking the peace of silence of sleep as early as 4:00 AM morning every day. I \n\nhave even proof of their working procedures, whereas they are closing after 10:15 PM. Their normal working hours is approx 19 hours daily.\n\nThis way, we are not having proper night\'s sleep and those who stay in the day bear the wrath of noise.\n\nThis is a common problem which is faced by my fellow apartment owners as well.\n\nRequest you to please deal with this and help us out.
# 959
# Black Smoke
# Everyday near the outer walls of Palace Ground there is a huge cloud of black smoke that is seen. This is as a result of people burning garbage and leaves in the area everyday. This along with the heavy traffic in the area is leading to the air being very polluted in the area. I was curious to know if someone can tell me how I can get the air in the locality check for the level of pollution and which authority I should complain to in order to help bring about some measures to prevent this.
# 967
# Vehicle
# Many vehicles polluting in bangalore
# 1239
# Smoking in public areas inspite of the ban
# There is a bakery right next to our house and it has become a nuisance since most of the people who come to the shop smoke and all this smoke enters our house making it really unhealthy for us. This is the case right from 6:30 in the morning till 11:00 in the night. Inspite of the ban on smoking in public areas such activities still continue. Even police personnel who come on patrol do not take any action, they just warn and leave. This has to stop as it is affecting our health. Hope some action is taken in this regards.
# 1323
# NON STOP emission of Smoke from DG Plant
# Karnataka Power Corporation is having a Diesel Generator Plant (DG Plant) which is located on the Doddaballapura Road and adjacent to the puttenahalli lake. This Plant is emitting Black Smoke 24x7 and hence the health of residents of Heritage estate, NCC Urban, Prestige Monte Carlo, Ananthapura Gate, and hospitals like Health Zone and educational institutions like BMS Engg College, Nagarjuna college are severely affected. Will the KSPCB and KPCL take action to stop emission of Black smoke.
# 1547
# Emission from autos
# Hi we are seeing lot of black colored autos whose exhaust is a suspect. can any action be taken please?
# 1699
# Please take action on Vehicle owner of KA-53 5095 who dumped waste
# Please take action on Vehicle owner of KA-53 5095 who dumped waste yesterday near Benniganahalli lake bed yesterday. The owner details are attached in this complaint. Thy also had openly incinerated it causing huge AIR POLLUTION.\n\nRequest Number:  10518983\nEstimated Complete date: 03/10/2015\nName of the Requester: SIVARAMAN HARIHARAN\nPhone Number:  9845228625\nComplaint Type: Reduce pollution effect\nZone:  Mahadevapura\nWard Name: Vijnanapura\nArea  Vijinapura,\nProblem Description:    Please take action on Vehicle owner of KA-53 5095 who dumped waste yesterday near Benniganahalli lake bed yesterday. The owner details are attached in this complaint. Thy also had openly incinerated it causing huge AIR POLLUTION.\nAddress:  2C-301 HARINKTN,KASTURI NAGAR, BDA LAYOUT,Vijinapura,,Bangalore,560016\nPriority:  MEDIUM\nSource of Complaint:   Online\nOpen Date: 30/09/2015\nClosed Date: \nStatus:  COMPLAINT RECEIVED
# 1706
# ULSOOR BUS STOP NEEDS POLLUTION CONTROL BOARD HELP
# 1. ULSOOR BUS STOP NEEDS REDUCE ELEMINATE DUST AIR SMOKE NOICE POLLUTION. 2. IN FUTURE HOW MANY MORE WILL SUFFER WITH EVER ICREASING RESPIRATRY PROBLEMS. 3. KSPCBOARD KINDLY DIRECT B B M P TO MAINTAIN BUS STOP IN A MOSTHYGENIC CONDITION FREE FROM ALL KINDS OF POLLUTION.
# 1874
# Is it possible to speed up metro train construction?
# I feel by increasing public transport air pollution can be controlled. So we need to speed up Metro construction. Is there any way to do this?
# 1935
# Smokers smoking in public places-No Civic rules followed
# Many places in and around Kormangala do not follow rules of No Smoking just as that keeps there tea stalls working.
#  Police have sticked posters at the entrance but still rule is not followed nor the shop owner stops anyone from doing it.
# As normal humans we cant enter the hotel ,sit and drink a cup of tea.That's ridiculous.
# One is Chai Chowki and the other Chetta Sagar. Mark them.
# The hotel is completely filled with Smoke and smokers.
#  ''Not to smoke in public place" is not a rule here. You smoke and you will be treated well .No civic sense at all.
# Even on requesting they do not bother to say their customers. Being a non smoker we have to stand outside and sip our cups. It is harmful even to stand besides smokers and inhale that smoke .
# 1968
# There is daily burning of garbage and leaves
# Hi,
# 2200
# Most polluted area in bangalore
# Dear Authorities,\n\nThe pollution in this area is severely affecting our health.pls take our request into consideration as there are thousands of families suffering everyday.\n1.Tar the road and remove the speed breakers .Especially the stretch back of Graphite India near Acc cement plant needs mask to drive through\n2.Relocate the  factories especially the one near Adithya Elixir  needs urgent shutdown as its so close to residences\n4.CEMENT TRUCKS are a NIGHTMARE to us throwing cement dust all over the path .We need an urgent resolution from your end
# 2847
# Air Pollution
# So many veichels travel in bangalore city this problem reson for a so meny health issus
# 3055
# Roads near Ramamurthy nagar police station are not being cleaned up
# Roads leading to ramamurthy nagar police station have not been cleaned up for the last 2-3 months due to which air pollution has gone up significantly in this area. One can see a big coating of dust on these roads. I request the concerned authorities to look into this issue ASAP.
# 3703
# Burning of plastics causing smoke pollution
# On 13-11-2012, The photo was taken at garbage collection center at Ankamma Road, Halasur. Control room was also informed , But no immediate action was taken till now. In the Interest of the public health, see that in the future, such burning are to be put to an end. Please let me know who is the official, who has to take action in such cases. Bescom Transformer is clearly visible, often burning of garbage may damage the transformer and injuries to human beings. Immediate action to be taken.
# 3778
# Cement piled up on the road. toxic to kids and elders in the neighbour hood
# Cement is not stored in container n bags . it left out in open in huge quantity. can cause serious chronic lung diseases to babies and kids in nearby houses and apartments.
# 4249
# Lot of air pollution.
# Need to have greenery every where...
# 4409
# Burning Plastic
# Garbage collector burning collected garbage with having proper dumping system, this is creating air pollution.
# 4545
# Air pollution-cement SILO in residential area
# Under construction SNN Raj serenity apartments on Begur Koppa road has large cement mixing SILOs. They spew caustic fumes which are carried by the winds and causing respiratory problems and other health hazards to residents and destroying greenery on road side as well as home gardens. Complaints to the concerned AEE and health officer has not yielded any reaction from them. This should be immediately stopped to save environment and air pollution
# 4610
# Too much pollution
# This car was polluting a lot. black smoke.
# 4998
# Pigs getting cut and sold very bad smell
# 3rd main road mathikere next to globe tailors pigs are getting cut and sold from here if we complain against this no action  has been taken only warning won\'t stop this we even can\'t keep open our own house door or windows bcoz of very bad smell and pig shouting request u to solve this asap
# 5096
# Dust and bad roads
# There is lot dust pollution and bad roads. Roads in bad condition.
# 5325
# PARTHENIUM MENACE
# Abundant Parthenium growth in Suryavamshi layout near SHRIRAM Suhaana apartments off Doddaballapura road poses a serious health hazard to residents. \nMany people in the locality have developed breathing disorders. \nPlease clear the Parthenium growth in the area.
# 5429
# Polluting vehicle
# Near anand Rao circle  flyover
# 5491
# Playground dust
# Hi there are a good number of play grounds in bangalore city.Most of them are barren & while playing lot of dust is generated. if we can grow small grass on them dust pollution will be reduced drasticaly.\nNot any exotic variety of grass but local grass which requires bare minimum maintainenence.
# 5644
# Air pollution
# I don\'t think that we have enough of trees in basavanagudi as to prove that we are best then others
# 5711
# Poor workman ship in road works resulting into Airpollution and unsafe to travell on the road
# Some stretch of the flyover constructed recently, near Tata Institute (IISC) is creating problem to the public from last few weeks. As the road layers laid with less bituminous and hence the top layer of subgrade (small sized stones) are getting crushed due to heavy/busy traffic and polluting the Air due to Dust in the area. The road is also got damaged heavily at that stretch. I request to rebuild that stretch of roads immediately to avoid air pollution and accidents on the busy road/flyover. I have attached recent photos for your ready reference
# 5816
# Burning Garbage
# Certain individuals are burning garbage mainly plastic, rubber and old cloths in the empty land in from our apartment. My parents are old and they suffocate as smoke usually blows our direction. Repeated requests are being ignored.
# 5991
# PLS PROHIBIT SELLING OF CIGARETTES
# The problem is near uma maheshwari temple where some shop are selling cigarettes and beedis though the selling of this items  is prohibited near by public places like temple s , school s.
# 6017
# Thanisandra Main Road - Very Dusty
# Thanisandra Main road is very dusty. Its very difficult for any one to walk or ride a 2 wheeler on this road. This dust has to be clean once for all and maintain the road.
# 6132
# Burning leaves and garbage throughout city
# In today\'s world of global warming, why are we still burning leaves and garbage? this complaint is from indranagar, but I have noticed it throughout the city. please stop burning garbage, it produces pollution and reduces our lifespan.
# 6259
# Cement Mixing Plants Polluting Air on ORR-ITPL Road
# Hi, \nI live on ORR-ITPL road that leads from Outer Ring Road to Graphite India, there has been increasing residential construction on this road for past 5 years, yet there are several units on this road that produce pre-mix concrete. These units are polluting the air and surroundings. Given that residential permissions are being provided for buildings, the concrete pre mix units could be moved out of this location.
# 6532
# Construction going on without proper covering which cause more pollution in street and nearby houses
# New construction is going without any proper covering using tarpaulin and it causes more Air pollution and dust in the street and also nearby houses. Hope the rules should be followed when the construction is going on in Residential areas.\nKids are getting affected more because of these kind of pollutions. Please take a proper action
# 6889
# Ban 3 wheeler 2 stroke passenger autos
# 3 wheeler 2 stroke passenger autos making lots of air pollution. please ban them. don\'t wait till our bangalore becomes like other polluted cities and then start taking action on them..
# 6943
# Pollution Due to Garbage Burning
# The pungent stench and smoke emanating from this pile forces residents to keep their windows shut day and nighthttp.Waste collected and  dumped at an open space near Brindavan Layout and are burnt at night.
# 8246
# Bus emitting thick white smoke and polluting the air
# Bus number: KA-01 FA 558 was emitting lots of smoke. It requires immediate attention to get it repaired and to prevent air pollution.
# 8300
# Hotels using fire wood to prepare meals
# Quite a few godd number of hotels are using fire wood in city to cook food especialy Dosa & Biriyani.Theres a dosa hotel in basaveshwaranagar which uses fire wood to cook dosa plz stop them from doing so,since its a residential area.Preferably all over the city wooden fire cooking should be banned for commercial purpouse.
# 8529
# Black smoke air pollution
# Currently I am in Bangalore, and facing black smokes problem every time I travels in bike. I had been in many other cities, I never seen that much ignorance on Black smoke air pollution. At least I have seen 1000 cases where traffic police caught the vehicles who brakes rules or over-loaded, but no importance to those vehicles who emits Black Smokes.
# 8680
# Burning of leaves and/or garbage
# We request your help to clamp down on the environment pollution caused by the burning of leaves and/garbage by people in the area. The resulting smoke periodically floods our homes drastically impacting our health and quality of life.
# 9080
# My test complaint
# Test complaint description
# 9111
# Smoke emitting BMTC bus bearing no.: KA 01 F 8738. No action my complaint: BMTCC10170366
# I raised my complaint BMTCC10170366 on 15th Aug 2016.\nSmoke emitting BMTC bus bearing no.: KA 01 F 8738. No action my complaint.
# 9517
# Two Stroke Diesel engine
# In bangalore, currently most of the air pollution comes out of these two stroke engines like Black Auto, Yamaha RX100 bikes, diesel truck and buses. More and more people are falling sick because of Bronchitis, asthma and lungs related problems due to this.\nIn last 5 years, the environment and weather of bangalore has been changed drastically due to pollution.\nIn other metro cities, these diesel engine are banned or only allowed to operate in night. Why in bangalore we don\'t have any regulation on this ?
# 9703
# BBMP sweeper burns dust
# BBMP sweeper does not sweep properly and whatever swept tree leaves, paper, plastic etc. dust is burnt under a tree. This cause air pollution for hours and also road side tree is getting burnt daily a little\n\nRegards,\nAnil
# 9909
# Difficult to breathe
# I am a resident of Pariwar Passion located at \nTejaswini Nagar, Phase2, \nDodda Kammanahalli Main Road,\nBegur Hobli, Bengaluru-76.\n\nI am getting a smell (looks like a plastic burning) at times throughout day and night. sometimes intensity is too much and sometimes its less. we can not keep our windows and doors open at that time. It\'s really suffocating. \n\nNot really sure about the source. There is a factory nearby. Is it possible to have a factory in a residential area?
# 10094
# Garbage burning in Lingarapuram, near Banaswadi Railway Station, near Don-Bosco Church
# Continous burning of garbage around the residential area and the wind blows the smoke all over Lingarajapuram area\n\nLast meeting with Corporator Mr. Ganesh ( Lavanya Ganesh) he said KFSC Layout will be a model colony!!! \n\nCan some one act to basically stop burning of garbage and leaves - we have enough pollution from fossil fuels.
# 10168
# Too much pollution caused by cement factories
# Can not travel on this road due to too much pollution. How can authorities permit both residential and industry at same place?
# 10225
# Pollution under control
# Buses trucks auto and 2 stroke bikes rampantly emit black smoke.\nFor proof to can take any road with a divider to see the black residue of smoke infused in it.
# 10275
# Air pollution level is keep going high in this road
# Air pollution level is keep going high in this road and not able to walk without covering our face with mask\nSands are there in both sides of the road and it is cleaned properly. It should be completely removed instead sweeping everyday
# 10382
# Vehicular pollution in Bangalore
# Hi Sir/Madam,\nWith the increasing vehicles, vehicular air pollution in Bangalore is at an all time high. It is impossible to sit in a rickshaw/bus/bike or even take a short walk w/o covering one\'s mouth. We do not want our city residents to suffer from Lung diseases because of this.\n\nA system is needed to punish people who\'s vehicles are not meeting Emission Test criterion. Most common offenders are Autos  and Cabs.\nWhen I spoke to ACP, Traffic, Bengaluru, Dr.Saleem, he told me that this is not under Traffic Police\'s duties. Traffic Police is responsible for ensuring traffic moves properly, not the lung damage unchecked vehicles are causing in Bengaluru.\nI disagree to his stand. If that is the case, then, everytime there is road rage, Traffic Police can raise their hands saying, it is Crime Dept\'s job only. But, Crime Dept would need Traffic Police\'s help to work together and resolve cases.\nThe truth of the matter is that the various Govt Departments in Bengaluru need to work in harmony for better lives of people. \n\nI shall call KSPCB regarding this as well. Will update the complaint shortly.\nA strong step needs to be taken for this asap. This step would need BTP, KSPCB and Transport Dept to work together to ensure that the culprit vehicle is made to correct it\'s emissions and fined as soon as possible. \n\nThe mindset has to change regarding this important aspect. The unrest and road-rage in Bangalore traffic is partly due to the agitation polluted air causes in our bodies. Our lungs deserve good fresh air and not suffer because of the neglect by irresponsible citizens.\n\nThanks and Regards,\nNeha
# 10400
# Heavy pollution
# As krpuram is it hub there  ll be heavy traffic which leading to lots of pollution in environment , mainly in childrens causing respiratory problem.
# 10401
# Strong smelling chemicals/oils stored in mahalakshmi layout godown in a residential area
# Hi, This complaint is regarding strong smelling chemicals/oils being stored in a godown in Mahalakshmi Layout in a residential area. The godown is right next to a school. The company in question is Florachem trading co. They claim it is essential oils. Even then it is no reason to pollute the air with such strong smelling oils which are quite flammable. In large amounts, essential oils can have debilitating effects on small children and pregnant women and those with asthma. This is cause for concern for the residents.
# 11158
# Concrete mixing plant in residential neighbourhood
# A concrete mixing plant is coming up in a empty land in Banjara layout, Horamavu. This place is adjacent to several residential houses. Huge heaps of soil is already dumped in the place. This concrete mixing plant will cause air and sound pollution leading to health hazards among the residents. Concerned authorites should kindly look into this and take action as soon as possible.
# 11353
# Air pollution by BMTC bus
# Bus number : KA-01 F 3972. Please decommission the bus.
# 11826
# Dusty roads tend to illness near appartments
# Kempapura Main Road, Yemalur, recently roads got digged off for drainage dooms all over the road. Because of which the road is completely dusty with lot of unstructured road with many path holes. This road is very much busy during office hours and evenings. Lof of dust flies all around the route and it creates a smoke kind of environment. whenever you pass thru the road, you will be fully filled with dust. This also cause child illness and infections affecting kid\'s lungs. Few of my appt kids are already having cold and cough for last 4 months and not getting reduced.\nRequest you to please make a proper road asap.
# 11997
# Air and Noise Pollution by sand, brick and cement business in residential area
# Chiru enterprises formerly rukmini enterprises located opposite to the below mentioned address has been a nuisance for quite a few years now. The problems being faced are innumerable like - (1) Heavily loaded vehicle movement throughout the day. (2) Lorry movements at off times and disturbance while loading and unloading content. (3) Heavy vehicles occupying the streets most of the times and errant owner who always wants others to budge what ever may happen. (4) Fine dust from sand, brick and cement polluting the air as well covering the front portion of my house which is exactly opposite to this shop. (5) Fine dust swept by air spreading into the house posing health issues to the elderly and kid (Doctor\'s certificate available). (6) Errant visitors who park vehicles in a apazard manner. (7) Encroachment of footpath for brick stacking and carryout business. (8) Avoiding BBMP to carryout drench work in front of the shop to help his own business by heavy vehicle movement (this drench would have taken a lot of sand and dust when cleaned or during rains. Now, all this dirt stops either in front of my house or gets into drench in front of my house.)
# 12020
# Air Pollution - Bad drainage Smell
# People residing on 7th B main road,3rd stage, Yelahanka New Town are unable breathe due to bad stinky drainage smell which is polluting the air  &amp; making people fall prey to diseases specifically like Dengue,Malaria.... I would like to urge the concerned civic authorities to take a immediate action ASAP &amp; help us to breathe natural fresh air.
# 12147
# Auto Rikshaws polluting around
# I observe cops asking for emission certificates for bikes even it\'s smoke s not visible but why leave the autos which pollute a lot around and smoke too can be seen around?  It\'s just one pic I managed to click from bus. In signals mainly these old vehicles polute a lot. Please take necessary action and save our bangaluru from pollution.
# 12351
# Fire Crackers
# Sir Please BAN fire crackers. We can avoid this extra pollution ( air & noise). Today BBMP celebration and loads of noise and air polkution. Please we already have sufficient pollution. And no cleaning after celebrations.
# 12580
# Air Pollution Caused by Public,Private Transport
# I am leaving in Bangalore and i always used to walk. Now a days i am watching that traffic Police man are quite busy in looking for Driving License and Helmate but they are ignoring air pollution that are being caused by any Vehicle. If License or Helmate is not there we will sort out this problem instead of this if climate shows its black side we will not make it right by paying money also. Nature is God gifted we have to save it instead of making fun of it .Now a days Bangalore, far from its adage of garden city, figures prominently on the list of highly polluted cities when tested on many pollution parameters, according to a report by the Centre for Science and Environment (CSE) on the state of air pollution and mobility. Under particulate matter Bangalore has been identified as one among 14 cities that have high levels of particulate matter, while 47 per cent cities monitored in the State exceed ambient air quality standards in this category. These figures are drawn from air quality analysis data by the Central Pollution Control Board, and are part of the statistics presented and discussed at a workshop conducted jointly by the CSE and the Karnataka State Pollution Control Board. My request to every Bangalorites and Traffic Policeman to please cooperate.
# 13210
# AECS layout
# All the mud and dust on the roads in ITPL main road and AECS Layout road joining kundalahalli gate is causing too much air pollution, please remove all the mud and dirt from the roads
# 13459
# Trucks carrying construct material openly and the same flies during transportation and pollutes.
# Trucks carrying construct material openly and the same flies during transportation and pollutes.
# 13693
# Clean dust from the roads...
# I have not seen any BBMP guys cleaning or removing the dusts from the sides of the roads. At-least once  a month and this should be handled properly where construction work is ongoing for Metro, ex: Mysore Road Nayandahalli Junction. No one covers the potholes, the road is without asphalt and full of dirt. You can\'t even breath in that dust cloud. \nWhere did the Street sweeper vanish from Bangalore? Its been more than a year now i saw Street sweeper on the roads or Isn\'t BBMP Paying for the workers?\n\nI have been to Rajasthan which is a desert area but still roads are damn clean and maintained.
# 13881
# Bugle rock park - Leaves and other things being burnt
# Attached photograph shows leaves etc. being burnt in the plant nursery area of the Bugle rock park, Basavanagudi. This is being done by the park personnel.
# 14013
# Air pollution and inconvenience to residents
# Thick black smoke from Shri nidhi sagar hotel in indiranagar double road causes inconvenience to the residents.
# 14380
# Pure Air is very essential
# Pure Air is very essential for our health. But AECS residents breathe impure and dirty air. Yes ! The dry leaves and the heaps of plastic garbage bags are put together and burnt in large numbers. This causes great health problems in senior citizens. I would request you to kindly look into this matter as this a very serious issue.
# 14574
# Polluted vehicles near Basveswaranagar - 560079
# The problem is there are lots of 3 and 4 wheeler vehicles that are polluted in that entire zip code and cause a menace to the residents around. The drivers aren\'t worried about public at all, they keep exhausting polluted black smoke which is harmful to the entire community. This whole Zip code needs attention.
# 14778
# Public smoking on rampage in Bangalore
# Hi! Everyone,
#    This is actually quite a general complaint, to have attention of everyone concerned about the increasing nuisance of  public smoking in Bangalore. Horribly, i noticed that it's increasing day by day, and crossing all the limits.
#    It happened yesterday to me, when I was having my midday meal in a restaurant near Bangalore Dairy Circle/Forum Mall. Where I found a group of college girls and boys smoking openly in different groups.  People eating near me, requested them to move away since they were eating, but they kept ignoring. There was hardly any place left around, where someone was not smoking. Hilariously, I could see 2 traffic police men, talking and gossiping in a nearby shop.
#
# While later i was travelling throughout the city I noticed that smoking has increased terribly. Every shop, restaurant, bar, cinema hall, bakeries, have dozens of people smoking without any fear.  If you are in restaurant or roadside eatery shop, the situation is terrible. You cannot eat peacefully.
# The most shameful, I saw, that most of these people are well educated and boast themselves as employees of international level corporates and colleges.
#
# I could find many links while surfing, that seems to be related :
#
# https://smokingbanbangalore.wordpress.com/
#
# and some other links, that I think are nothing but jokes, when you see the ground reality of public smoking  in Bangalore:
#
# http://www.dnaindia.com/bangalore/report-bangalore-no-ifs-and-butts-no-smoking-in-public-places-1940069
#
# http://timesofindia.indiatimes.com/india/Soon-Rs-20000-fine-for-smoking-in-public/articleshow/42235453.cms
#
# http://www.complaintboard.in/complaints-reviews/cigarette-smoking-nuisances-in-public-places-in-bangalore-l233994.html
# 15427
# IJM cement factory(ORR-Whitefield bypass Road) operating 24 hours without consent causing pollution
# We had filed an RTI sometimes back against 3 cement factories (ACC, Concrete India and IJM) those are operating in the back of Graphite India on the bypass Road to ORR. From the RTI which is attached below we came to know that all 3 factories have been applied for consents (renewal of their agreement). While "ACC" and "Concrete India" didn't get the approval and have already moved out. Even IJM hasn't got the approval yet but it still continues the operation with full speed. Even they are operating over the night and making a lot of noise and dust pollution. We are getting it difficult to cope up over the night. We near by residents requesting ichangemycity/KSPCB/BBMP/E-Janaspandana  to help us on this. Please help us and take some actions on this serious sound and noise pollution.
# 15611
# Cement Factory in chinapanahalli - potential health hazard
# In the chinapanahalli area, there is a cement factory which is causing lot of air pollution and potentially impacting the health of people who are currently living surrounding the area. Lot of new apartments consturctions have happened in this area of late and loads of people are living around the factory. Appreciate if appropriate actions are taken to either relocation this factory for the betterment of the society
# 15826
# Garbage being burnt
# Garbage being burnt on the road every day. this is causing lot of inconvenience as the air pollution is causing lot of health problems to the residents staying in the vicinity. request you to take necessary action.
# 15939
# Plastic burning in Anjanapura 5th block
# I have been living in Anjanapura 5th block and have been suffering from Plastic burning. I have complained to MLA Krishnappa\'s secretary, Mr Ramesh and for sometime the burning had stopped during the rainy season. Again from the last one month plastic is burnt in the evenings. It is an unbearable stench and pollutes the air around. We have to shut ourselves inside the home with all the windows closed. It is very difficult to stay like this. I try calling the Karnataka State pollution board and the phone numbers keep ringing but there is response at all. I can identify the spot where plastic has been burnt. Hope i get some responses and we can resolve this issue.\n\nThanks,\nSanjay
# 16089
# Piled up cement for construction pose deadly hazard to neighbourhood
# Cement dumped on the road. more than 100 people in the neighbourhood mainly babies and old persons is likely to get affected by chronic lung problems.
# 16094
# Air pollution
# From past 25 days, plastic/other material is being burnt from neighboring slums/dump area. The whole area is covered with this burnt air.We are all breathing this foul air.This is getting worse day by day. This open burning of plastic is simply dangerous to our health. When these are burnt in open, carbon monoxide, dioxins and furans are released into air. Carbon monoxide is a pretty well known poison and medical studies have linked dioxins and furans to cancer and respiratory disease.\nThe old and the kids are very sick. Asthma is on the rise. Please visit area and take action.
# 16232
# Ban the bursting crackers in the political functions
# Bursting of crackers on the eve of birthday of some political leader in ramamuthy nagar yesterday created a lot of noise and dust and whole road was coverd with papers which adds an extra burden to already existing garbage  I hope our leaders as well as government authorities take some step toward this and make our city cleaner
# 16347
# Polution
# Pollution
# 16633
# Very bad smell and irritation
# This perticular industry \'The global food specialities\' is producing a horrible foul smelling smoke and spoiling the area and causing tramendous problem to the workers in the area with nausea and vomiting sensation. Please take necessary action.
# 16779
# Wood fire cooking
# Construction crew residing in building next door cook their meals in the open using wood fire which causes the entire neighbourhood to be filled with smoke. It is creating health issues as well as causing damage to property. Repeated complaints to the owners and construction crew have fallen on deaf ears. Problem has been occurring for over a year now and is taking its toll. Please help resolve this immediately.
# 16859
# BMTC buses or Pollution bus?
# Very disappointed with the amount of air pollution caused by the government vehicles...No wonder if the city might turn into a place where people breathe only  black air and get all kind of possible diseases....\nHas government even bother what kind of fuel BMTC busses use....90 % of BMTC busses and auto rickshaws in the city emit harmful gas and this is causing a lot of trouble to other riders and pedestrians...The harmful gas is oftenly blown right into our faces while riding or standing  behind the bus ....This is a very serious matter which should be taken care of before the city turns up into one where there is scarcity of oxygen and people suffer ..\n\nThank You
# 16863
# Damn Dust in Sarjapur Road
# It is really difficult to travel on Sarjalur Road from Carmelaram to Agara. It is full of dust and damaged road . I would appreciate if all of you can raise the issue and open up the blind eyes of the authority.
# 17090
# Garbage Burning near Centre of Road side
# Someone burning waste see smoke  near varthur lake .its polluting air bbmp officers stop this.its in front of varthur  lake .really bangalore temp will cross 40 degree
# 17462
# Smoking near my flat window
# I am staying at #16/2, GF, T S Nivas, Bellandur Main Road, Near Krystal Galena and Opp Akme Harmony Back Gate, Bellandur. My flat window opens on road. Near my window there is a Cigrate shop where all people purchase Cigrate and used to smoke near window. Due to this all smoke used to come to my home which cause problem to me and my family. I have written \"No Smoking Zone\" on the wall but still people do the same. People used to throw garbage there also which is not acceptable.\n\nThis area is completely residential. So my request is that please shut down this shop permanently or shift to another place.
# 17571
# Daily Burning of Tyre ,Polythene &amp; Hazardous Waste at DumpYard@ Bommanhalli
# Daily burning up of heaps of Tyre , polythene & hazardous substances  behind J.R.Makwoods Apartment ,Bommanhalli. It surrounds the entire apartment with chocking smell of poisonous gases , which is causing asthma ,sinus , fever ,tuberculosis in adults and is running havoc to small children health .\n\nIt makes evening walks impossible around corridors and backside as the filthy smell fills up the nostrils . Even if a window remains open , the poisonous gases enter inside the house .\nClean Air is every citizen\'s right and it is criminal on part of few individuals to run havoc with hundreds of people lives and quality of Air they breathe.\n\nIt is not only a matter of clean air for all of us , but for the environmental degradation as a larger issue in Bangalore ,which must be stopped. Besides it is creating health issues and creating asthmatic patients in young children and adults alike.\n\nPlease see & feel the magnitude of poisonous gases emanating and entering our breathing periphery.\n\nhttp://youtu.be/1y3Sz-PQyMo\n\nhttp://youtu.be/aoWWKubC_Q4\n\nhttp://youtu.be/LIwIhgRYfX0
# 18094
# 3 Borewells are dug in
# 3 Borewells are dug in a site where a new construction is going to take place. 3rd Borewell construction is in progress and its unbearable noise a air pollution happening here. No measures are used to regulate the enormous amount of dust coming out which pollutes the whole area. The digging goes on till late night and it is not possible to live peacefully here. Police has come and warned them, still no steps are taken to fix this. Please look into the issue.
# 18497
# Air pollution
# This is polluting goods vehicle near RBI KR Circle
# 18672
# Air pollution
# Too much smoke near chalukya hotel basaveshwara circle
# 18678
# Dusty Area
# Hi ichangemycity,\nThere is lot of dust near K.G Road this is coming because the BMTC buses are speeding too much. Please resolve ASAP
# 18719
# Polluting vehicle
# Hudson  circle
# 18724
# Burning of garbage in open
# Pourakarmikas sweep the road.collect and burn on the road itself often under the trees.People are forced to inhale t the smoke, the trees will die .The cess we. pay is used in such a way.
# 18823
# Rampant Garbage (Plastic and solid waste) burning behind Purva Skywood aptmt complex
# Garbage is dumped daily by trucks and then burnt for disposal. Please see attached pics. The fumes are noxious and harmful.
# The waste is burnt on a daily basis. (you can see the waste being burnt in the second photograph)
#
# Edit-1 - Adding snaps clicked on 23 Jun
# 19653
# RETIRED ARMY VETERANS BEING BEING SUBJECTED TO CHEMICAL AGENT ATTACK IN BANGALORE
# A common wall separates the Army Veterans Colony and a very highly polluting Asphalt and Tar mixing Unit which spews noxious gases, dense smoke along with tar and sans dust in copious quantities into the atmosphere. The polluting unit operates day and night and the entire surroundings which includes a primary school run by the Church gets covered by dust and settled ash.\nFormal Complaints lodged with the PCB in April and July and several meetings with the officers of the PCB has had no effect. The polluting unit continue to ruin the health of the veterans with a vengeance.\nThese veterans have survived the enemy\'s bullets in their prime but stand no chance against a killer from amongst our own.
# 19672
# Peanuts chikki factory\'s
# Peanuts chikki factory\'s making air pollution in residential area near magadi Road bangalore
# 19967
# ORR from Agara to Sarjapur Junction full of dust
# I daily commute to my office via ORR. After Agara flyover till Sarjapur Junction the service lane is full of dust. Many vehicles specially some BMTC busses use the service lane due to which the whole ORR in this stretch is covered with a kind of a dust storm or dust fog.\nThis is worse for the 2 wheeler riders commuting during morning hours including me. This dust has been accumulated there only in the past 1-2 months, earlier it used to be fine.\nI urge the authorities to take this up on high priority as it directly affects the health of the commuters.\nI am attaching a map for reference.\nThanks!
# 20011
# Pollution from Graphite India affecting children\'s health
# Air pollution in and around Kundalahalli, Whitefield is aggravated by presence of Graphite India. While the company may have taken measures to reduce the pollution levels, it still largely contributes to making Whitefield a pollution hotspot. Children especially are the victims- they suffer from respiratory problems from the time they are toddlers. As a mother, their ill-health gives me sleepless nights. Just visit the RXDX clinic located opposite to Graphite India and you know what I am talking about. The air in the clinic is loaded with the pollution emanating from Graphite India and one comes out feeling irritation in the throat, coughing or sneezing. Either the authorities should not have permitted the growing of a township near such a polluting unit; but now that the township had been established, Graphite India needs to be relocated and quickly.
# 20326
# Burning of dry waste at dry waste collection centre...!!
# Hi all..\nOf late, I\'ve seen lumps of dry garbage being burnt down at Kodihalli (old airport road, near Leela palace/Manipal hospital ) every morning...\nThis practise goes on the whole day.. Please try to put an end to this... It\'s  not just harming the environment ; the people of that area are being exposed to high threats and lung disorders...!! \nI request ICMC to do the necessary ASAP ..\nThanks again..!
# 20430
# JCB usage
# This sand sales group using this place un authorised the place and constantly using the JCB machine to mix the all kind of sand from 6.am to 6.pm this creates constant noise which is disturbing us.
# 20725
# Garbage burnt in the surrounding.
# Garbage burnt in the surrounding. this is causing lot of health problems. please take necessary action.
# 21018
# Smoking pollution
# In living in 9 th cross swimming pool extention near my house in the residential area one Sai Ram coffee shop opend theyselling cigarettes daily from morning to evening more than 20 person comming smoking  at any point of time.This is comming under vallaikaval police limit .kindly take necessery action.
# 21068
# Solid waste management in worst scenario
# I\'m concerned about increasing PM2.5 and PM10 which exceeds the liveable environment. This is occurring due burning of uncollected solid waste which are dumped near Dr vishnuvardhan road uttrahalli .. Every day a large amount solid waste are burnt on road side .. Which cause hazardous air to accumulate in uttrahalli area .please kindly take action regarding the burning of uncollected solid wastes
# 21261
# Spolling the atmosper
# From few days they are burning garbage waste
# 21619
# Extreme Dust on LIC Colony 1st Cross (From Canara Bank Holiday home to End of the road)
# BWSSB has dug up the road to replace old sewerage lines and they are indeed replaced. Unfortunately, there are many gaping holes near cross road junctions and workers hardly work in these areas. Huge debris and Mud is remaining through out the road and is causing very bad air pollution when vehicles goes by. Even a 2 wheeler kicks up enough dust and already many children are suffering from Asthma and Wheezing. Even senior citizens have to pay the price. The place is full of dust. Before the BWSSB digging, the road was good and it was never like this before. The road is bug at both sides one for sewerage and the other for water pipeline. Please tar the roads or at least tar the gaps and dug up stretches to ensure the road is dust free. Thanks,
# 21770
# Plastic-garbage burnt everyday - unbearable air pollution
# Massive amounts of plastic-waste is being burnt at 6th cross, 8th main, SBM Colony, Mathikere almost on a everyday basis by BVG-India contract workers.The toxic fumes from the burning garbage is unbearable and causing health problems to the local residents. There is also a school near-by! I request the authorities to please take the matter seriously and put an end to the garbage burning immediately.
# 21771
# Burning of garden and leaf litter on road side
# Regularly BBMP Pourakarmikas burn dry leafs and garden litter
# 21788
# Non-veg wastes thrown near the lake
# Area name is called - Begur Lake
# 21877
# Unauthorized burning
# Every day at ST bed extension there is huge amount if burning. The smoke pollutes the entire area and enters our home. This has been going on for days.
# 21912
# Burning of dry leaves
# The dry leaves that are fallen in our locality are burnt down everyday..Unauthorised personnel burn leaves during early morning hours and also ,sometimes during the day... This causes a lot of trouble to the residents as the smoke gets inside the house and breathing becomes difficult ..
# 22251
# Construction in nearby areas
# The issue is regarding Bellandur, near Cafe coffee day opposite Central Mall. Many plots were empty till last few days. Recently, construction plans started and bore wells were dig. No covering was provided, so the whole area was filled with dust and public waiting for the bus were the victims. The issue is getting worse everyday as construction work is progressing. Roads are occupied by JCBs and other trucks bringing load and used in construction work. I am worried about monsoon arrival, as it shall leave roads in an unusable condition in the presence of these vehicles.
# 22499
# Dusty roads of Marathahalli
# After pouring in around 20% of my salary and various other varieties of taxes, what do we get is good amount of dust, smoke etc. in our lungs twice a day daily. How many years will it take to get rid of the dirty roads? Throughout the day especially morning and evening hours whole Marathahalli to Whitefield area is under cloud of dust. How is it possible for the bikers to drive without causing harm to their health?
# 22731
# Thick, black smoke on Millers Road
# Please see this thick black smoke that went unattended for more than an hour! This is what people are doing to our city.
# 22964
# Cement in air beyond inhaling limits.
# I live in Doddanakundi and for the last few months, the dust from two cement factories in the neighborhood is troubling us to no end.
# Every morning, there is not a place that is not covered with the soot and dust. We, the residents, cannot leave the food open as the dust settles on the top. The same is the case with water. We also cannot dry clothes in the open because of the same problem. In short, the dust is omnipresent in the area.
# Firstly, Though it is an industrial area the authorities have allowed many private builders to build apartments and offices close by. Also, there is a mushroom growth of more than thousands of existing and new apartments here. It s becoming a prominent residential area these days.
# Secondly, almost everyone in our area susceptible to stroke of Asthma and Bronchitis and lung inflammation. So the health hazards are very serious in nature.
# So we people think that, the authorities should take steps to gradually shift the factories outskirts and as early as possible.There are a couple of cement factories in the Doddanakundi Industrial Area and the service road from marathahalli total mall to ITPL is crowded with lots of lorries and trucks plying through day and night carrying loads of cement, sand and stones. The entire stretch of road till kundanahalli has become difficult for pedestrians. The dust is beyond limits and there are many apartments here, close to 10000 families residing. The new apartments are getting constructed as well. Our kids fall sick very often. Cough and cold, dry cough asthma and chest infection have become very common to our families. Winters are really scary, such horrifying dust with added cold. We are really scared if this is carcinogenic. There has often been a difficulty in breathing.  There has been a lots of complaints raised on this regard since a year ago and no promising actions have been taken, rather the approval for many newer apartments are given despite the cement and dust levels.  Though, there has also been a mention about the pollution levels and the cement dust in Doddanakundi and Graphite India many a times in newspapers and media from 2012 on-wards, still there has been no plausible outcome. Here is for your reference: http://www.thehindu.com/news/national/ka ataka/bangalore-among-14-cities-with-high-levels-of-pollution/article4538834.ece http://timesofindia.indiatimes.com/city/bangalore/Whitefield-is-most-polluted-area-in-Bangalore/articleshow/12000809.cms This is the recent survery from The Hindu : http://www.thehindu.com/news/cities/bangalore/1/article6347493.ece  We would be really grateful if that gets resolved. I understand there was a time when this used to be an industrial belt. But as the city expands, these factories should move out. Hoping some positive action in this regard. Fingers crossed.
# 23151
# Pollution Check On Vehicles
# Hi, I\'ve noticed two vehicles making lot of air pollution today : Vehicle Numbers are as below : KA 03 B 4855 KA 03 B 3088 Thanks and Regards, Concerned Citizen
# 23233
# Govt\'s new Vehicles are Polluting more than the peoples old vehicle
# Govt\'s new Vehicles are Polluting more than the peoples old vehicle\n\nhttp://www.bangaloremirror.com/bangalore/others/Govt-vehicles-biggest-choke-of-Bengaluru/articleshow/52946269.cms
# 23676
# Sewage drain open for many years causing regular health hazards
# ...
#
# Kindly forward my complaint to the management of these universities and colleges, so that they can persuade their students not to break laws.
# 28083
# Smoking spot next Childrens Hospital
# Respective sir, govt had rules that no smoking in public places but in Ramanjaneya gudda surrounding have one bakery and also one children\'s hospital next to that bakery, every day so many children\'s coming with health problem and also they suffering with smoke smell, pls kindly save our children and us
# 28218
# Pollution from Factories and Trucks in Doddanakundi
# We middle class citizens, working hard and paying taxes duly has NO VALUE in this country.if any politician or influential people had complained it would have been resolved a long time back.
# 28829
# BMTC BUS... No. 276... rout K.B.S to Vidyaranyapura
# Bus no . KA-01  F-8691... rout from KBS to Vidyaranyapura.... \n\nEmitting Black Smoke from its exhaust ... normally, I have never seen these kind of black smoke exhausted from a BMTC Bus....\n\nI\'m a resident of Bangalore from my birth.... I have never seen these kind of pollution .... \n\nand its shows  irregularity from the BMTC department to maintain the public\'s transportation..
# 29460
# Bellandur Lake
# Bad smell from Bellandur Lake Because Of dirty water mixing in Lake Here public going to die soon by diseases please help us before that happens
# 29571
# Pollution controls
# All the people must use the bicycles for the short distance becoz most of bykes and cars may causes the pollution and inffects to childerns and old people
# 29611
# Cement in Air in Chinapanahalli Residential Area because of factories.
# As Chinapannhalli has lot of residential apartments now, even we have moved in there; In presence of cement factories we cant even breathe properly. Its dusty full day time with extent to very poor visibilty. I want to complain about it and request the authority to immediately issue notice to cement factories move away to some non- residential open areas.
# 29685
# Illegal Garbage burning at Gottigere
# For the past few weeks, there\'s has been constant garbage burning(Esp. Plastic/Tyre or hazardous waste) smell emanating. This is very predominant at nights and wee hours in the morning. We are unable to pin point exact location of this as it\'s very discerning from any part of Gottigere and towards Nice road junction. Requesting the authorities to look into this and take very stern action against unscrupulous garbage collectors or whoever behind this.
# 29816
# Most of the autos, trollies and buses are creating lots of air pollution in bangalore
# In Bangalore, air pollution level has been increased dramatically.
# 29861
# Bus 201 KA-01-FA-1825 BMTC bus polluting the air lot. Today the Koramangala 3rd block water tank roa
# Bus 201 KA-01-FA-1825 BMTC bus polluting the air lot. Today the Koramangala 3rd block water tank road is fully polluted by this bus. Reigns the bus authorities to fix the issue
# 30022
# Massive concrete mixing in residential area
# Hello, \n\nSeems there is a massive concrete mixing about to happen in the middle of residential area. This is going to affect everyone living in that area. \n\nThis is happening in the middle of Banjara Layout located at horamavu. \nIts on Banjara main road where there is a huge vacant property.
# 30180
# Burning of dry leaves
# This is my 3rd complaint on burning of leaves..\nIt\'s my humble request to ICMC, to take severe actions and stop all those who burn dry leaves..\nIt definitely increases the temperature of the city and makes it much more polluted...! \nThanks..!
# 30692
# See how the air pollution going on by KCDC
# Today morning we captured these picture, which describe you to how much air polluted by KCDC. Who is responsible for this scenario.\nMy humble request to all do something for save the nature.\nThank You!
# 30705
# Poisonous Air
# BBMP is failing miserably in garbage handling. It is not having any control over its workers. It is least bothered about proper disposal of waste. BBMP workers who are supposed to collect the garbage and dispose it are collecting only waste material which can be sold to scrap merchants. They are dumping remaining waste material (majority of which is plastic covers) in empty sites or other vacant place and putting fire. This is very dangerous as poisonous gases are released. BBMP should realize this and take an account of how much waste each worker is collecting.
# 30745
# Illegal stone cutting in residential area causing air and sound pollution in Roopena Agrahara
# Illegal stone cutting in residential area causing air and noise pollution in Roopena Agrahara
# 30941
# Radiation
# Mobile tower
# 30984
# Near hudson circle
# Heavy smoke air pollution
# 31049
# Cheap furniture factory spreading air pollution
# I stay at Golden palms society on k narayanpura cross road, off hennur main road.  Just next to the entrance we have a cheap furniture carpentry shop who day in and out use spray paint. Such proximity leads to severe poisnous air pollution and kids start coughing as soon as they come into contact with air flowing from that side. Even adults feels irritation in throat and can\'t stand the air. Please get it checked by competent authority and ask the owner to shift the premises to an industrial area.
# 31687
# NO EMISSION TESTS FOR BMTC??
# There are rules, time for policemen to catch vehicles with high smoke exhaust. But BMTC buses are not so well maintained such. This should be done in the depot itself.
# 31826
# Air Pollution near to Venkat International Public School, 66th Cross Road, 5th Block, Rajajinagar, B
# Burning of plastic is carried out next to the big drain. This causes air pollution and this is having a very bad impact on the students health who are studying at Venkat International Public School. Appreciate the relevant Authority will be able to address this issue and stop the burning of plastics and other improper materials.
# 31832
# Parthenium plants
# Sir, lot of parthenium plants have grown in our area and around causing severe breathing problems. Kindly organize to clear these growth for a healthy Vidyaranyapura
# 31923
# Air pollution causing skin diseases
# Dear Sir/Madam,\n\nThe increasing number of vehicles is causing the air pollution to take place  causing many health effects on the population.\nPlease do the needful.\n\nThanks and Regards,\n     Poonam
# 32428
# Burning of dry leaves
# Burning of dry leaves on Dickenson road, a daily feature near Defence Accounts Dept
# 32621
# Mobile Tower Radiation Problem
# We have a Mobile tower in our residential area. Its very close to apartments .We started staying here from last 4 months and we are facing health issues like headache, fever etc frequently. These may lead very serious health diseases. Radiations are really dangerous to pregnant women and children an we have already seen the ill effects.Since there are lot of families staying close to this tower, we urge the respective authorities to take up this issue very seriously and remove the tower from this place.
# 32781
# Burning of rubber tires and garbage
# Whenever the temperature drops, some people get together and burn garbage and/or rubber tires. The air pollution because of this is very harmful to all. This needs to be stopped. Citizens need to be educated on why this is a bad practice.
# 32855
# Poor solid waste management
# Im concerned about burning of uncollected solid waste which  increases the hazardous gases and get accumulate in utthrahalli area . people are exposed to toxic gases generated by burning of solid wastes . PM2.5 and PM10 are exceeded beyond breathable limit. please kindly take measures to collect the solid waste in time so the it remains uncollected and burnt on the road side ..place uttralli main road ,dr vishnuvardha road in between poornapragna layout and pattelamma temple
# 33024
# Bad smiling gasses emits from industries
# Bad smelling gas from an industry\nSir This is to draw your attention to the violation of norms with respect to pollution and environment by the systems alloys situated on thanisadra main road,near Nagwara signal. The industry is surrounded by residential area and hence causes lot of in convenience to the residents.A bad smelling gases emits from the industries at odd times of the day. Sometime in the early morning and sometime in the afternoon . The gases are causing breathing difficulties among the young and old peoples . Hope the authorities will take immediate action
# 33037
# Air pollution in Cox town area.
# The Ramakrishna road is full of dust. While the vehicle are moving, the area is covered with dust. This is leading to air pollution, please clean the road proper as students are coming to school in this area so please do some need full to this area.
# 33098
# Air pollution
# In venkateshwara layout near outer ring road we are facing severe air pollution created by burning plastics,rubber and scrap material by scrap dealer everyday morning and evening and the smoke and smell is really unbearable.Inspite of requesting them not to do they just dont care about anything.hence requesting to take immediate action against this illegal and hazardous activity going on in residential area which can be very harmful for health as well as environment threatening.
# 33114
# Burning of leaves by Pourakarmikas
# Self explanatory.. No need of photos!! Pourkarmikas sweep the roads and set fire to leaves and paper etc, at every crossroad and even main roads in Domlur, and Indiranagar polluting the fresh clean morning air. This is despite the notification from the BBMP commissioner, prohibiting it, just a few months ago.. Why is this not being utilized for composting at the Parks of the ward instead?
# 33281
# Cement Factories in Chinnapanahalli Residential Area
# Hi, There are 2-3 Cement mixing plants in Chinnapanahalli (Mahadevapura, Bangalore) Residential area, causing huge dust , Air pollution issues. There is lot of dust being flown everyday into the apartments. Residents in that area are suffering with severe health issues. There are lot of up-coming new constructions in this area. Kindly help relocate these Cement factories from this residential area
# 33285
# Volvo buses - adding onto Air pollution
# Looks like the AC buses (Volvo) are adding to the existing air pollution in Bangalore, they are emitting more gas into the air when compared to other vehicles on the road. How often do these buses get serviced? (in terms of emission tests) and What measures are taken to control their emission level?
# 33422
# Pollution caused due to irregular maintenance of Public and transport vehicle
# I daily travel to Sarjapur from Electronic city via central jail road, and on my way I come across various BMTC buses  and goods carriers trucks, I don\'t why government and truck owners are not maintaining these vehicles, these vehicles release dark black some and sometimes it is very difficult to breathe as well see, so much pollution is released from them.\nThis is giving rise to global warming, I\'ve been in Bangalore from last 1 year and have seen a noticeable climate change. This pollution is increasing health disorders and many others diseases. I request government to keep regular checks on these vehicles and also should issue chalans if necessary.\nI\'m from Delhi and their traffic rules for such problems are very strict, trucks are only allowed to enter the city for specific time and only those trucks are allowed which have valid pollution certificate. Delhi government has taken step to control this problem and they are progressing on this and are now able to control the pollution level in Delhi.\n\nAlso BMTC buses run on Diesel, we have CNG (a clean fuel) as a option, this will also result in controlling the pollution level.
# 34271
# Air polluting
# Polluting vehicle
# 34493
# Free from Pollution
# We want less pollution . so please take care of that issue
# 34568
# Piled up cement for construction pose deadly hazard to neighbourhood
# Cement dumped on the road. more than 100 people in the neighbourhood mainly babies and old persons is likely to get affected by chronic lung problems.
# 34821
# BURNING WOOD &amp;/or GARBAGE
# Wood or garbage is being burnt in an unoccupied plot of land on the koramangala main road, next to pai electronic showroom.
# 34972
# Vehicles emitting pitch black(Poisonuos) effluents
# Why are the traffic police not seizing heavy polluting vehicles which is polluting Bangalore, Old BMTC buses, private tempos, autos which ply between Marathalli to Kadugodi. Why cant Government or concerned authorities seize their vehicle or cancel their license. Everyone will suffer because of these people , its a slow poison
# 35056
# Cant Breathe
# Too many BMTC\'s and Black-Yellow autos creating huge amounts of air pollution. It would be great if there is an app to click pictures of these vehicles expelling so much of toxic into the air and post, so that the RTO\'s can take respective action. Its really getting hard to breathe on the roads.
# 35294
# Ksrtc bus beari g no ka 13-f 2074
# Causing air pollution
# 35452
# Air pollution a big concern
# Please do the needful to decrease the air pollution.
# 35718
# Residential areas allowed close to industries
# The areas adjacent to doddanakundi industrial area is facing severe pollution.Though it is an industrial area the authorities have allowed many private builders to build apartments and offices where thousands of people live breathing severely polluted air and water .Many trucks fly over these roads frequently causing the roads and trees to be covered in cement dust.It would be advisable for the authorities to gradually shift such industrial areas within city to outside
# 35900
# Foul smell and Black soots from Graphite India @ Doddanekundi Industrial Area
# Off and on, especially on weekends, there is lot of foul smell in the area around Graphite India factory. This mainly consists of black carbon suspended particles and is harmful for thousands of people crossing the Graphite India Junction every day, not to mention the people who work and live in the area around the factory.\n\nSomething should be done to stop this!
# 36011
# Too much air pollution from the cabs, lorries &amp; buses
# A dense black smoke is emitted from most of the Company cabs, buses & lorries travelling daily in the outer ring road from silk board, marathalli & whitefield arreas
# 36275
# BMTC Bus creating pollution
# BMTC bus KA 01 FA 1761 was seen creating a huge black smoke near HAL and this vehicle needs immediate attention as this is creating lot of pollution
# 36702
# Air polluting vehicle
# Near bhovipalya  1st block Rajainagar
# 36913
# 2 stroke auto should be banned
# I see there are many 2 stroke autos which are polluting air in Bangalore and j am afraid that one day it be like Delhi.\n\nnow a days traffic police are also least bothers about polluting cars and bikes and trucks these vehicles should be seized and never to allowed to run on roads .
# 36922
# Pollution due to burnt tyres
# During the recent strikes tyres were burnt near State bank of Travancore in Girinagar 1st phase and the left over is not being cleaned. The dust which is raising from that is causing pollution and irritation. Please do help us to get it cleaned as the sweeper also denies to clean it.
# 37476
# Pigs getting cut and sold very bad smell
# 3rd main road mathikere next to globe tailors pigs are getting cut and sold from here if we complain against this no action  has been taken only warning won\'t stop this we even can\'t keep open our own house door or windows bcoz of very bad smell and pig shouting request u to solve this asap
# 37527
# Cement and Dust level is too high in our area.
# Due to Cement and Mixture factories surround , Cement and Dust level is too high in Air. \n\nCurrently 1000 flats are there in the same area. It is very difficult to live with current condition of Air pollution. This problem need to resolve as soon as possible.

# %%
## training word2vec 


# import gensim.matutils as gm

# from gensim.models.keyedvectors import KeyedVectors

# import gensim, logging
# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
 
# model = gensim.models.Word2Vec(sentences, size=200, window=5, min_count=5)

# model.save("../word2vec_icmcData")

#to continue training
# model = Word2Vec.load("../word2vec_icmcData")

# %%
# print(len(model.wv.vocab))
# print([x for x in model.wv.vocab.keys()])
# model.accuracy('../questions-words.txt')

# %%
import gensim.matutils as gm
import gensim
from gensim.models.keyedvectors import KeyedVectors

# Load pretrained model (since intermediate data is not included, the model cannot be refined with additional data)
# model = KeyedVectors.load_word2vec_format('../glove_w2v.txt', binary=False)  # C binary format


model = gensim.models.Word2Vec.load("./J/word2vec_bangalore_description_train_min_count_5_clean.model")
model = model.wv

# model = KeyedVectors.load_word2vec_format('../word2vec_icmcData.txt', binary=False)  # C binary format
 
wordvec_unavailable= set()
def write_to_file(wordvec_unavailable):
    with open("wordvec_unavailable.txt","w") as f:
        for word in wordvec_unavailable:
            f.write(word+"\n")



def get_word_vectors(btw_words): # returns vector of embeddings of words
    word_vectors= []
    for word in btw_words:
        try:
            word_v = np.array(model[word])
            word_v = word_v.reshape(len(word_v),1)
            #print(word_v.shape)
            word_vectors.append(model[word])
        except:
            wordvec_unavailable.add(word)
    return word_vectors

def get_similarity(word_vectors,target_word): # sent(list of word vecs) to word similarity
    similarity = 0
    target_word_vector = 0
    try:
        target_word_vector = model[target_word]
    except:
        wordvec_unavailable.add(target_word+" t")
        return similarity
    target_word_sparse = gm.any2sparse(target_word_vector,eps=1e-09)
    for wv in word_vectors:
        wv_sparse = gm.any2sparse(wv, eps=1e-09)
        similarity = max(similarity,gm.cossim(wv_sparse,target_word_sparse))
    return similarity

# %%
import os
import re

stopwords_pattern = ' of| and| no| others| or| -|,|no '

def ltp(x):
    return '(' + '|'.join(x) + ')'

def create_LF_Based_On_Category_Name(debug=False):
    if os.path.exists("Category_Name_LFs.py"):
        os.remove("Category_Name_LFs.py")
        
    f = open("Category_Name_LFs.py","a+")
    for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])

        pattern = re.sub(stopwords_pattern , '', class_names[i].lower().strip())
        pattern= re.sub("( )+",",",pattern)
        pattern= re.sub(" $","",pattern)
        
        words = pattern.split(',')
        wordsStr = '['+','.join(['"'+x+'"' for x in words])+']'
        
        pattern = ltp(words)
        if(debug):
            print(pattern)
        f.write("\n")
        f.write(r'''def LF_Category_Name_'''+functionName+'''(c):
    words = '''+wordsStr+'''
    if(len(set(c['complaint_text']).intersection(words))>0):
            return ('''+str(i)+''',1)
    return (-1,0)''')
        f.write("\n")
    f.close()
    


    

def create_LF_Based_On_Keywords(debug=False):
    if os.path.exists("KeyWord_Based_LFs.py"):
        os.remove("KeyWord_Based_LFs.py")
    f = open("KeyWord_Based_LFs.py","a+")
    for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        
        pattern = re.sub(stopwords_pattern , '', class_names[i].lower().strip())
        pattern= re.sub("( )+",",",pattern)
      
        words = pattern.split(',')
        ##### add keywords #####
        
        words = words+ keywords[class_names[i]]
        ####
        wordsStr = '['+','.join(['"'+x+'"' for x in words])+']'
        
        pattern = ltp(words)
        if(debug):
            print(pattern)
        f.write("\n")
        f.write(r'''def LF_KeyWord_'''+functionName+'''(c):
    words = '''+wordsStr+'''
    if(len(set(c['complaint_text']).intersection(words))>0):
            return ('''+str(i)+''',1)
    return (-1,0)''')
        f.write("\n")
    f.close()
    
def create_LF_Extracts_Phrases_Regex(debug=False):
    if os.path.exists("Regex_Based_Extracts_Phrases_LFs.py"):
        os.remove("Regex_Based_Extracts_Phrases_LFs.py")
    f = open("Regex_Based_Extracts_Phrases_LFs.py","a+")
    for i in range(len(class_names)):
        if(class_names[i] in extracts_df.index.tolist()):
            functionName = re.sub(r'( )+|-|,','',class_names[i])

            pattern = re.sub(stopwords_pattern , '', class_names[i].lower().strip())
            pattern= re.sub("( )+",",",pattern)

            words = pattern.split(',')
            ##### add keywords #####

            words = words+ keywords[class_names[i]]
            ####
            wordsStr = '['+','.join(['"'+x+'"' for x in words])+']'


            if(debug):
                print(pattern)
            f.write("\n")
            f.write(r'''def LF_Extract_Phrase_Regex_'''+functionName+'''(c):
   
    pattern = \''''+extracts_df.loc[class_names[i]]['complaint words']+'''\'
    if(re.search(pattern,c['complaint_description'],flags=re.I)):
            return ('''+str(i)+''',1)
    return (-1,0)''')
            f.write("\n")
    f.close()
    
def create_LF_Description_Regex(debug=False):
    if os.path.exists("Regex_Based_Description_LFs.py"):
        os.remove("Regex_Based_Description_LFs.py")
    f = open("Regex_Based_Description_LFs.py","a+")
    for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        
        pattern = re.sub(stopwords_pattern , '', class_names[i].lower().strip())
        pattern= re.sub("( )+",",",pattern)
      
        words = pattern.split(',')
        ##### add keywords #####
        
        words = words+ keywords[class_names[i]]
        ####
        wordsStr = '['+','.join(['"'+x+'"' for x in words])+']'
        
       
        if(debug):
            print(pattern)
        f.write("\n")
        f.write(r'''def LF_Desc_Regex_'''+functionName+'''(c):
    words = '''+wordsStr+'''
    pattern = \''''+''.join(regexPatterns[class_names[i]])+'''\'
    if(re.search(pattern,c['complaint_description'],flags=re.I)):
            return ('''+str(i)+''',1)
    return (-1,0)''')
        f.write("\n")
    f.close()
    
    
    
def create_LF_Title_Regex(debug=False):
    if os.path.exists("Regex_Based_Title_LFs.py"):
        os.remove("Regex_Based_Title_LFs.py")
    f = open("Regex_Based_Title_LFs.py","a+")
    for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        
        pattern = re.sub(stopwords_pattern , '', class_names[i].lower().strip())
        pattern= re.sub("( )+",",",pattern)
      
        words = pattern.split(',')
        ##### add keywords #####
        
        words = words+ keywords[class_names[i]]
        ####
        wordsStr = '['+','.join(['"'+x+'"' for x in words])+']'
        
        pattern = ltp(words)
        if(debug):
            print(pattern)
        f.write("\n")
        f.write(r'''def LF_Title_Regex_'''+functionName+'''(c):
    words = '''+wordsStr+'''
    pattern = \''''+ ''.join(regexPatterns[class_names[i]]) +'''\'
    if(re.search(pattern,c['complaint_title'],flags=re.I)):
            return ('''+str(i)+''',1)
    return (-1,0)''')
        f.write("\n")
    f.close()


def create_LF_Based_On_Embeddings(debug=False):
    if os.path.exists("Embeddings_Based_LFs.py"):
        os.remove("Embeddings_Based_LFs.py")
    f = open("Embeddings_Based_LFs.py","a+")
    for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        
        pattern = re.sub(stopwords_pattern, '', class_names[i].lower().strip())
        pattern= re.sub("( )+",",",pattern)
      
        words = pattern.split(',')
       
        
        words = words+ keywords[class_names[i]]
        ####
        wordsStr = '['+','.join(['"'+x+'"' for x in words])+']'
        
        pattern = ltp(words)
        if(debug):
            print(pattern)

        f.write("\n")
        f.write(r'''def LF_Embedding_'''+functionName+'''(c):
    words = '''+wordsStr+'''
    sc = 0
    word_vectors = get_word_vectors(c['complaint_text'])
    for ow in words:
        sc=max(sc,get_similarity(word_vectors,ow))
    return ('''+str(i)+''',sc)''')
        f.write("\n")
    f.close()

def create_LF_Based_On_Embeddings_Title(debug=False):
    if os.path.exists("Title_Embeddings_Based_LFs.py"):
        os.remove("Title_Embeddings_Based_LFs.py")
    f = open("Title_Embeddings_Based_LFs.py","a+")
    for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        
        pattern = re.sub(stopwords_pattern, '', class_names[i].lower().strip())
        pattern= re.sub("( )+",",",pattern)
      
        words = pattern.split(',')
       
        
        words = words+ keywords[class_names[i]]
        ####
        wordsStr = '['+','.join(['"'+x+'"' for x in words])+']'
        
        pattern = ltp(words)
        if(debug):
            print(pattern)

        f.write("\n")
        f.write(r'''def LF_Title_Embedding_'''+functionName+'''(c):
    words = '''+wordsStr+'''
    sc = 0
    word_vectors = get_word_vectors(c['complaint_title'].lower().split())
    for ow in words:
        sc=max(sc,get_similarity(word_vectors,ow))
    return ('''+str(i)+''',sc)''')
        f.write("\n")
    f.close()

def create_LF_Based_On_Embeddings_Description(debug=False):
    if os.path.exists("Description_Embeddings_Based_LFs.py"):
        os.remove("Description_Embeddings_Based_LFs.py")
    f = open("Description_Embeddings_Based_LFs.py","a+")
    for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        
        pattern = re.sub(stopwords_pattern, '', class_names[i].lower().strip())
        pattern= re.sub("( )+",",",pattern)
      
        words = pattern.split(',')
       
        
        words = words+ keywords[class_names[i]]
        ####
        wordsStr = '['+','.join(['"'+x+'"' for x in words])+']'
        
        pattern = ltp(words)
        if(debug):
            print(pattern)

        f.write("\n")
        f.write(r'''def LF_Description_Embedding_'''+functionName+'''(c):
    words = '''+wordsStr+'''
    sc = 0
    word_vectors = get_word_vectors(c['complaint_description'].lower().split())
    for ow in words:
        sc=max(sc,get_similarity(word_vectors,ow))
    return ('''+str(i)+''',sc)''')
        f.write("\n")
    f.close()


def create_LF_Based_On_TFIDF(debug=False):
    if os.path.exists("TFIDF_Based_LFs.py"):
        os.remove("TFIDF_Based_LFs.py")
    f = open("TFIDF_Based_LFs.py","a+")
    for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])       
               
        f.write("\n")
        f.write(r'''def LF_TFIDF_{}(c):
    sc = cosine_similarity(class_words_tfidf['{}'],tfidf_matrix[c.name+{}])
    return ({},sc)'''.format(functionName,class_names[i],len(class_names),i))
        f.write("\n")
    f.close()

# %%
LF_Names = []
LF_output_map = dict()
LF_l = []

create_LF_Title_Regex()
create_LF_Description_Regex()
# create_LF_Based_On_Keywords()
# create_LF_Extracts_Phrases_Regex()
# create_LF_Based_On_Category_Name()
# create_LF_Based_On_Embeddings()
# create_LF_Based_On_TFIDF()
# create_LF_Based_On_Embeddings_Title()
# create_LF_Based_On_Embeddings_Description()



        
# for i in range(len(class_names)):
#         functionName = re.sub(r'( )+|-|,','',class_names[i])
#         LF_Names.append('LF_Category_Name_'+functionName)
#         LF_output_map['LF_Category_Name_'+functionName]=i
#         LF_l.append(i)
        
# for i in range(len(class_names)):
#         functionName = re.sub(r'( )+|-|,','',class_names[i])
#         LF_Names.append('LF_Embedding_'+functionName)
#         LF_output_map['LF_Embedding_'+functionName]=i
        

        
# for i in range(len(class_names)):
#         functionName = re.sub(r'( )+|-|,','',class_names[i])
#         LF_Names.append('LF_TFIDF_'+functionName)
#         LF_output_map['LF_TFIDF_'+functionName]=i

for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        LF_Names.append('LF_KeyWord_'+functionName)
        LF_output_map['LF_KeyWord_'+functionName]=i
        LF_l.append(i)

for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        LF_Names.append('LF_Title_Regex_'+functionName)
        LF_output_map['LF_Title_Regex_'+functionName]=i
        LF_l.append(i)

for i in range(len(class_names)):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        LF_Names.append('LF_Desc_Regex_'+functionName)
        LF_output_map['LF_Desc_Regex_'+functionName]=i
        LF_l.append(i)

for i in range(len(class_names)):
    if(class_names[i] in extracts_df.index.tolist()):
        functionName = re.sub(r'( )+|-|,','',class_names[i])
        LF_Names.append('LF_Extract_Phrase_Regex_'+functionName)
        LF_output_map['LF_Extract_Phrase_Regex_'+functionName]=i
        LF_l.append(i)
        
# for i in range(len(class_names)):
#         functionName = re.sub(r'( )+|-|,','',class_names[i])
#         LF_Names.append('LF_Title_Embedding_'+functionName)
#         LF_output_map['LF_Title_Embedding_'+functionName]=i
#         LF_l.append(i)
        
# for i in range(len(class_names)):
#         functionName = re.sub(r'( )+|-|,','',class_names[i])
#         LF_Names.append('LF_Description_Embedding_'+functionName)
#         LF_output_map['LF_Description_Embedding_'+functionName]=i
#         LF_l.append(i)
 

        

print('['+','.join(LF_Names)+']')
# Out:
# [LF_KeyWord_AirPollution,LF_KeyWord_AutorickshawsandTaxis,LF_KeyWord_BMTCDriverorConductor,LF_KeyWord_BMTCNeednewBusRoute,LF_KeyWord_BMTCOthers,LF_KeyWord_BadRoads,LF_KeyWord_BrokenStormWaterDrains,LF_KeyWord_Cattle,LF_KeyWord_ClearingofBlockageofUnderGroundDrainagePipelinesandReplacementofDamagedorMissingManholeCover,LF_KeyWord_DesiltingLakes,LF_KeyWord_Diseases,LF_KeyWord_Electricity,LF_KeyWord_FloodingofRoadsandFootpaths,LF_KeyWord_Footpaths,LF_KeyWord_Garbage,LF_KeyWord_GovernmentLandEncroachment,LF_KeyWord_HawkersandVendors,LF_KeyWord_Hoardings,LF_KeyWord_IllegalpostersandHoardings,LF_KeyWord_LakesOthers,LF_KeyWord_MaintenanceofRoadsandFootpathsOthers,LF_KeyWord_Manholes,LF_KeyWord_Mosquitos,LF_KeyWord_NeedNewStreetlights,LF_KeyWord_NeedNewToilets,LF_KeyWord_NewBusShelters,LF_KeyWord_NoSewageDrains,LF_KeyWord_NoisePollution,LF_KeyWord_Others,LF_KeyWord_OverflowofStormWaterDrains,LF_KeyWord_ParkingViolations,LF_KeyWord_Parksandplaygrounds,LF_KeyWord_Potholes,LF_KeyWord_PublicNuisance,LF_KeyWord_Repairofstreetlights,LF_KeyWord_SewageandStormWaterDrainsOthers,LF_KeyWord_StrayDogs,LF_KeyWord_Traffic,LF_KeyWord_TreesParksandPlaygroundsOthers,LF_KeyWord_UnauthorizedConstruction,LF_KeyWord_WaterLeakage,LF_KeyWord_WaterSupply,LF_Title_Regex_AirPollution,LF_Title_Regex_AutorickshawsandTaxis,LF_Title_Regex_BMTCDriverorConductor,LF_Title_Regex_BMTCNeednewBusRoute,LF_Title_Regex_BMTCOthers,LF_Title_Regex_BadRoads,LF_Title_Regex_BrokenStormWaterDrains,LF_Title_Regex_Cattle,LF_Title_Regex_ClearingofBlockageofUnderGroundDrainagePipelinesandReplacementofDamagedorMissingManholeCover,LF_Title_Regex_DesiltingLakes,LF_Title_Regex_Diseases,LF_Title_Regex_Electricity,LF_Title_Regex_FloodingofRoadsandFootpaths,LF_Title_Regex_Footpaths,LF_Title_Regex_Garbage,LF_Title_Regex_GovernmentLandEncroachment,LF_Title_Regex_HawkersandVendors,LF_Title_Regex_Hoardings,LF_Title_Regex_IllegalpostersandHoardings,LF_Title_Regex_LakesOthers,LF_Title_Regex_MaintenanceofRoadsandFootpathsOthers,LF_Title_Regex_Manholes,LF_Title_Regex_Mosquitos,LF_Title_Regex_NeedNewStreetlights,LF_Title_Regex_NeedNewToilets,LF_Title_Regex_NewBusShelters,LF_Title_Regex_NoSewageDrains,LF_Title_Regex_NoisePollution,LF_Title_Regex_Others,LF_Title_Regex_OverflowofStormWaterDrains,LF_Title_Regex_ParkingViolations,LF_Title_Regex_Parksandplaygrounds,LF_Title_Regex_Potholes,LF_Title_Regex_PublicNuisance,LF_Title_Regex_Repairofstreetlights,LF_Title_Regex_SewageandStormWaterDrainsOthers,LF_Title_Regex_StrayDogs,LF_Title_Regex_Traffic,LF_Title_Regex_TreesParksandPlaygroundsOthers,LF_Title_Regex_UnauthorizedConstruction,LF_Title_Regex_WaterLeakage,LF_Title_Regex_WaterSupply,LF_Desc_Regex_AirPollution,LF_Desc_Regex_AutorickshawsandTaxis,LF_Desc_Regex_BMTCDriverorConductor,LF_Desc_Regex_BMTCNeednewBusRoute,LF_Desc_Regex_BMTCOthers,LF_Desc_Regex_BadRoads,LF_Desc_Regex_BrokenStormWaterDrains,LF_Desc_Regex_Cattle,LF_Desc_Regex_ClearingofBlockageofUnderGroundDrainagePipelinesandReplacementofDamagedorMissingManholeCover,LF_Desc_Regex_DesiltingLakes,LF_Desc_Regex_Diseases,LF_Desc_Regex_Electricity,LF_Desc_Regex_FloodingofRoadsandFootpaths,LF_Desc_Regex_Footpaths,LF_Desc_Regex_Garbage,LF_Desc_Regex_GovernmentLandEncroachment,LF_Desc_Regex_HawkersandVendors,LF_Desc_Regex_Hoardings,LF_Desc_Regex_IllegalpostersandHoardings,LF_Desc_Regex_LakesOthers,LF_Desc_Regex_MaintenanceofRoadsandFootpathsOthers,LF_Desc_Regex_Manholes,LF_Desc_Regex_Mosquitos,LF_Desc_Regex_NeedNewStreetlights,LF_Desc_Regex_NeedNewToilets,LF_Desc_Regex_NewBusShelters,LF_Desc_Regex_NoSewageDrains,LF_Desc_Regex_NoisePollution,LF_Desc_Regex_Others,LF_Desc_Regex_OverflowofStormWaterDrains,LF_Desc_Regex_ParkingViolations,LF_Desc_Regex_Parksandplaygrounds,LF_Desc_Regex_Potholes,LF_Desc_Regex_PublicNuisance,LF_Desc_Regex_Repairofstreetlights,LF_Desc_Regex_SewageandStormWaterDrainsOthers,LF_Desc_Regex_StrayDogs,LF_Desc_Regex_Traffic,LF_Desc_Regex_TreesParksandPlaygroundsOthers,LF_Desc_Regex_UnauthorizedConstruction,LF_Desc_Regex_WaterLeakage,LF_De ...

# %%
# %load Regex_Based_Title_LFs.py

# %%
# %load Regex_Based_Description_LFs.py

# %%
LFs = [LF_Title_Regex_AirPollution,LF_Title_Regex_AutorickshawsandTaxis,LF_Title_Regex_BMTCDriverorConductor,LF_Title_Regex_BMTCNeednewBusRoute,LF_Title_Regex_BMTCOthers,LF_Title_Regex_BadRoads,LF_Title_Regex_BrokenStormWaterDrains,LF_Title_Regex_Cattle,LF_Title_Regex_ClearingofBlockageofUnderGroundDrainagePipelinesandReplacementofDamagedorMissingManholeCover,LF_Title_Regex_DesiltingLakes,LF_Title_Regex_Diseases,LF_Title_Regex_Electricity,LF_Title_Regex_FloodingofRoadsandFootpaths,LF_Title_Regex_Footpaths,LF_Title_Regex_Garbage,LF_Title_Regex_GovernmentLandEncroachment,LF_Title_Regex_HawkersandVendors,LF_Title_Regex_Hoardings,LF_Title_Regex_IllegalpostersandHoardings,LF_Title_Regex_LakesOthers,LF_Title_Regex_MaintenanceofRoadsandFootpathsOthers,LF_Title_Regex_Manholes,LF_Title_Regex_Mosquitos,LF_Title_Regex_NeedNewStreetlights,LF_Title_Regex_NeedNewToilets,LF_Title_Regex_NewBusShelters,LF_Title_Regex_NoSewageDrains,LF_Title_Regex_NoisePollution,LF_Title_Regex_Others,LF_Title_Regex_OverflowofStormWaterDrains,LF_Title_Regex_ParkingViolations,LF_Title_Regex_Parksandplaygrounds,LF_Title_Regex_Potholes,LF_Title_Regex_PublicNuisance,LF_Title_Regex_Repairofstreetlights,LF_Title_Regex_SewageandStormWaterDrainsOthers,LF_Title_Regex_StrayDogs,LF_Title_Regex_Traffic,LF_Title_Regex_TreesParksandPlaygroundsOthers,LF_Title_Regex_UnauthorizedConstruction,LF_Title_Regex_WaterLeakage,LF_Title_Regex_WaterSupply,LF_Desc_Regex_AirPollution,LF_Desc_Regex_AutorickshawsandTaxis,LF_Desc_Regex_BMTCDriverorConductor,LF_Desc_Regex_BMTCNeednewBusRoute,LF_Desc_Regex_BMTCOthers,LF_Desc_Regex_BadRoads,LF_Desc_Regex_BrokenStormWaterDrains,LF_Desc_Regex_Cattle,LF_Desc_Regex_ClearingofBlockageofUnderGroundDrainagePipelinesandReplacementofDamagedorMissingManholeCover,LF_Desc_Regex_DesiltingLakes,LF_Desc_Regex_Diseases,LF_Desc_Regex_Electricity,LF_Desc_Regex_FloodingofRoadsandFootpaths,LF_Desc_Regex_Footpaths,LF_Desc_Regex_Garbage,LF_Desc_Regex_GovernmentLandEncroachment,LF_Desc_Regex_HawkersandVendors,LF_Desc_Regex_Hoardings,LF_Desc_Regex_IllegalpostersandHoardings,LF_Desc_Regex_LakesOthers,LF_Desc_Regex_MaintenanceofRoadsandFootpathsOthers,LF_Desc_Regex_Manholes,LF_Desc_Regex_Mosquitos,LF_Desc_Regex_NeedNewStreetlights,LF_Desc_Regex_NeedNewToilets,LF_Desc_Regex_NewBusShelters,LF_Desc_Regex_NoSewageDrains,LF_Desc_Regex_NoisePollution,LF_Desc_Regex_Others,LF_Desc_Regex_OverflowofStormWaterDrains,LF_Desc_Regex_ParkingViolations,LF_Desc_Regex_Parksandplaygrounds,LF_Desc_Regex_Potholes,LF_Desc_Regex_PublicNuisance,LF_Desc_Regex_Repairofstreetlights,LF_Desc_Regex_SewageandStormWaterDrainsOthers,LF_Desc_Regex_StrayDogs,LF_Desc_Regex_Traffic,LF_Desc_Regex_TreesParksandPlaygroundsOthers,LF_Desc_Regex_UnauthorizedConstruction,LF_Desc_Regex_WaterLeakage,LF_Desc_Regex_WaterSupply]

# %%
# pkl.dump(LF_Names,open("LF_Names_245.p","wb"))
# pkl.dump(LF_output_map,open("LF_output_map_245.p","wb"))
# pkl.dump(LF_l,open("LF_l_245.p","wb"))

pkl.dump(LF_Names,open("LF_Names_161.p","wb"))
pkl.dump(LF_output_map,open("LF_output_map_161.p","wb"))
pkl.dump(LF_l,open("LF_l_161.p","wb"))
print(len(LF_Names),len(LF_output_map),len(LF_l))
# Out:
# 161 161 161

# %%
def get_L_S_Tensor(df,msg):     
    L_S = []
    print('labelling ',msg,' data')
    for i in range(len(df.index)):
        L_S_ci=[]
        L=[]
        S=[]
        P_ik = []
        for LF in LFs:
#             print(i,LF.__name__)            
            l,s = LF(df.iloc[i])
            L.append(l)
            S.append((s+1)/2)  #to scale scores in [0,1] 
        L_S_ci.append(L)
        L_S_ci.append(S)
        L_S.append(L_S_ci) 
        if(i%500==0 and i!=0):
            print(str(i)+'data points labelled in',(time.time() - start_time)/60,'mins')
        
    return L_S


import time
import datetime
start_time = time.time()

lt = time.localtime()

print("started at: {}-{}-{}, {}:{}:{}".format(lt.tm_mday,lt.tm_mon,lt.tm_year,lt.tm_hour,lt.tm_min,lt.tm_sec))

# val_L_S = get_L_S_Tensor(val_df)

# pkl.dump(val_L_S,open("val_L_S.p","wb"))

# test_L_S = get_L_S_Tensor(test_df,'test')
# pkl.dump(test_L_S,open("test_L_S_TFIDF.p","wb"))

# train_L_S = get_L_S_Tensor(train_df,'train')
# pkl.dump(train_L_S,open("train_L_S_TFIDF.p","wb"))


# train_L_S = get_L_S_Tensor(train_df,'keywords train')
# pkl.dump(train_L_S,open("train_L_S_Keywords.p","wb"))

# test_L_S = get_L_S_Tensor(test_df,'keywords test')
# pkl.dump(test_L_S,open("test_L_S_Keywords_regex_extracts.p","wb"))

# train_L_S = get_L_S_Tensor(train_df,'keywords train')
# pkl.dump(train_L_S,open("train_L_S_Keywords_regex_extracts.p","wb"))

test_L_S = get_L_S_Tensor(test_df,'regex test')
pkl.dump(test_L_S,open("test_L_S_regex.p","wb"))

train_L_S = get_L_S_Tensor(train_df,'regex train')
pkl.dump(train_L_S,open("train_L_S_regex.p","wb"))


# test_L_S = get_L_S_Tensor(test_df,'embeddings test')
# pkl.dump(test_L_S,open("test_L_S_Embeddings.p","wb"))

# test_L_S = get_L_S_Tensor(test_df,'T and D embeddings test')
# pkl.dump(test_L_S,open("test_L_S_T-D_Embeddings.p","wb"))



# train_L_S = get_L_S_Tensor(train_df,'embeddings train')
# pkl.dump(train_L_S,open("train_L_S_Embeddings.p","wb"))

# train_L_S = get_L_S_Tensor(train_df,'T and D embeddings train')
# pkl.dump(train_L_S,open("train_L_S_T-D_Embeddings.p","wb"))

# gold_L_S = get_L_S_Tensor(gold_df,'gold-labels-clean')
# pkl.dump(gold_L_S,open("gold-labels-clean.p","wb"))


print(str(datetime.timedelta(seconds=time.time() - start_time)))
# Out:
# started at: 14-5-2018, 17:34:3
# labelling  keywords test  data
# 500data points labelled in 0.0825196623802185 mins
# 1000data points labelled in 0.1646123170852661 mins
# 1500data points labelled in 0.24780991474787395 mins
# 2000data points labelled in 0.33310418923695884 mins
# 2500data points labelled in 0.4195414463678996 mins
# 3000data points labelled in 0.5027475953102112 mins
# 3500data points labelled in 0.5834892471631368 mins
# 4000data points labelled in 0.6665494680404663 mins
# 4500data points labelled in 0.7496981739997863 mins
# 5000data points labelled in 0.8299444238344829 mins
# 5500data points labelled in 0.9106906294822693 mins
# 6000data points labelled in 0.9915045777956645 mins
# 6500data points labelled in 1.0725292364756267 mins
# labelling  regex test  data
# 500data points labelled in 1.1809990525245666 mins
# 1000data points labelled in 1.2610489487648011 mins
# 1500data points labelled in 1.3414787213007608 mins
# 2000data points labelled in 1.422957138220469 mins
# 2500data points labelled in 1.5047119379043579 mins
# 3000data points labelled in 1.5854538202285766 mins
# 3500data points labelled in 1.669091558456421 mins
# 4000data points labelled in 1.7543184558550518 mins
# 4500data points labelled in 1.836054786046346 mins
# 5000data points labelled in 1.9167758544286093 mins
# 5500data points labelled in 1.9974491755167643 mins
# 6000data points labelled in 2.076659417152405 mins
# 6500data points labelled in 2.1560493628184 mins
# labelling  regex train  data
# 500data points labelled in 2.2833834012349445 mins
# 1000data points labelled in 2.382256631056468 mins
# 1500data points labelled in 2.4826095779736836 mins
# 2000data points labelled in 2.5830373565355935 mins
# 2500data points labelled in 2.683756645520528 mins
# 3000data points labelled in 2.7841681321461995 mins
# 3500data points labelled in 2.884035853544871 mins
# 4000data points labelled in 2.9836360216140747 mins
# 4500data points labelled in 3.0831919511159263 mins
# 5000data points labelled in 3.183048903942108 mins
# 5500data points labelled in 3.2831554651260375 mins
# 6000data points labelled in 3.382984725634257 mins
# 6500data points labelled in 3.482662347952525 mins
# 7000data points labelled in 3.5835821350415547 mins
# 7500data points labelled in 3.6834936857223513 mins
# 8000data points labelled in 3.784007493654887 mins
# 8500data points labelled in 3.88388192653656 mins
# 9000data points labelled in 3.9839855154355366 mins
# 9500data points labelled in 4.084203406174978 mins
# 10000data points labelled in 4.184512829780578 mins
# 10500data points labelled in 4.2845890084902445 mins
# 11000data points labelled in 4.384671707948049 mins
# 11500data points labelled in 4.484723401069641 mins
# 12000data points labelled in 4.584211353460947 mins
# 12500data points labelled in 4.685167582829793 mins
# 13000data points labelled in 4.785454452037811 mins
# 13500data points labelled in 4.885680858294169 mins
# 14000data points labelled in 4.985021166006724 mins
# 14500data points labelled in 5.0843612313270565 mins
# 15000data points labelled in 5.183458356062571 mins
# 15500data points labelled in 5.282552742958069 mins
# 16000data points labelled in 5.381659154097239 mins
# 16500data points labelled in 5.4805182377497355 mins
# 17000data points labelled in 5.579563331604004 mins
# 17500data points labelled in 5.678342763582865 mins
# 18000data points labelled in 5.777133464813232 mins
# 18500data points labelled in 5.876069235801697 mins
# 19000data points labelled in 5.975949692726135 mins
# 19500data points labelled in 6.076853493849437 mins
# 20000data points labelled in 6.175228969256083 mins
# 20500data points labelled in 6.274388202031454 mins
# 21000data points labelled in 6.373405877749125 mins
# 21500data points labelled in 6.472270810604096 mins
# 22000data points labelled in 6.571534045537313 mins
# 22500data points labelled in 6.671149746576945 mins
# 23000data points labelled in 6.770211414496104 mins
# 23500data points labelled in 6.869332261880239 mins
# 24000data points labelled in 6.9679646770159405 mins
# 24500data points labelled in 7.066977898279826 mins
# 25000data points labelled in 7.166479198137919 mins
# 25500data points labelled in 7.265947266419729 mins
# 26000data points labelled in 7.3646899342536924 mins
# 26500data points labelled in 7.463628164927164 mins
# 27000data points labelled in 7.562510613600413 mins
# 27500data points labelled in 7.661165257294972 mins
# 28000data points labelled in 7.761545805136363 mins
# 28500data points labelled in 7.860293646653493 mins
# 29000data points labelled in 7.95924901564916 mins
# 29500data points labelled in 8.058190937836965 mins
# 30000data points labelled in 8.157143326600393 mins
# 30500data points labelled in 8.256040632724762 mins
# 31000data points labelled in 8.355292785167695 mins
# 31500data points labelled in 8.458208763599396 mins
# 32000data points labelled in 8.562572781244914 mins
# 32500data points labelled in 8.664879337946575 mins
# 33000data points labelled in 8.764741289615632 mins
# 33500data points labelled in 8.863787813981373 mins
# 34000data points labelled in 8.962402749061585 mins
# 34500data points labelled in 9.060928388436635 mins
# 35000data points labelled in 9.159773484865825 mins
# 35500data points labelled in 9.258654816945393 mins
# 36000data points labelled in 9.357519245147705 mins
# 36500data points labelled in 9.45594494342804 mins
# 37000data points labelled in 9.554562242825826 mins
# 37500data points labelled in 9.652786982059478 mins
# 0:09:40.469003

# %%
# import sys
# !{sys.executable} -m pip install tensorflow
# !type python
# Out:
# python is /usr/bin/python

# %%
pkl.dump(val_L_S,open("val_L_S.p","wb"),protocol=2)
pkl.dump(train_L_S,open("train_L_S.p","wb"),protocol=2)
pkl.dump(test_L_S,open("test_L_S.p","wb"),protocol=2)

# %%
import numpy as np
from scipy.sparse.csr import csr_matrix #need this if you want to save tfidf_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def process(s):
    return ''.join([i for i in s if not i.isdigit() and i not in '_' ]).lower()
    
vectorizer = TfidfVectorizer(preprocessor=process)
tfidf_matrix = vectorizer.fit_transform(class_words+train_df['complaint_description'].tolist())

# %%
print(len(vectorizer.vocabulary_))
idf = vectorizer.idf_
d = dict(zip(vectorizer.get_feature_names(), idf))

from collections import OrderedDict
d = OrderedDict(sorted(d.items(),key=lambda kv: kv[1], reverse=True))
# for x in d.items():
#     print(x)
for c in class_names:
    for w in re.sub('-|,','',c.lower()).split():
        if w in d.keys():
            print(w,d[w])
        else:
            print(w,'not in vocabulary')
# Out:
# 31917
# air 5.655315363914983
# pollution 5.31884312729377
# autorickshaws 8.397851741088363
# and 1.5476140735768542
# taxis 7.731372807610579
# bmtc 4.515745496698209
# driver 5.912945091300362
# or 3.328616577422118
# conductor 6.798995937984799
# bmtc 4.515745496698209
# need 3.961411684690687
# new 4.3365017010013
# bus 3.5158475847987893
# route 4.549946292783993
# bmtc 4.515745496698209
# others 6.090017292208173
# bad 3.5015842685054035
# roads 3.1803449207861125
# broken 4.996654359426207
# storm 5.615442972667606
# water 3.3725871369761475
# drains 5.31884312729377
# cattle 7.065624601238747
# clearing 6.588700529148438
# of 1.6403075439294033
# blockage 6.717317906970532
# of 1.6403075439294033
# under 4.774212808842828
# ground 5.10984270370428
# drainage 4.429547899761626
# pipelines 7.316939029519654
# and 1.5476140735768542
# replacement 8.164236889906856
# of 1.6403075439294033
# damaged 4.847025164317795
# or 3.328616577422118
# missing 6.777942528786967
# manhole 6.154904914414048
# cover 5.882705206110644
# desilting 8.703233390639543
# lakes 7.492143118544744
# diseases 5.445136852618062
# electricity 6.177504746331289
# flooding 7.231416856081491
# of 1.6403075439294033
# roads 3.1803449207861125
# and 1.5476140735768542
# footpaths 5.461757733854102
# footpaths 5.461757733854102
# garbage 2.6811703600319223
# government 5.271552992252313
# land 5.510408242971286
# encroachment 6.842481049924538
# hawkers 7.065624601238747
# and 1.5476140735768542
# vendors 5.878458915229193
# hoardings 6.4981036337962115
# illegal 5.467359989402772
# posters 7.0248026067184925
# and 1.5476140735768542
# hoardings 6.4981036337962115
# lakes 7.492143118544744
# others 6.090017292208173
# maintenance 5.682808504495182
# of 1.6403075439294033
# roads 3.1803449207861125
# and 1.5476140735768542
# footpaths 5.461757733854102
# others 6.090017292208173
# manholes 7.051831279106412
# mosquitos 6.513976982952502
# need 3.961411684690687
# new 4.3365017010013
# streetlights 5.882705206110644
# need 3.961411684690687
# new 4.3365017010013
# toilets 6.911473921411489
# new 4.3365017010013
# bus 3.5158475847987893
# shelters 7.492143118544744
# no 2.55247833406383
# sewage 4.623277565869543
# drains 5.31884312729377
# noise 5.721889854537653
# pollution 5.31884312729377
# others 6.090017292208173
# overflow 6.757323241584231
# of 1.6403075439294033
# storm 5.615442972667606
# water 3.3725871369761475
# drains 5.31884312729377
# parking 4.637876365290696
# violations 7.353306673690528
# parks 6.459488797668432
# and 1.5476140735768542
# playgrounds 9.732852807820702
# potholes 3.6178440746212654
# public 4.20342372030928
# nuisance 5.348329292948233
# repair 4.747877260505025
# of 1.6403075439294033
# streetlights 5.882705206110644
# sewage 4.623277565869543
# and 1.5476140735768542
# storm 5.615442972667606
# water 3.3725871369761475
# drains 5.31884312729377
# others 6.090017292208173
# stray 3.9211131916594093
# dogs 3.4254832293171997
# traffic 2.947039199643808
# trees 6.127354962645817
# parks 6.459488797668432
# and 1.5476140735768542
# playgrounds 9.732852807820702
# others 6.090017292208173
# unauthorized 7.410465087530477
# construction 4.6946023466914735
# water 3.3725871369761475
# leakage 6.292434713005266
# water 3.3725871369761475
# supply 5.32613356055645

# %%
# feature_names = vectorizer.get_feature_names()
# print(len(feature_names))
# print((feature_names))


class_words_tfidf= dict()
for i,cat in enumerate(class_names):
    class_words_tfidf[cat] = tfidf_matrix.getrow(i)

# %%
def LF_KeyWord_AirPollution(c):
    words = ["air","pollution"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (0,1)
    return (-1,0)

def LF_KeyWord_AutorickshawsandTaxis(c):
    words = ["autorickshaws","taxis","taxi","auto","autorickshaw"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (1,1)
    return (-1,0)

def LF_KeyWord_BMTCDriverorConductor(c):
    words = ["bmtc","driver","conductor"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (2,1)
    return (-1,0)

def LF_KeyWord_BMTCNeednewBusRoute(c):
    words = ["bmtc","need","new","bus","route"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (3,1)
    return (-1,0)

def LF_KeyWord_BMTCOthers(c):
    words = ["bmtc"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (4,1)
    return (-1,0)

def LF_KeyWord_BadRoads(c):
    words = ["bad","roads","road"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (5,1)
    return (-1,0)

def LF_KeyWord_BrokenStormWaterDrains(c):
    words = ["broken","storm","water","drains","overflow","drainage"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (6,1)
    return (-1,0)

def LF_KeyWord_Cattle(c):
    words = ["cattle","cows","buffaloes","goats"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (7,1)
    return (-1,0)

def LF_KeyWord_ClearingofBlockageofUnderGroundDrainagePipelinesandReplacementofDamagedorMissingManholeCover(c):
    words = ["clearing","blockage","under","ground","drainage","pipelines","replacement","damaged","missing","manhole","cover"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (8,1)
    return (-1,0)

def LF_KeyWord_DesiltingLakes(c):
    words = ["desilting","lakes"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (9,1)
    return (-1,0)

def LF_KeyWord_Diseases(c):
    words = ["diseases","malaria","dengue","cholera"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (10,1)
    return (-1,0)

def LF_KeyWord_Electricity(c):
    words = ["electricity","power","current","power cut"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (11,1)
    return (-1,0)

def LF_KeyWord_FloodingofRoadsandFootpaths(c):
    words = ["flooding","roads","footpaths","water","flood","floods"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (12,1)
    return (-1,0)

def LF_KeyWord_Footpaths(c):
    words = ["footpaths","footpath"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (13,1)
    return (-1,0)

def LF_KeyWord_Garbage(c):
    words = ["garbage","waste","plastic","dirt"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (14,1)
    return (-1,0)

def LF_KeyWord_GovernmentLandEncroachment(c):
    words = ["government","land","encroachment","occupy","illegal"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (15,1)
    return (-1,0)

def LF_KeyWord_HawkersandVendors(c):
    words = ["hawkers","vendors"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (16,1)
    return (-1,0)

def LF_KeyWord_Hoardings(c):
    words = ["hoardings","advertisements"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (17,1)
    return (-1,0)

def LF_KeyWord_IllegalpostersandHoardings(c):
    words = ["illegal","posters","hoardings"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (18,1)
    return (-1,0)

def LF_KeyWord_LakesOthers(c):
    words = ["lakes","lake"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (19,1)
    return (-1,0)

def LF_KeyWord_MaintenanceofRoadsandFootpathsOthers(c):
    words = ["maintenance","roads","footpaths"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (20,1)
    return (-1,0)

def LF_KeyWord_Manholes(c):
    words = ["manholes","manhole","man hole"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (21,1)
    return (-1,0)

def LF_KeyWord_Mosquitos(c):
    words = ["mosquitos","mosquitoes"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (22,1)
    return (-1,0)

def LF_KeyWord_NeedNewStreetlights(c):
    words = ["need","new","streetlights","streetlight","light","new streetlight"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (23,1)
    return (-1,0)

def LF_KeyWord_NeedNewToilets(c):
    words = ["need","new","toilets","toilet"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (24,1)
    return (-1,0)

def LF_KeyWord_NewBusShelters(c):
    words = ["new","bus","shelters","shelter"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (25,1)
    return (-1,0)

def LF_KeyWord_NoSewageDrains(c):
    words = ["sewage","drains","drainage"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (26,1)
    return (-1,0)

def LF_KeyWord_NoisePollution(c):
    words = ["noise","pollution","siren","speakers","speakers","loud"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (27,1)
    return (-1,0)

def LF_KeyWord_Others(c):
    words = ["others"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (28,1)
    return (-1,0)

def LF_KeyWord_OverflowofStormWaterDrains(c):
    words = ["overflow","storm","water","drains","pipes"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (29,1)
    return (-1,0)

def LF_KeyWord_ParkingViolations(c):
    words = ["parking","violations"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (30,1)
    return (-1,0)

def LF_KeyWord_Parksandplaygrounds(c):
    words = ["parks","playgrounds","park","play","playground"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (31,1)
    return (-1,0)

def LF_KeyWord_Potholes(c):
    words = ["potholes","holes","pothole"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (32,1)
    return (-1,0)

def LF_KeyWord_PublicNuisance(c):
    words = ["public","nuisance"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (33,1)
    return (-1,0)

def LF_KeyWord_Repairofstreetlights(c):
    words = ["repair","streetlights","streetlight","light","broken","damaged"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (34,1)
    return (-1,0)

def LF_KeyWord_SewageandStormWaterDrainsOthers(c):
    words = ["sewage","storm","water","drains","drainage"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (35,1)
    return (-1,0)

def LF_KeyWord_StrayDogs(c):
    words = ["stray","dogs","dog"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (36,1)
    return (-1,0)

def LF_KeyWord_Traffic(c):
    words = ["traffic","vehicles"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (37,1)
    return (-1,0)

def LF_KeyWord_TreesParksandPlaygroundsOthers(c):
    words = ["trees","parks","playgrounds","tree"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (38,1)
    return (-1,0)

def LF_KeyWord_UnauthorizedConstruction(c):
    words = ["unauthorized","construction"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (39,1)
    return (-1,0)

def LF_KeyWord_WaterLeakage(c):
    words = ["water","leakage"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (40,1)
    return (-1,0)

def LF_KeyWord_WaterSupply(c):
    words = ["water","supply"]
    if(len(set(c['complaint_text']).intersection(words))>0):
            return (41,1)
    return (-1,0)
