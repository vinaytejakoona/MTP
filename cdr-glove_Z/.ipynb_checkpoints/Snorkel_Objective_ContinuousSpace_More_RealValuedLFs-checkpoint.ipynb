# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from snorkel import SnorkelSession

session = SnorkelSession()

from snorkel.models import candidate_subclass

ChemicalDisease = candidate_subclass('ChemicalDisease', ['chemical', 'disease'])

train_cands = session.query(ChemicalDisease).filter(ChemicalDisease.split == 0).all()
dev_cands = session.query(ChemicalDisease).filter(ChemicalDisease.split == 1).all()

# %%
from gensim.parsing.preprocessing import STOPWORDS
import gensim.matutils as gm

from gensim.models.keyedvectors import KeyedVectors

# Load pretrained model (since intermediate data is not included, the model cannot be refined with additional data)
model = KeyedVectors.load_word2vec_format('../glove_w2v.txt', binary=False)  # C binary format


wordvec_unavailable= set()
def write_to_file(wordvec_unavailable):
    with open("wordvec_unavailable.txt","w") as f:
        for word in wordvec_unavailable:
            f.write(word+"\n")

def preprocess(tokens):
    btw_words = [word for word in tokens if word not in STOPWORDS]
    btw_words = [word for word in btw_words if word.isalpha()]
    return btw_words

def get_word_vectors(btw_words): # returns vector of embeddings of words
    word_vectors= []
    for word in btw_words:
        try:
            word_v = np.array(model[word])
            word_v = word_v.reshape(len(word_v),1)
            #print(word_v.shape)
            word_vectors.append(model[word])
        except:
            wordvec_unavailable.add(word)
    return word_vectors

def get_similarity(word_vectors,target_word): # sent(list of word vecs) to word similarity
    similarity = 0
    target_word_vector = 0
    try:
        target_word_vector = model[target_word]
    except:
        wordvec_unavailable.add(target_word+" t")
        return similarity
    target_word_sparse = gm.any2sparse(target_word_vector,eps=1e-09)
    for wv in word_vectors:
        wv_sparse = gm.any2sparse(wv, eps=1e-09)
        similarity = max(similarity,gm.cossim(wv_sparse,target_word_sparse))
    return similarity

import bz2
from six.moves.cPickle import load

with bz2.BZ2File('data/ctd.pkl.bz2', 'rb') as ctd_f:
    ctd_unspecified, ctd_therapy, ctd_marker = load(ctd_f)

# %%
import numpy as np

def distanceCDfar(c):
    dist = 0
    chem_start, chem_end = c.chemical.get_word_start(), c.chemical.get_word_end()
    dis_start, dis_end = c.disease.get_word_start(), c.disease.get_word_end()
    if dis_start < chem_start:
        dist = chem_start - dis_end
    else:
        dist = dis_start - chem_end
    return dist/5000

def distanceCD(c):
    dist = 0
    chem_start, chem_end = c.chemical.get_word_start(), c.chemical.get_word_end()
    dis_start, dis_end = c.disease.get_word_start(), c.disease.get_word_end()
    if dis_start < chem_start:
        dist = chem_start - dis_end
    else:
        dist = dis_start - chem_end
    return (5000 - dist)/5000

def distanceCD_(c,l):
    dist = []
    for w in l:
        pattern = r'({{A}})(.*)('+w+r')(.*)({{B}})'
        matchObj = re.search(pattern, get_tagged_text(c), flags=re.I)
        if(matchObj):
            match_groups = matchObj.group(2,4)
            dist.append(max([len(mg) for mg in match_groups]))
    if(len(dist)>0):
        return (5000-min(dist))/5000
    return 0

def distanceDC_(c,l):
    dist = []
    for w in l:
        pattern = r'({{B}})(.*)('+w+r')(.*)({{A}})'
        matchObj = re.search(pattern, get_tagged_text(c), flags=re.I)
        if(matchObj):
            match_groups = matchObj.group(2,4)
            dist.append(max([len(mg) for mg in match_groups]))
    if(len(dist)>0):
        return (5000-min(dist))/5000
    return 0

def distanceDevFol(c):
    dist = 1000
    matchObj = re.search(r'(develop)(.*)({{B}})(.*)(following)(.*)({{A}})', get_tagged_text(c), flags=re.I)
    if(matchObj):
        match_groups = matchObj.group(2,4,6)
        dist = max([len(mg) for mg in match_groups])
    return (5000-dist)/5000
    

def levenshtein(source, target):
    if len(source) < len(target):
        return levenshtein(target, source)

    # So now we have len(source) >= len(target).
    if len(target) == 0:
        return len(source)

    # We call tuple() to force strings to be used as sequences
    # ('c', 'a', 't', 's') - numpy uses them as values by default.
    source = np.array(tuple(source))
    target = np.array(tuple(target))

    # We use a dynamic programming algorithm, but with the
    # added optimization that we only need the last two rows
    # of the matrix.
    previous_row = np.arange(target.size + 1)
    for s in source:
        # Insertion (target grows longer than source):
        current_row = previous_row + 1

        # Substitution or matching:
        # Target and source items are aligned, and either
        # are different (cost of 1), or are the same (cost of 0).
        current_row[1:] = np.minimum(
                current_row[1:],
                np.add(previous_row[:-1], target != s))

        # Deletion (target grows shorter than source):
        current_row[1:] = np.minimum(
                current_row[1:],
                current_row[0:-1] + 1)

        previous_row = current_row

    return previous_row[-1]

# %%
# import bz2
# from six.moves.cPickle import load

# with bz2.BZ2File('data/ctd.pkl.bz2', 'rb') as ctd_f:
#     ctd_unspecified, ctd_therapy, ctd_marker = load(ctd_f)
    
    
def cand_in_ctd_unspecified(c):
    return 1 if c.get_cids() in ctd_unspecified else 0

def cand_in_ctd_therapy(c):
    return 1 if c.get_cids() in ctd_therapy else 0

def cand_in_ctd_marker(c):
    return 1 if c.get_cids() in ctd_marker else 0

def LF_in_ctd_unspecified(c):
    if(cand_in_ctd_unspecified(c)==1):
        return (-1,1)
    else:
        return (0,0)

def LF_in_ctd_therapy(c):
    if(cand_in_ctd_therapy(c)==1):
        return (-1,1)
    else:
        return (0,0)

def LF_in_ctd_marker(c):
    if(cand_in_ctd_marker(c)==1):
        return (1,1)
    else:
        return (0,0)

# %%
from __future__ import division

def LF_closer_chem(c):
    # Get distance between chemical and disease
    chem_start, chem_end = c.chemical.get_word_start(), c.chemical.get_word_end()
    dis_start, dis_end = c.disease.get_word_start(), c.disease.get_word_end()
    if dis_start < chem_start:
        dist = chem_start - dis_end
    else:
        dist = dis_start - chem_end
    # Try to find chemical closer than @dist/2 in either direction
    sent = c.get_parent()
    closest_other_chem = float('inf')
    #print("LF_CHEM",len(sent.words),dis_end + dist // 2)
    for i in range(dis_end, min(len(sent.words), dis_end + dist // 2)):
        et, cid = sent.entity_types[i], sent.entity_cids[i]
        if et == 'Chemical' and cid != sent.entity_cids[chem_start]:
            return (-1,1)
    for i in range(max(0, dis_start - dist // 2), dis_start):
        et, cid = sent.entity_types[i], sent.entity_cids[i]
        if et == 'Chemical' and cid != sent.entity_cids[chem_start]:
            return (-1,1)
    return (0,0)

def LF_closer_dis(c):
    # Get distance between chemical and disease
    chem_start, chem_end = c.chemical.get_word_start(), c.chemical.get_word_end()
    dis_start, dis_end = c.disease.get_word_start(), c.disease.get_word_end()
    if dis_start < chem_start:
        dist = chem_start - dis_end
    else:
        dist = dis_start - chem_end
    # Try to find chemical disease than @dist/8 in either direction
    sent = c.get_parent()
    for i in range(chem_end, min(len(sent.words), chem_end + dist // 8)):
        et, cid = sent.entity_types[i], sent.entity_cids[i]
        if et == 'Disease' and cid != sent.entity_cids[dis_start]:
            return (-1,1)
    for i in range(max(0, chem_start - dist // 8), chem_start):
        et, cid = sent.entity_types[i], sent.entity_cids[i]
        if et == 'Disease' and cid != sent.entity_cids[dis_start]:
            return (-1,1)
    return (0,0)

# %%
from load_external_annotations import load_external_labels
load_external_labels(session, ChemicalDisease, split=1, annotator='gold')

from snorkel.annotations import load_gold_labels
L_gold_dev = load_gold_labels(session, annotator_name='gold', split=1)
L_gold_dev
# Out:
# AnnotatorLabels created: 0
# <888x1 sparse matrix of type '<type 'numpy.int64'>'
# 	with 888 stored elements in Compressed Sparse Row format>

# %%
#gold_labels_dev = [x[0,0] for x in L_gold_dev.todense()]
#for i,L in enumerate(gold_labels_dev):
#    print(i,gold_labels_dev[i])

gold_labels_dev = []
for i,L in enumerate(L_gold_dev):
    gold_labels_dev.append(L[0,0])
    
    
print(len(gold_labels_dev))
print(gold_labels_dev.count(1),gold_labels_dev.count(-1))
# Out:
# 888
# (296, 592)

# %%
def LF_ctd_marker_c_d(c):
    l,s = LF_c_d(c)
    return (l*cand_in_ctd_marker(c),s)

def LF_ctd_marker_induce(c):
    l1,s1 = LF_c_induced_d(c)
    l2,s2 = LF_d_induced_by_c_tight(c)
    return ((l1 or l2) * cand_in_ctd_marker(c),(s1*s2))

def LF_ctd_therapy_treat(c):
    l,s = LF_c_treat_d_wide(c)
    return (l* cand_in_ctd_therapy(c),s)

def LF_ctd_unspecified_treat(c):
    l,s = LF_c_treat_d_wide(c)
    return (l* cand_in_ctd_unspecified(c),s)

def LF_ctd_unspecified_induce(c):
    l1,s1 = LF_c_induced_d(c)
    l2,s2 = LF_d_induced_by_c_tight(c)
    return ((l1 or l2) * cand_in_ctd_unspecified(c),(s1*s2))

import re
from snorkel.lf_helpers import (
    get_tagged_text,
    rule_regex_search_tagged_text,
    rule_regex_search_btw_AB,
    rule_regex_search_btw_BA,
    rule_regex_search_before_A,
    rule_regex_search_before_B,
)

from snorkel.lf_helpers import (
    get_left_tokens, get_right_tokens, get_between_tokens,
    get_text_between, get_tagged_text,
)

# List to parenthetical
def ltp(x):
    return '(' + '|'.join(x) + ')'

# %%
# def LF_induce(c):
#     return (1,1) if re.search(r'{{A}}.{0,20}induc.{0,20}{{B}}', get_tagged_text(c), flags=re.I) else (0,0)


def LF_induce(c):
    return (1,distanceCD_(c,['induc'])) if re.search(r'{{A}}.*induc.*{{B}}', get_tagged_text(c), flags=re.I) else (0,0)

causal_past = ['induced', 'caused', 'due']
# def LF_d_induced_by_c(c):
#     return (rule_regex_search_btw_BA(c, '.{0,50}' + ltp(causal_past) + '.{0,9}(by|to).{0,50}', 1),1)

def LF_d_induced_by_c(c):
    sc = 0
    word_vectors = get_word_vectors(get_between_tokens(c))
    for w in causal_past:
        sc=max(sc,get_similarity(word_vectors,w))
    return (1,sc)

# def LF_d_induced_by_c_tight(c):
#     return (rule_regex_search_btw_BA(c, '.{0,50}' + ltp(causal_past) + ' (by|to) ', 1),1)

def LF_d_induced_by_c_tight(c):
    return (rule_regex_search_btw_BA(c, '.*' + ltp(causal_past) + ' (by|to) ', 1),distanceCD_(c,causal_past))

def LF_induce_name(c):
    return (1,1) if 'induc' in c.chemical.get_span().lower() else (0,0)     

causal = ['cause[sd]?', 'induce[sd]?', 'associated with']
# def LF_c_cause_d(c):
#     return (1,1) if (
#         re.search(r'{{A}}.{0,50} ' + ltp(causal) + '.{0,50}{{B}}', get_tagged_text(c), re.I)
#         and not re.search('{{A}}.{0,50}(not|no).{0,20}' + ltp(causal) + '.{0,50}{{B}}', get_tagged_text(c), re.I)
#     ) else (0,0)

def LF_c_cause_d(c):
    return (1,distanceCD_(c,causal)) if (
        re.search(r'{{A}}.* ' + ltp(causal) + '.*{{B}}', get_tagged_text(c), re.I)
        and not re.search('{{A}}.{0,50}(not|no).{0,20}' + ltp(causal) + '.{0,50}{{B}}', get_tagged_text(c), re.I)
    ) else (0,0)


treat = ['treat', 'effective', 'prevent', 'resistant', 'slow', 'promise', 'therap']

# def LF_d_treat_c(c):
#     return (rule_regex_search_btw_BA(c, '.*' + ltp(treat) + '.*', -1),distanceDC_(c,treat))

def LF_d_treat_c(c):
    return (rule_regex_search_btw_BA(c, '.{0,50}' + ltp(treat) + '.{0,50}', -1),distanceDC_(c,treat))


# def LF_d_treat_c(c):
#     return (rule_regex_search_btw_BA(c, '.*' + ltp(treat) + '.*', -1),1)

# def LF_c_treat_d(c):
#     return (rule_regex_search_btw_AB(c, '.*' + ltp(treat) + '.*', -1),distanceCD_(c,treat))

def LF_c_treat_d(c):
    return (rule_regex_search_btw_AB(c, '.{0,50}' + ltp(treat) + '.{0,50}', -1),distanceCD_(c,treat))


# def LF_treat_d(c):
#     return (rule_regex_search_before_B(c, ltp(treat) + '.{0,50}', -1),1)


def LF_treat_d(c):
    sc = 0
    word_vectors = get_word_vectors(get_left_tokens(c[1],5))
    for w in treat:
        sc=max(sc,get_similarity(word_vectors,w))
    if(re.search('(not|no|none) .* {{B}}', get_tagged_text(c), re.I)):
        return (0,0)
    else:
        return (-1,sc)
    
# def LF_c_treat_d_wide(c):
#     return (rule_regex_search_btw_AB(c, '.*' + ltp(treat) + '.*', -1),1)

def LF_c_treat_d_wide(c):
    return (rule_regex_search_btw_AB(c, '.{0,200}' + ltp(treat) + '.{0,200}', -1),distanceCD_(c,treat))

# def LF_c_treat_d_wide(c):
#     return (rule_regex_search_btw_AB(c, '.*' + ltp(treat) + '.*', -1),distanceCD_(c,treat))


def LF_c_d(c):
    return (1,1) if ('{{A}} {{B}}' in get_tagged_text(c)) else (0,0)

def LF_c_induced_d(c):
    return (1,1) if (
        ('{{A}} {{B}}' in get_tagged_text(c)) and 
        (('-induc' in c[0].get_span().lower()) or ('-assoc' in c[0].get_span().lower()))
        ) else (0,0)


def distanceImproveBeforeDisease(c):
    m=re.search(r'(improv)(.*)({{B}}.*{{A}})', get_tagged_text(c), flags=re.I)
    if(m):
        return (5000-len(m.group(2)))/5000
    return 0

def LF_improve_before_disease(c):
    return (rule_regex_search_before_B(c, 'improv.*', -1), distanceImproveBeforeDisease(c))

pat_terms = ['in a patient with ', 'in patients with']
def LF_in_patient_with(c):
    return (-1,1) if re.search(ltp(pat_terms) + '{{B}}', get_tagged_text(c), flags=re.I) else (0,0)

uncertain = ['combin', 'possible', 'unlikely']
# def LF_uncertain(c):
#     return (rule_regex_search_before_A(c, ltp(uncertain) + '.*', -1),1)

def LF_uncertain(c):
    sc = 0
    word_vectors = get_word_vectors(get_left_tokens(c[1],5))
    for w in uncertain:
        sc=max(sc,get_similarity(word_vectors,w))
    if(re.search('(not|no|none) .* {{B}}', get_tagged_text(c), re.I)):
        return (0,0)
    else:
        return (-1,sc)
    
# def LF_induced_other(c):
#     return (rule_regex_search_tagged_text(c, '{{A}}.*-induced {{B}}', -1),distanceCD(c))

def LF_induced_other(c):
    return (rule_regex_search_tagged_text(c, '{{A}}.{20,1000}-induced {{B}}', -1),distanceCDfar(c))

# def LF_induced_other(c):
#     return (rule_regex_search_tagged_text(c, '{{A}}.*-induced {{B}}', -1),1)

def LF_far_c_d(c):
    return (rule_regex_search_btw_AB(c, '.{100,5000}', -1),distanceCDfar(c))

# def LF_far_c_d(c):
#     return (rule_regex_search_btw_AB(c, '.*', -1),distanceCD(c))

# def LF_far_d_c(c):
#     return (rule_regex_search_btw_BA(c, '.{100,5000}', -1),1)

def LF_far_d_c(c):
    return (rule_regex_search_btw_BA(c, '.{100,5000}', -1),distanceCDfar(c))

# def LF_far_d_c(c):
#     return (rule_regex_search_btw_BA(c, '.*', -1),distanceCD(c))

# def LF_risk_d(c):
#     return (rule_regex_search_before_B(c, 'risk of ', 1),1)


def LF_risk_d(c):
    sc = 0
    word_vectors = get_word_vectors(get_left_tokens(c[1],5))
    sc=max(sc,get_similarity(word_vectors,'risk'))
    return (1,sc)

# def LF_develop_d_following_c(c):
#     return (1,1) if re.search(r'develop.{0,25}{{B}}.{0,25}following.{0,25}{{A}}', get_tagged_text(c), flags=re.I) else (0,0)

def LF_develop_d_following_c(c):
    return (1,distanceDevFol(c)) if re.search(r'develop.*{{B}}.*following.*{{A}}', get_tagged_text(c), flags=re.I) else (0,0)

procedure, following = ['inject', 'administrat'], ['following']
# def LF_d_following_c(c):
#     return (1,1) if re.search('{{B}}.{0,50}' + ltp(following) + '.{0,20}{{A}}.{0,50}' + ltp(procedure), get_tagged_text(c), flags=re.I) else (0,0)

def LF_d_following_c(c):
    return (1,distanceDC_(c,following)) if re.search('{{B}}.*' + ltp(following) + '.*{{A}}.*' + ltp(procedure), get_tagged_text(c), flags=re.I) else (0,0)

# def LF_measure(c):
#     return (-1,1) if re.search('measur.{0,75}{{A}}', get_tagged_text(c), flags=re.I) else (0,0)

def distanceMeasureA(c):
    m = re.search('(measur)(.*)({{A}})', get_tagged_text(c), flags=re.I) 
    if(m):
        return (5000-len(m.group(2)))/5000
    return 0

def LF_measure(c):
    return (-1,distanceMeasureA(c)) if re.search('measur.*{{A}}', get_tagged_text(c), flags=re.I) else (0,0)

# def LF_level(c):
#     return (-1,1) if re.search('{{A}}.{0,25} level', get_tagged_text(c), flags=re.I) else (0,0)

def distanceLevel(c):
    m = re.search('({{A}})(.*)(level)', get_tagged_text(c), flags=re.I)
    if(m):
        return (5000-len(m.group(2)))/5000
    return 0

def LF_level(c):
    return (-1,distanceLevel(c)) if re.search('{{A}}.* level', get_tagged_text(c), flags=re.I) else (0,0)

def distanceNeg(c):
    m = re.search('(none|not|no)(.*)({{B}})', get_tagged_text(c), flags=re.I)
    if(m):
        return (5000-len(m.group(2)))/5000
    return 0

# def LF_neg_d(c):
#     return (-1,1) if re.search('(none|not|no) .{0,25}{{B}}', get_tagged_text(c), flags=re.I) else (0,0)

def LF_neg_d(c):
    return (-1,distanceNeg(c)) if re.search('(none|not|no) .*{{B}}', get_tagged_text(c), flags=re.I) else (0,0)


WEAK_PHRASES = ['none', 'although', 'was carried out', 'was conducted',
                'seems', 'suggests', 'risk', 'implicated',
               'the aim', 'to (investigate|assess|study)']

WEAK_RGX = r'|'.join(WEAK_PHRASES)

def LF_weak_assertions(c):
    return (-1,1) if re.search(WEAK_RGX, get_tagged_text(c), flags=re.I) else (0,0)

# %%
# original
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from tensorflow.contrib.tensorboard.plugins import projector

def train_NN():
    print()
    result_dir = "./"
    config = projector.ProjectorConfig()
    tf.logging.set_verbosity(tf.logging.INFO)
    summary_writer = tf.summary.FileWriter(result_dir)

    tf.reset_default_graph()

    dim = 2 #(labels,scores)

    _x = tf.placeholder(tf.float64,shape=(dim,len(LFs)))

    alphas = tf.get_variable('alpha', _x.get_shape()[-1],initializer=tf.truncated_normal_initializer(1,0.1,12),
                            dtype=tf.float64)

    thetas = tf.get_variable('theta', _x.get_shape()[-1],initializer=tf.truncated_normal_initializer(2,0.2,12),
                            dtype=tf.float64)

    l,s = tf.unstack(_x)

    prelu_out_s = tf.maximum(tf.subtract(s,alphas), tf.zeros(shape=(len(LFs)),dtype=tf.float64))        

    mul_L_S = tf.multiply(l,prelu_out_s)

    phi_p1 = tf.reduce_sum(tf.multiply(mul_L_S,thetas))

    phi_n1 = tf.reduce_sum(tf.multiply(tf.negative(mul_L_S),thetas))

    phi_out = tf.stack([phi_n1,phi_p1])
    
    predict = tf.argmax(tf.nn.softmax(phi_out))

    loss = tf.negative(tf.reduce_logsumexp(phi_out))

    train_step = tf.train.GradientDescentOptimizer(0.0001).minimize(loss) 


    check_op = tf.add_check_numerics_ops()

    sess = tf.Session()
    init = tf.global_variables_initializer()
    sess.run(init)

    for i in range(1):
        c = 0
        te_prev=1
        total_te = 0
        for L_S_i in train_L_S:

            a,t,te_curr,_ = sess.run([alphas,thetas,loss,train_step],feed_dict={_x:L_S_i})
            total_te+=te_curr

            if(abs(te_curr-te_prev)<1e-200):
                print("too low")
                break

            if(c%100==0):
                pl = []
                t_de=0
                for L_S_i in dev_L_S:
                    a,t,de_curr,p = sess.run([alphas,thetas,loss,predict],feed_dict={_x:L_S_i})
                    pl.append(p)
                    t_de+=de_curr
                predicted_labels = [-1 if x==0 else x for x in pl]
                print("dev err:",t_de/888)
                print(total_te/100)
                total_te=0
#                 print(a)
#                 print(t)
                print()
                print(predicted_labels.count(-1),predicted_labels.count(1))
                print(c," d ",precision_recall_fscore_support(np.array(gold_labels_dev),np.array(predicted_labels),average='macro'))
            c+=1
            te_prev = te_curr
        pl = []
        
        for L_S_i in dev_L_S:
            p = sess.run(predict,feed_dict={_x:L_S_i})
            pl.append(p)
        predicted_labels = [-1 if x==0 else x for x in pl]
        print(i,total_te)
#         a,t = sess.run([alphas,thetas],feed_dict={_x:dev_L_S[0]})
        a,t = sess.run([alphas,thetas])
        print(a)
        print(t)
        print(predicted_labels.count(-1),predicted_labels.count(1))
        print(precision_recall_fscore_support(np.array(gold_labels_dev),np.array(predicted_labels),average=None))
        print()
        print(precision_recall_fscore_support(np.array(gold_labels_dev),np.array(predicted_labels),average='macro'))

# %%
import numpy as np
import math

import matplotlib.pyplot as plt

LFs = [
    LF_c_cause_d,
    LF_c_d,
    LF_c_induced_d,
    LF_c_treat_d,
    LF_c_treat_d_wide,
    LF_closer_chem,
    LF_closer_dis,
    LF_ctd_marker_c_d,
    LF_ctd_marker_induce,
    LF_ctd_therapy_treat,
    LF_ctd_unspecified_treat,
    LF_ctd_unspecified_induce,
    LF_d_following_c,
    LF_d_induced_by_c,
    LF_d_induced_by_c_tight,
    LF_d_treat_c,
    LF_develop_d_following_c,
    LF_far_c_d,
    LF_far_d_c,
    LF_improve_before_disease,
    LF_in_ctd_therapy,
    LF_in_ctd_marker,
    LF_in_patient_with,
    LF_induce,
    LF_induce_name,
    LF_induced_other,
    LF_level,
    LF_measure,
    LF_neg_d,
    LF_risk_d,
    LF_treat_d,
    LF_uncertain,
    LF_weak_assertions
]

# %%
''' output:

    [[[L_x1],[S_x1]],
     [[L_x2],[S_x2]],
     ......
     ......
    ]

'''
def get_L_S_Tensor(cands): 
    
    L_S = []
    for ci in cands:
        L_S_ci=[]
        L=[]
        S=[]
        P_ik = []
        for LF in LFs:
            #print LF.__name__
            l,s = LF(ci)
            L.append(l)
            S.append((s+1)/2)  #to scale scores in [0,1] 
        L_S_ci.append(L)
        L_S_ci.append(S)
        L_S.append(L_S_ci) 
    return L_S

# %%
# import matplotlib.pyplot as plt
   
from sklearn.metrics import precision_recall_fscore_support

import cPickle as pkl

dev_L_S = get_L_S_Tensor(dev_cands)
train_L_S = get_L_S_Tensor(train_cands)
# test_L_S = get_L_S_Tensor(test_cands)

import cPickle as pkl
from sklearn.metrics import precision_recall_fscore_support

pkl.dump(dev_L_S,open("dev_L_S.p","wb"))
pkl.dump(train_L_S,open("train_L_S.p","wb"))
# pkl.dump(test_L_S,open("test_L_S.p","wb"))

# %%
# with an extra layer
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from tensorflow.contrib.tensorboard.plugins import projector

def train_NN_EL():
    print()
    result_dir = "./"
    config = projector.ProjectorConfig()
    tf.logging.set_verbosity(tf.logging.INFO)
    summary_writer = tf.summary.FileWriter(result_dir)

    tf.reset_default_graph()

    dim = 2 #(labels,scores)

    _x = tf.placeholder(tf.float64,shape=(dim,len(LFs)))

    alphas = tf.get_variable('alpha', _x.get_shape()[-1],initializer=tf.truncated_normal_initializer(1,0.1,12),
                            dtype=tf.float64)

    layer12_out_dim = _x.get_shape()[-1]
    
    layer12 = tf.get_variable('layer12',[_x.get_shape()[-1], layer12_out_dim ],initializer=tf.truncated_normal_initializer(2,0.2,12),
                            dtype=tf.float64)
    
    layer2b = tf.get_variable('layer2b',layer12_out_dim,initializer=tf.truncated_normal_initializer(2,0.2,12),
                            dtype=tf.float64)
    
    thetas = tf.get_variable('theta', layer12.get_shape()[-1],initializer=tf.truncated_normal_initializer(2,0.2,12),
                            dtype=tf.float64)

    l,s = tf.unstack(_x)

    prelu_out_s = tf.maximum(tf.subtract(s,alphas), tf.zeros(shape=(len(LFs)),dtype=tf.float64))        

    
    mul_L_S = tf.multiply(l,prelu_out_s)
    
    layer12_out = tf.nn.relu(tf.matmul(tf.expand_dims(prelu_out_s,0)+layer2b,layer12))

#     phi_p1 = tf.reduce_sum(tf.multiply(mul_L_S,thetas))

    phi_p1 = tf.reduce_sum(tf.multiply(layer12_out,thetas))


#     phi_n1 = tf.reduce_sum(tf.multiply(tf.negative(mul_L_S),thetas))

    phi_n1 = tf.reduce_sum(tf.multiply(tf.negative(layer12_out),thetas))

    phi_out = tf.stack([phi_n1,phi_p1])
    
    predict = tf.argmax(tf.nn.softmax(phi_out))

    loss = tf.negative(tf.reduce_logsumexp(phi_out))

    train_step = tf.train.GradientDescentOptimizer(0.01).minimize(loss) 


    check_op = tf.add_check_numerics_ops()

    sess = tf.Session()
    init = tf.global_variables_initializer()
    sess.run(init)

    for i in range(1):
        c = 0
        te_prev=1
        total_te = 0
        for L_S_i in train_L_S:

            a,t,te_curr,_ = sess.run([alphas,thetas,loss,train_step],feed_dict={_x:L_S_i})
            total_te+=te_curr

            if(abs(te_curr-te_prev)<1e-200):
                print("too low")
                break

            if(c%1000==0):
                pl = []
                t_de=0
                for L_S_i in dev_L_S:
                    a,t,de_curr,p = sess.run([alphas,thetas,loss,predict],feed_dict={_x:L_S_i})
                    pl.append(p)
                    t_de+=de_curr
                predicted_labels = [-1 if x==0 else x for x in pl]
                print("dev err:",t_de/888)
                print(total_te/1000)
                total_te=0
                print(a)
                print(t)
                print()
                print(predicted_labels.count(-1),predicted_labels.count(1))
                print(c," d ",precision_recall_fscore_support(np.array(gold_labels_dev),np.array(predicted_labels),average='macro'))
            c+=1
            te_prev = te_curr
        pl = []
        
        for L_S_i in dev_L_S:
            p = sess.run(predict,feed_dict={_x:L_S_i})
            pl.append(p)
        predicted_labels = [-1 if x==0 else x for x in pl]
        print(i,total_te)
#         a,t = sess.run([alphas,thetas],feed_dict={_x:dev_L_S[0]})
        a,t = sess.run([alphas,thetas])
        print(a)
        print(t)
        print(predicted_labels.count(-1),predicted_labels.count(1))
        print(precision_recall_fscore_support(np.array(gold_labels_dev),np.array(predicted_labels),average=None))
        print()
        print(precision_recall_fscore_support(np.array(gold_labels_dev),np.array(predicted_labels),average='macro'))

# %%
# distances changed

train_NN()
# Out:
# dev err: -0.709887445754
# -0.00699214594392
#
# 350 538
# 0  d  (0.76801911842804038, 0.7880067567567568, 0.71968412531121595, None)
# too low
# 0 -6.53739772714
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98357064  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91993454
#   1.05962482  0.83641602  1.03537624  0.94116148  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82205496  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714129  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83986908
#   2.11924965  1.67283205  2.07075248  1.88287928  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398282  1.67675493  1.92430086]
# 350 538
# (array([ 0.99142857,  0.54460967]), array([ 0.58614865,  0.98986486]), array([ 0.73673036,  0.70263789]), array([592, 296]))
#
# (0.76801911842804038, 0.7880067567567568, 0.71968412531121595, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c, tight ranges for -1 but used distancefarCD , exp22

train_NN()
# Out:
# dev err: -0.709871351813
# -0.00699214594392
#
# 352 536
# 0  d  (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)
# too low
# 0 -6.53481099834
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358419  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91993454
#   1.05962482  0.83641602  1.03537624  0.94116723  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82204994  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83986908
#   2.11924965  1.67283205  2.07075248  1.8828791   1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398284  1.67675493  1.92430086]
# 352 536
# (array([ 0.98579545,  0.54291045]), array([ 0.58614865,  0.98310811]), array([ 0.73516949,  0.69951923]), array([592, 296]))
#
# (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)

# %%
# All non tight with distance score exp21

train_NN()
# Out:
# dev err: -0.705421228101
# -0.00693703542313
#
# 563 325
# 0  d  (0.69574258778521658, 0.70439189189189189, 0.69915302089215137, None)
# too low
# 0 -14.8749292717
# [ 1.11754463  0.81414095  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98355774  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91991171
#   1.05962482  0.83641602  1.03537624  0.94116747  0.99621468  1.16301113
#   0.87350344  1.17747756  1.06808572  1.06850778  1.05747627  0.99037652
#   0.82194712  0.83837747  0.96207502]
# [ 2.23508926  1.62843746  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714137  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83986962
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.7474835   2.35495511  2.13617144  2.13701556  2.11495255  1.98068728
#   1.64398348  1.67675493  1.92430256]
# 563 325
# (array([ 0.80994671,  0.58153846]), array([ 0.77027027,  0.63851351]), array([ 0.78961039,  0.60869565]), array([592, 296]))
#
# (0.69574258778521658, 0.70439189189189189, 0.69915302089215137, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c, tight ranges for -1 but used distance, 
#also changed imporveBeforeB exp20

train_NN()
# Out:
# dev err: -0.710106593062
# -0.00699214594392
#
# 419 469
# 0  d  (0.74778256687920774, 0.77787162162162171, 0.73247997517503549, None)
# too low
# 0 -6.54534869958
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358541  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91990846
#   1.05962482  0.83641602  1.03537624  0.94116606  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82202947  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714119  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83987009
#   2.11924965  1.67283205  2.07075248  1.88287914  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398293  1.67675493  1.92430086]
# 419 469
# (array([ 0.92840095,  0.56716418]), array([ 0.65709459,  0.89864865]), array([ 0.76953511,  0.69542484]), array([592, 296]))
#
# (0.74778256687920774, 0.77787162162162171, 0.73247997517503549, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c, tight ranges for -1 but used distance, exp19

train_NN()
# Out:
# dev err: -0.710242046373
# -0.00699214594392
#
# 423 465
# 0  d  (0.74830321055441162, 0.77871621621621623, 0.73443291494857033, None)
# too low
# 0 -6.54534869958
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358541  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91990846
#   1.05962482  0.83641602  1.03537624  0.94116606  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82202947  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714119  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83987009
#   2.11924965  1.67283205  2.07075248  1.88287914  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398293  1.67675493  1.92430086]
# 423 465
# (array([ 0.92671395,  0.56989247]), array([ 0.66216216,  0.89527027]), array([ 0.77241379,  0.69645204]), array([592, 296]))
#
# (0.74830321055441162, 0.77871621621621623, 0.73443291494857033, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c, tight ranges for -1 but used distance, all -1 exp18

train_NN()
# Out:
# dev err: -0.71029466018
# -0.00699214594392
#
# 424 464
# 0  d  (0.74674690956408596, 0.77702702702702697, 0.73319519270617484, None)
# too low
# 0 -6.54478867599
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358387  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91990846
#   1.05962482  0.83641602  1.03537624  0.94116753  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82202818  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83987009
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398293  1.67675493  1.92430086]
# 424 464
# (array([ 0.9245283 ,  0.56896552]), array([ 0.66216216,  0.89189189]), array([ 0.77165354,  0.69473684]), array([592, 296]))
#
# (0.74674690956408596, 0.77702702702702697, 0.73319519270617484, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c, tight ranges for -1 but used distance  LF_far_d_c exp17

train_NN()
# Out:
# dev err: -0.710624123218
# -0.00699214594392
#
# 426 462
# 0  d  (0.74589964026583744, 0.77618243243243246, 0.73301677975854151, None)
# too low
# 0 -6.5471247757
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358387  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91990565
#   1.05962482  0.83641602  1.03537624  0.94116753  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82202566  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83987034
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398294  1.67675493  1.92430086]
# 426 462
# (array([ 0.92253521,  0.56926407]), array([ 0.66385135,  0.88851351]), array([ 0.77210216,  0.6939314 ]), array([592, 296]))
#
# (0.74589964026583744, 0.77618243243243246, 0.73301677975854151, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c,LF_far_c_d distanceCDn1, LF_far_d_c ,LF_measure  
# LF_level, LF_neg_d exp16 old

train_NN()
# Out:
# dev err: -0.709880393687
# -0.00699214594392
#
# 352 536
# 0  d  (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)
# too low
# 0 -6.53470386686
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358388  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91993454
#   1.05962482  0.83641602  1.03537624  0.94116753  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82204968  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83986908
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398285  1.67675493  1.92430086]
# 352 536
# (array([ 0.98579545,  0.54291045]), array([ 0.58614865,  0.98310811]), array([ 0.73516949,  0.69951923]), array([592, 296]))
#
# (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c,LF_far_c_d distanceCDn1, LF_far_d_c ,LF_measure  
# LF_level exp15

train_NN()
# Out:
# dev err: -0.709880393687
# -0.00699214594392
#
# 352 536
# 0  d  (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)
# too low
# 0 -6.53470386686
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358388  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91993454
#   1.05962482  0.83641602  1.03537624  0.94116753  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82204968  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83986908
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398285  1.67675493  1.92430086]
# 352 536
# (array([ 0.98579545,  0.54291045]), array([ 0.58614865,  0.98310811]), array([ 0.73516949,  0.69951923]), array([592, 296]))
#
# (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c,LF_far_c_d distanceCDn1, LF_far_d_c ,LF_measure  exp14

train_NN()
# Out:
# dev err: -0.709880393687
# -0.00699214594392
#
# 352 536
# 0  d  (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)
# too low
# 0 -6.53470386686
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358388  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91993454
#   1.05962482  0.83641602  1.03537624  0.94116753  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82204968  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83986908
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398285  1.67675493  1.92430086]
# 352 536
# (array([ 0.98579545,  0.54291045]), array([ 0.58614865,  0.98310811]), array([ 0.73516949,  0.69951923]), array([592, 296]))
#
# (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c,LF_far_c_d distanceCDn1, LF_far_d_c   exp13

train_NN()
# Out:
# dev err: -0.709880393687
# -0.00699214594392
#
# 352 536
# 0  d  (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)
# too low
# 0 -6.53470386686
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358388  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91993454
#   1.05962482  0.83641602  1.03537624  0.94116753  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82204968  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83986908
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398285  1.67675493  1.92430086]
# 352 536
# (array([ 0.98579545,  0.54291045]), array([ 0.58614865,  0.98310811]), array([ 0.73516949,  0.69951923]), array([592, 296]))
#
# (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c,LF_far_c_d distanceCDn1   exp12

train_NN()
# Out:
# dev err: -0.709880393687
# -0.00699214594392
#
# 352 536
# 0  d  (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)
# too low
# 0 -6.53470386686
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358388  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91993454
#   1.05962482  0.83641602  1.03537624  0.94116753  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82204968  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83986908
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398285  1.67675493  1.92430086]
# 352 536
# (array([ 0.98579545,  0.54291045]), array([ 0.58614865,  0.98310811]), array([ 0.73516949,  0.69951923]), array([592, 296]))
#
# (0.76435295115332424, 0.7846283783783784, 0.71734436114732725, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c,LF_far_c_d, 1/distanceCD  exp11

train_NN()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-ec976bdd65d9> in <module>()
#       2 # distanceCD_ ,LF_d_following_c,LF_far_c_d, 1/distanceCD  exp11
#       3
# ----> 4 train_NN()
#
# <ipython-input-79-95af70978dc7> in train_NN()
#      67                 t_de=0
#      68                 for L_S_i in dev_L_S:
# ---> 69                     a,t,de_curr,p = sess.run([alphas,thetas,loss,predict],feed_dict={_x:L_S_i})
#      70                     pl.append(p)
#      71                     t_de+=de_curr
#
# /home/vinay/anaconda3/envs/en27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/vinay/anaconda3/envs/en27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /home/vinay/anaconda3/envs/en27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/vinay/anaconda3/envs/en27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /home/vinay/anaconda3/envs/en27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c, exp10

train_NN()
# Out:
# dev err: -0.710624123218
# -0.00699214594392
#
# 426 462
# 0  d  (0.74589964026583744, 0.77618243243243246, 0.73301677975854151, None)
# too low
# 0 -6.5471247757
# [ 1.11754463  0.81412327  1.00955965  1.00062431  1.10637787  1.04133855
#   1.169206    1.03120785  1.14633471  1.0647233   0.98358387  1.06661405
#   0.98238184  1.07858159  1.04081247  1.04223612  0.85334134  0.91990565
#   1.05962482  0.83641602  1.03537624  0.94116753  0.99621468  1.16301113
#   0.87352575  1.17747756  1.06808572  1.06850778  1.05747627  0.99033244
#   0.82202566  0.83837747  0.9621615 ]
# [ 2.23508926  1.62843948  2.01911931  2.00124861  2.21275574  2.0826771
#   2.33841199  2.0624157   2.29266943  2.12944659  1.96714118  2.13322809
#   1.96476369  2.15716318  2.08162495  2.08447223  1.70668268  1.83987034
#   2.11924965  1.67283205  2.07075248  1.88287909  1.99242937  2.32602226
#   1.74748188  2.35495511  2.13617144  2.13701556  2.11495255  1.9806875
#   1.64398294  1.67675493  1.92430086]
# 426 462
# (array([ 0.92253521,  0.56926407]), array([ 0.66385135,  0.88851351]), array([ 0.77210216,  0.6939314 ]), array([592, 296]))
#
# (0.74589964026583744, 0.77618243243243246, 0.73301677975854151, None)

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ ,LF_d_following_c, exp10

train_NN()

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, LF_develop_d_following_c,
# distanceCD_ , exp9

train_NN()

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, F_induce, distanceCD_ , exp8

train_NN()

# %%
#LF_d_induced_by_c_tight made * ,LF_c_cause_d, distanceCD_ , exp7

train_NN()

# %%
#LF_d_induced_by_c_tight made * , distanceCD_ , exp6

train_NN()

# %%
 #LF_d_induced_by_c_tight, LF_far_c_d made *, distance (500-dist)/500 exp5

train_NN()

# %%
 #LF_d_induced_by_c_tight, LF_far_c_d made *, distance (5000-dist)/5000 exp4

train_NN()

# %%
 #LF_d_induced_by_c_tight, LF_far_c_d made *, distance (100-dist)/100 exp3

train_NN()

# %%
#LF_d_induced_by_c_tight, LF_far_c_d made *,  exp2

train_NN()

# %%
#LF_d_induced_by_c_tight made * , exp1

train_NN()

# %%
# baseline reproduce
train_NN()

# %%
# new baseline
train_NN()

# %%
# for reference
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from tensorflow.contrib.tensorboard.plugins import projector

def train_NN():
    print()
    result_dir = "./"
    config = projector.ProjectorConfig()
    tf.logging.set_verbosity(tf.logging.INFO)
    summary_writer = tf.summary.FileWriter(result_dir)

    tf.reset_default_graph()

    dim = 2 #(labels,scores)

    _x = tf.placeholder(tf.float64,shape=(dim,len(LFs)))

    alphas = tf.get_variable('alpha', _x.get_shape()[-1],initializer=tf.truncated_normal_initializer(1,0.1,12),
                            dtype=tf.float64)

    thetas = tf.get_variable('theta', _x.get_shape()[-1],initializer=tf.truncated_normal_initializer(2,0.2,12),
                            dtype=tf.float64)

    l,s = tf.unstack(_x)

    prelu_out_s = tf.maximum(tf.subtract(s,alphas), tf.zeros(shape=(len(LFs)),dtype=tf.float64))        

    mul_L_S = tf.multiply(l,prelu_out_s)

    phi_p1 = tf.reduce_sum(tf.multiply(mul_L_S,thetas))

    phi_n1 = tf.reduce_sum(tf.multiply(tf.negative(mul_L_S),thetas))

    phi_out = tf.stack([phi_n1,phi_p1])
    
    predict = tf.argmax(tf.nn.softmax(phi_out))

    loss = tf.negative(tf.reduce_logsumexp(phi_out))

    train_step = tf.train.GradientDescentOptimizer(0.0001).minimize(loss) 


    check_op = tf.add_check_numerics_ops()

    sess = tf.Session()
    init = tf.global_variables_initializer()
    sess.run(init)

    for i in range(1):
        c = 0
        te_prev=1
        total_te = 0
        for L_S_i in train_L_S:

            a,t,te_curr,_ = sess.run([alphas,thetas,loss,train_step],feed_dict={_x:L_S_i})
            total_te+=te_curr

            if(abs(te_curr-te_prev)<1e-200):
                print("too low")
                break

            if(c%100==0):
                pl = []
                t_de=0
                for L_S_i in dev_L_S:
                    a,t,de_curr,p = sess.run([alphas,thetas,loss,predict],feed_dict={_x:L_S_i})
                    pl.append(p)
                    t_de+=de_curr
                predicted_labels = [-1 if x==0 else x for x in pl]
                print("dev err:",t_de/888)
                print(total_te/100)
                total_te=0
                print(a)
                print(t)
                print()
                print(predicted_labels.count(-1),predicted_labels.count(1))
                print(c," d ",precision_recall_fscore_support(np.array(gold_labels_dev),np.array(predicted_labels),average='macro'))
            c+=1
            te_prev = te_curr
        pl = []
        for L_S_i in dev_L_S:
            p = sess.run(predict,feed_dict={_x:L_S_i})
            pl.append(p)
        predicted_labels = [-1 if x==0 else x for x in pl]
        print(i,total_te)
        print(predicted_labels.count(-1),predicted_labels.count(1))
        print(precision_recall_fscore_support(np.array(gold_labels_dev),np.array(predicted_labels),average='macro'))
    
train_NN()

# %%
# def distanceCD_(c,l):
#     dist = [0]
#     for w in l:
#         pattern = r'({{A}})(.*)('+w+r')(.*)({{B}})'
#         print(pattern)
#         matchObj = re.search(pattern, get_tagged_text(c), flags=re.I)
#         if(matchObj):
#             print(w)
#             match_groups = matchObj.group(2,4)
#             print(match_groups)
#             print([len(mg) for mg in match_groups])
#             print(min([len(mg) for mg in match_groups]))
#             dist.append(min([len(mg) for mg in match_groups]))        
#             print(0,len(matchObj.group(0)),matchObj.group(0))
#             print(1,len(matchObj.group(1)),matchObj.group(1))
#             print(2,len(matchObj.group(2)),matchObj.group(2))
#             print(3,len(matchObj.group(3)),matchObj.group(3))
#             print(4,len(matchObj.group(4)),matchObj.group(4))
#             print(5,len(matchObj.group(5)),matchObj.group(5))
#     return (1000-max(dist))/1000

# dir(train_cands[0])
# print(train_cands[0].get_parent())

# print(get_tagged_text(train_cands[0]))
# distanceCD_(train_cands[0],['induc'])

# i =0;
# for c in train_cands[0:]:
#     i+=1
#     if('induc' in get_tagged_text(c)):
#         print(i,get_tagged_text(c))
#         distanceCD_(c,['induc'])
# Out:
# Sentence(Document 7234705,7,In the seventh patient, a permanent ventricular pacemaker was inserted and, despite continuation of procainamide therapy, polymorphous ventricular tachycardia did not reoccur.)
# In the seventh patient, a permanent ventricular pacemaker was inserted and, despite continuation of {{A}} therapy, polymorphous {{B}} did not reoccur.
# ({{A}})(.*)(induc)(.*)({{B}})
# 2 Estrogens protect ovariectomized rats from hippocampal injury induced by {{A}} {{B}} (SE).
# ({{A}})(.*)(induc)(.*)({{B}})
# 3 Estrogens protect ovariectomized rats from hippocampal injury induced by {{A}} status epilepticus ({{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 4 Estrogens protect ovariectomized rats from {{B}} induced by {{A}} status epilepticus (SE).
# ({{A}})(.*)(induc)(.*)({{B}})
# 9 NRA0160 and {{A}} antagonized locomotor {{B}} induced by methamphetamine (MAP) in mice.
# ({{A}})(.*)(induc)(.*)({{B}})
# 10 {{A}} and clozapine antagonized locomotor {{B}} induced by methamphetamine (MAP) in mice.
# ({{A}})(.*)(induc)(.*)({{B}})
# 11 NRA0160 and clozapine antagonized locomotor {{B}} induced by {{A}} (MAP) in mice.
# ({{A}})(.*)(induc)(.*)({{B}})
# 12 NRA0160 and clozapine antagonized locomotor {{B}} induced by methamphetamine ({{A}} in mice.
# ({{A}})(.*)(induc)(.*)({{B}})
# 19 The yield of severe {{B}} (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of {{A}} given intragastrically in the phenobarbitone-primed rat was increased from 25% to 56% by giving the initial "calibrating" dose of carbon tetrachloride at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 20 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, {{B}} greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of {{A}} given intragastrically in the phenobarbitone-primed rat was increased from 25% to 56% by giving the initial "calibrating" dose of carbon tetrachloride at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 21 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and {{B}} approximately half normal weight) after 12 doses of {{A}} given intragastrically in the phenobarbitone-primed rat was increased from 25% to 56% by giving the initial "calibrating" dose of carbon tetrachloride at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 22 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, {{B}} 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of {{A}} given intragastrically in the phenobarbitone-primed rat was increased from 25% to 56% by giving the initial "calibrating" dose of carbon tetrachloride at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 23 The yield of severe {{B}} (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of carbon tetrachloride given intragastrically in the phenobarbitone-primed rat was increased from 25% to 56% by giving the initial "calibrating" dose of {{A}} at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 24 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, {{B}} greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of carbon tetrachloride given intragastrically in the phenobarbitone-primed rat was increased from 25% to 56% by giving the initial "calibrating" dose of {{A}} at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 25 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and {{B}} approximately half normal weight) after 12 doses of carbon tetrachloride given intragastrically in the phenobarbitone-primed rat was increased from 25% to 56% by giving the initial "calibrating" dose of {{A}} at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 26 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, {{B}} 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of carbon tetrachloride given intragastrically in the phenobarbitone-primed rat was increased from 25% to 56% by giving the initial "calibrating" dose of {{A}} at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 27 The yield of severe {{B}} (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of carbon tetrachloride given intragastrically in the {{A}} rat was increased from 25% to 56% by giving the initial "calibrating" dose of carbon tetrachloride at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 28 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, {{B}} greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of carbon tetrachloride given intragastrically in the {{A}} rat was increased from 25% to 56% by giving the initial "calibrating" dose of carbon tetrachloride at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 29 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, splenomegaly 2-3 times normal, and {{B}} approximately half normal weight) after 12 doses of carbon tetrachloride given intragastrically in the {{A}} rat was increased from 25% to 56% by giving the initial "calibrating" dose of carbon tetrachloride at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 30 The yield of severe cirrhosis of the liver (defined as a shrunken finely nodular liver with micronodular histology, ascites greater than 30 ml, plasma albumin less than 2.2 g/dl, {{B}} 2-3 times normal, and testicular atrophy approximately half normal weight) after 12 doses of carbon tetrachloride given intragastrically in the {{A}} rat was increased from 25% to 56% by giving the initial "calibrating" dose of carbon tetrachloride at the peak of the phenobarbitone-induced enlargement of the liver.
# ({{A}})(.*)(induc)(.*)({{B}})
# 35 Warfarin-induced {{B}} is accelerated by growth and {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 37 NRA0160 and {{A}} significantly induced {{B}} in rats, although their effects did not exceed 50% induction even at the highest dose given.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' significantly ', u'ed ')
# [15, 3]
# 3
# 0 33 {{A}} significantly induced {{B}}
# 1 5 {{A}}
# 2 15  significantly
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 38 {{A}} and clozapine significantly induced {{B}} in rats, although their effects did not exceed 50% induction even at the highest dose given.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' and clozapine significantly ', u'ed ')
# [29, 3]
# 3
# 0 47 {{A}} and clozapine significantly induced {{B}}
# 1 5 {{A}}
# 2 29  and clozapine significantly
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 40 We compared the effects of {{A}} in adult male and ovariectomized female rats subjected to lithium-pilocarpine-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' in adult male and ovariectomized female rats subjected to lithium-pilocarpine-', u'ed ')
# [79, 3]
# 3
# 0 97 {{A}} in adult male and ovariectomized female rats subjected to lithium-pilocarpine-induced {{B}}
# 1 5 {{A}}
# 2 79  in adult male and ovariectomized female rats subjected to lithium-pilocarpine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 43 Cerebral blood flow and cerebral metabolic rate for {{A}} were measured during isoflurane-induced {{B}} in 10 patients subjected to craniotomy for clipping of a cerebral aneurysm.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' were measured during isoflurane-', u'ed ')
# [33, 3]
# 3
# 0 51 {{A}} were measured during isoflurane-induced {{B}}
# 1 5 {{A}}
# 2 33  were measured during isoflurane-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 44 Cerebral blood flow and cerebral metabolic rate for {{A}} were measured during isoflurane-induced hypotension in 10 patients subjected to craniotomy for clipping of a {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' were measured during isoflurane-', u'ed hypotension in 10 patients subjected to craniotomy for clipping of a ')
# [33, 72]
# 33
# 0 120 {{A}} were measured during isoflurane-induced hypotension in 10 patients subjected to craniotomy for clipping of a {{B}}
# 1 5 {{A}}
# 2 33  were measured during isoflurane-
# 3 5 induc
# 4 72 ed hypotension in 10 patients subjected to craniotomy for clipping of a
# 5 5 {{B}}
# 47 {{B}} induced by {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 59 {{A}} reduces seizure-induced {{B}} in ovariectomized female but not in male rats.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' reduces seizure-', u'ed ')
# [17, 3]
# 3
# 0 35 {{A}} reduces seizure-induced {{B}}
# 1 5 {{A}}
# 2 17  reduces seizure-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 66 {{A}} (10 micro g) was injected into the masseter muscle to induce {{B}} in 11 healthy volunteers.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (10 micro g) was injected into the masseter muscle to ', u'e ')
# [55, 2]
# 2
# 0 72 {{A}} (10 micro g) was injected into the masseter muscle to induce {{B}}
# 1 5 {{A}}
# 2 55  (10 micro g) was injected into the masseter muscle to
# 3 5 induc
# 4 2 e
# 5 5 {{B}}
# 79 RESULTS: The results of this paper confirm that inhibition of {{A}} receptors and inducible NO synthase but not neuronal NO synthase activity reduces {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' receptors and ', u'ible NO synthase but not neuronal NO synthase activity reduces ')
# [15, 63]
# 15
# 0 93 {{A}} receptors and inducible NO synthase but not neuronal NO synthase activity reduces {{B}}
# 1 5 {{A}}
# 2 15  receptors and
# 3 5 induc
# 4 63 ible NO synthase but not neuronal NO synthase activity reduces
# 5 5 {{B}}
# 80 Immunohistochemical study on inducible type of nitric oxide (iNOS), basic fibroblast growth factor (bFGF) and {{B}} growth factor-beta1 (TGF-beta1) in arteritis induced in rats by {{A}} and theophylline, vasodilators.
# ({{A}})(.*)(induc)(.*)({{B}})
# 81 Immunohistochemical study on inducible type of nitric oxide (iNOS), basic fibroblast growth factor (bFGF) and tumor growth factor-beta1 (TGF-beta1) in {{B}} induced in rats by {{A}} and theophylline, vasodilators.
# ({{A}})(.*)(induc)(.*)({{B}})
# 82 Immunohistochemical study on inducible type of {{A}} (iNOS), basic fibroblast growth factor (bFGF) and {{B}} growth factor-beta1 (TGF-beta1) in arteritis induced in rats by fenoldopam and theophylline, vasodilators.
# ({{A}})(.*)(induc)(.*)({{B}})
# 83 Immunohistochemical study on inducible type of {{A}} (iNOS), basic fibroblast growth factor (bFGF) and tumor growth factor-beta1 (TGF-beta1) in {{B}} induced in rats by fenoldopam and theophylline, vasodilators.
# ({{A}})(.*)(induc)(.*)({{B}})
# 84 Immunohistochemical study on inducible type of nitric oxide (iNOS), basic fibroblast growth factor (bFGF) and {{B}} growth factor-beta1 (TGF-beta1) in arteritis induced in rats by fenoldopam and {{A}}, vasodilators.
# ({{A}})(.*)(induc)(.*)({{B}})
# 85 Immunohistochemical study on inducible type of nitric oxide (iNOS), basic fibroblast growth factor (bFGF) and tumor growth factor-beta1 (TGF-beta1) in {{B}} induced in rats by fenoldopam and {{A}}, vasodilators.
# ({{A}})(.*)(induc)(.*)({{B}})
# 105 To clarify the mechanisms of FK 506-induced {{B}}, we studied the chronic effects of {{A}} on the synthesis of endothelin-1 (ET-1), the expression of mRNA of ET-1 and endothelin-converting enzyme-1 (ECE-1), the endothelial nitric oxide synthase (eNOS) activity, and the expression of mRNA of eNOS and C-type natriuretic peptide (CNP) in rat blood vessels.
# ({{A}})(.*)(induc)(.*)({{B}})
# 106 To clarify the mechanisms of FK 506-induced {{B}}, we studied the chronic effects of FK 506 on the synthesis of endothelin-1 (ET-1), the expression of mRNA of ET-1 and endothelin-converting enzyme-1 (ECE-1), the endothelial {{A}} synthase (eNOS) activity, and the expression of mRNA of eNOS and C-type natriuretic peptide (CNP) in rat blood vessels.
# ({{A}})(.*)(induc)(.*)({{B}})
# 107 In addition, the effect of the specific endothelin type A receptor antagonist {{A}} on FK 506-induced {{B}} in rats was studied.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' on FK 506-', u'ed ')
# [11, 3]
# 3
# 0 29 {{A}} on FK 506-induced {{B}}
# 1 5 {{A}}
# 2 11  on FK 506-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 112 Arteritis induced in rats by vasodilators, {{A}} and theophylline, was examined immunohistochemically for expressions of inducible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and {{B}} growth factor-beta1 (TGF-beta1).
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' and theophylline, was examined immunohistochemically for expressions of ', u'ible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and ')
# [73, 85]
# 73
# 0 173 {{A}} and theophylline, was examined immunohistochemically for expressions of inducible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and {{B}}
# 1 5 {{A}}
# 2 73  and theophylline, was examined immunohistochemically for expressions of
# 3 5 induc
# 4 85 ible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and
# 5 5 {{B}}
# 113 {{B}} induced in rats by vasodilators, {{A}} and theophylline, was examined immunohistochemically for expressions of inducible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and tumor growth factor-beta1 (TGF-beta1).
# ({{A}})(.*)(induc)(.*)({{B}})
# 114 Arteritis induced in rats by vasodilators, fenoldopam and theophylline, was examined immunohistochemically for expressions of inducible type of {{A}} synthase (iNOS), basic fibroblast growth factor (bFGF) and {{B}} growth factor-beta1 (TGF-beta1).
# ({{A}})(.*)(induc)(.*)({{B}})
# 115 {{B}} induced in rats by vasodilators, fenoldopam and theophylline, was examined immunohistochemically for expressions of inducible type of {{A}} synthase (iNOS), basic fibroblast growth factor (bFGF) and tumor growth factor-beta1 (TGF-beta1).
# ({{A}})(.*)(induc)(.*)({{B}})
# 116 Arteritis induced in rats by vasodilators, fenoldopam and {{A}}, was examined immunohistochemically for expressions of inducible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and {{B}} growth factor-beta1 (TGF-beta1).
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u', was examined immunohistochemically for expressions of ', u'ible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and ')
# [56, 85]
# 56
# 0 156 {{A}}, was examined immunohistochemically for expressions of inducible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and {{B}}
# 1 5 {{A}}
# 2 56 , was examined immunohistochemically for expressions of
# 3 5 induc
# 4 85 ible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and
# 5 5 {{B}}
# 117 {{B}} induced in rats by vasodilators, fenoldopam and {{A}}, was examined immunohistochemically for expressions of inducible type of nitric oxide synthase (iNOS), basic fibroblast growth factor (bFGF) and tumor growth factor-beta1 (TGF-beta1).
# ({{A}})(.*)(induc)(.*)({{B}})
# 123 {{A}} (1 mg/kg ip) induced parkinsonian-like {{B}}, measured as an increased resistance of a rat's hind foot to passive flexion and extension at the ankle joint.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (1 mg/kg ip) ', u'ed parkinsonian-like ')
# [14, 21]
# 14
# 0 50 {{A}} (1 mg/kg ip) induced parkinsonian-like {{B}}
# 1 5 {{A}}
# 2 14  (1 mg/kg ip)
# 3 5 induc
# 4 21 ed parkinsonian-like
# 5 5 {{B}}
# 124 {{A}} (1 mg/kg ip) induced {{B}} muscle rigidity, measured as an increased resistance of a rat's hind foot to passive flexion and extension at the ankle joint.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (1 mg/kg ip) ', u'ed ')
# [14, 3]
# 3
# 0 32 {{A}} (1 mg/kg ip) induced {{B}}
# 1 5 {{A}}
# 2 14  (1 mg/kg ip)
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 146 Phenobarbitone-induced enlargement of the liver in the rat: its relationship to {{A}} {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 147 Phenobarbitone-induced {{B}} in the rat: its relationship to {{A}} cirrhosis.
# ({{A}})(.*)(induc)(.*)({{B}})
# 148 {{A}} enlargement of the liver in the rat: its relationship to carbon tetrachloride-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' enlargement of the liver in the rat: its relationship to carbon tetrachloride-', u'ed ')
# [79, 3]
# 3
# 0 97 {{A}} enlargement of the liver in the rat: its relationship to carbon tetrachloride-induced {{B}}
# 1 5 {{A}}
# 2 79  enlargement of the liver in the rat: its relationship to carbon tetrachloride-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 149 {{A}} {{B}} in the rat: its relationship to carbon tetrachloride-induced cirrhosis.
# ({{A}})(.*)(induc)(.*)({{B}})
# 168 Following unilateral {{A}} induced SN lesion, a transient period of {{B}} has been reported to precede the predominant ipsilateral circling.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' ', u'ed SN lesion, a transient period of ')
# [1, 36]
# 1
# 0 52 {{A}} induced SN lesion, a transient period of {{B}}
# 1 5 {{A}}
# 2 1
# 3 5 induc
# 4 36 ed SN lesion, a transient period of
# 5 5 {{B}}
# 178 Such {{B}} may result from either degeneration-induced breakdown of the {{A}} pool, or lesion-induced increase of DA turnover in the spared neurons.
# ({{A}})(.*)(induc)(.*)({{B}})
# 179 Such {{B}} may result from either degeneration-induced breakdown of the DA pool, or lesion-induced increase of {{A}} turnover in the spared neurons.
# ({{A}})(.*)(induc)(.*)({{B}})
# 187 {{A}} cardiomyopathy-induced {{B}} and apoptosis are attenuated by gene deletion of the kinin B1 receptor.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' cardiomyopathy-', u'ed ')
# [16, 3]
# 3
# 0 34 {{A}} cardiomyopathy-induced {{B}}
# 1 5 {{A}}
# 2 16  cardiomyopathy-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 191 Clinical use of the anthracycline {{A}} (DOX) is limited by its {{B}} effects, which are attributed to the induction of apoptosis.
# ({{A}})(.*)(induc)(.*)({{B}})
# 192 Clinical use of the anthracycline doxorubicin ({{A}} is limited by its {{B}} effects, which are attributed to the induction of apoptosis.
# ({{A}})(.*)(induc)(.*)({{B}})
# 193 Clinical use of the {{A}} doxorubicin (DOX) is limited by its {{B}} effects, which are attributed to the induction of apoptosis.
# ({{A}})(.*)(induc)(.*)({{B}})
# 232 Therefore, the effects of {{A}}, a beta-adrenoceptor antagonist, on haloperidol-induced {{B}} in rats were behaviorally studied and compared with those of propranolol and biperiden, a muscarinic receptor antagonist.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u', a beta-adrenoceptor antagonist, on haloperidol-', u'ed ')
# [49, 3]
# 3
# 0 67 {{A}}, a beta-adrenoceptor antagonist, on haloperidol-induced {{B}}
# 1 5 {{A}}
# 2 49 , a beta-adrenoceptor antagonist, on haloperidol-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 234 Therefore, the effects of carteolol, a beta-adrenoceptor antagonist, on haloperidol-induced {{B}} in rats were behaviorally studied and compared with those of propranolol and {{A}}, a muscarinic receptor antagonist.
# ({{A}})(.*)(induc)(.*)({{B}})
# 235 Therefore, the effects of carteolol, a beta-adrenoceptor antagonist, on haloperidol-induced {{B}} in rats were behaviorally studied and compared with those of {{A}} and biperiden, a muscarinic receptor antagonist.
# ({{A}})(.*)(induc)(.*)({{B}})
# 240 The memory-enhancing effects of {{A}} and its analogs were tested in the passive avoidance task using the model of scopolamine-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' and its analogs were tested in the passive avoidance task using the model of scopolamine-', u'ed ')
# [90, 3]
# 3
# 0 108 {{A}} and its analogs were tested in the passive avoidance task using the model of scopolamine-induced {{B}}
# 1 5 {{A}}
# 2 90  and its analogs were tested in the passive avoidance task using the model of scopolamine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 263 Pentoxifylline (Trental) does not inhibit dipyridamole-induced {{B}}: implications for {{A}} myocardial imaging.
# ({{A}})(.*)(induc)(.*)({{B}})
# 264 {{A}} (Trental) does not inhibit dipyridamole-induced {{B}}: implications for dipyridamole-thallium-201 myocardial imaging.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (Trental) does not inhibit dipyridamole-', u'ed ')
# [41, 3]
# 3
# 0 59 {{A}} (Trental) does not inhibit dipyridamole-induced {{B}}
# 1 5 {{A}}
# 2 41  (Trental) does not inhibit dipyridamole-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 275 Moreover, enantioselectivity was demonstrated by the ability of natural {{A}} to be an order of magnitude more effective than its synthetic enantiomer in reversing scopolamine-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' to be an order of magnitude more effective than its synthetic enantiomer in reversing scopolamine-', u'ed ')
# [99, 3]
# 3
# 0 117 {{A}} to be an order of magnitude more effective than its synthetic enantiomer in reversing scopolamine-induced {{B}}
# 1 5 {{A}}
# 2 99  to be an order of magnitude more effective than its synthetic enantiomer in reversing scopolamine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 280 Whether pentoxifylline inhibits dipyridamole-induced {{B}} like other {{A}} such as theophylline and should be stopped prior to dipyridamole-thallium-201 imaging is unknown.
# ({{A}})(.*)(induc)(.*)({{B}})
# 282 Whether pentoxifylline inhibits dipyridamole-induced {{B}} like other methylxanthines such as theophylline and should be stopped prior to {{A}} imaging is unknown.
# ({{A}})(.*)(induc)(.*)({{B}})
# 283 Whether {{A}} inhibits dipyridamole-induced {{B}} like other methylxanthines such as theophylline and should be stopped prior to dipyridamole-thallium-201 imaging is unknown.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' inhibits dipyridamole-', u'ed ')
# [23, 3]
# 3
# 0 41 {{A}} inhibits dipyridamole-induced {{B}}
# 1 5 {{A}}
# 2 23  inhibits dipyridamole-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 284 Whether pentoxifylline inhibits dipyridamole-induced {{B}} like other methylxanthines such as {{A}} and should be stopped prior to dipyridamole-thallium-201 imaging is unknown.
# ({{A}})(.*)(induc)(.*)({{B}})
# 289 Heparin-induced {{B}} (HIT) is an adverse immune-mediated reaction to {{A}}, resulting in platelet count decreases of more than 50%.
# ({{A}})(.*)(induc)(.*)({{B}})
# 290 Heparin-induced thrombocytopenia ({{B}} is an adverse immune-mediated reaction to {{A}}, resulting in platelet count decreases of more than 50%.
# ({{A}})(.*)(induc)(.*)({{B}})
# 291 However, pilocarpine-induced {{B}} result in a more widespread neuronal death in both WT and D2R -/- brains in comparison to {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 292 However, pilocarpine-induced seizures result in a more widespread {{B}} in both WT and D2R -/- brains in comparison to {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 326 Detection of abnormal cardiac adrenergic neuron activity in adriamycin-induced {{B}} with {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 333 Using a rat model of adriamycin-induced {{B}}, we tested the hypothesis that abnormal cardiac adrenergic neuron activity may appear and be exacerbated dose-dependently in {{A}} cardiomyopathy.
# ({{A}})(.*)(induc)(.*)({{B}})
# 334 Using a rat model of adriamycin-induced cardiomyopathy, we tested the hypothesis that abnormal cardiac adrenergic neuron activity may appear and be exacerbated dose-dependently in {{A}} {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 350 Protective effect of a specific platelet-activating factor antagonist, {{A}}, on bupivacaine-induced {{B}} in rats.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u', on bupivacaine-', u'ed ')
# [17, 3]
# 3
# 0 35 {{A}}, on bupivacaine-induced {{B}}
# 1 5 {{A}}
# 2 17 , on bupivacaine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 351 Reduction of {{B}} during induction with target-controlled {{A}} and remifentanil.
# ({{A}})(.*)(induc)(.*)({{B}})
# 352 Reduction of {{B}} during induction with target-controlled propofol and {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 355 Early trials of cisplatin and {{A}} also suggested that the incidence and severity of cisplatin-induced nephrotoxicity, ototoxicity, and {{B}} were reduced.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' also suggested that the incidence and severity of cisplatin-', u'ed nephrotoxicity, ototoxicity, and ')
# [61, 36]
# 36
# 0 112 {{A}} also suggested that the incidence and severity of cisplatin-induced nephrotoxicity, ototoxicity, and {{B}}
# 1 5 {{A}}
# 2 61  also suggested that the incidence and severity of cisplatin-
# 3 5 induc
# 4 36 ed nephrotoxicity, ototoxicity, and
# 5 5 {{B}}
# 356 Early trials of cisplatin and {{A}} also suggested that the incidence and severity of cisplatin-induced nephrotoxicity, {{B}}, and neuropathy were reduced.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' also suggested that the incidence and severity of cisplatin-', u'ed nephrotoxicity, ')
# [61, 19]
# 19
# 0 95 {{A}} also suggested that the incidence and severity of cisplatin-induced nephrotoxicity, {{B}}
# 1 5 {{A}}
# 2 61  also suggested that the incidence and severity of cisplatin-
# 3 5 induc
# 4 19 ed nephrotoxicity,
# 5 5 {{B}}
# 357 Early trials of cisplatin and {{A}} also suggested that the incidence and severity of cisplatin-induced {{B}}, ototoxicity, and neuropathy were reduced.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' also suggested that the incidence and severity of cisplatin-', u'ed ')
# [61, 3]
# 3
# 0 79 {{A}} also suggested that the incidence and severity of cisplatin-induced {{B}}
# 1 5 {{A}}
# 2 61  also suggested that the incidence and severity of cisplatin-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 358 Early trials of {{A}} and amifostine also suggested that the incidence and severity of cisplatin-induced nephrotoxicity, ototoxicity, and {{B}} were reduced.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' and amifostine also suggested that the incidence and severity of cisplatin-', u'ed nephrotoxicity, ototoxicity, and ')
# [76, 36]
# 36
# 0 127 {{A}} and amifostine also suggested that the incidence and severity of cisplatin-induced nephrotoxicity, ototoxicity, and {{B}}
# 1 5 {{A}}
# 2 76  and amifostine also suggested that the incidence and severity of cisplatin-
# 3 5 induc
# 4 36 ed nephrotoxicity, ototoxicity, and
# 5 5 {{B}}
# 359 Early trials of {{A}} and amifostine also suggested that the incidence and severity of cisplatin-induced nephrotoxicity, {{B}}, and neuropathy were reduced.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' and amifostine also suggested that the incidence and severity of cisplatin-', u'ed nephrotoxicity, ')
# [76, 19]
# 19
# 0 110 {{A}} and amifostine also suggested that the incidence and severity of cisplatin-induced nephrotoxicity, {{B}}
# 1 5 {{A}}
# 2 76  and amifostine also suggested that the incidence and severity of cisplatin-
# 3 5 induc
# 4 19 ed nephrotoxicity,
# 5 5 {{B}}
# 360 Early trials of {{A}} and amifostine also suggested that the incidence and severity of cisplatin-induced {{B}}, ototoxicity, and neuropathy were reduced.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' and amifostine also suggested that the incidence and severity of cisplatin-', u'ed ')
# [76, 3]
# 3
# 0 94 {{A}} and amifostine also suggested that the incidence and severity of cisplatin-induced {{B}}
# 1 5 {{A}}
# 2 76  and amifostine also suggested that the incidence and severity of cisplatin-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 381 CONCLUSIONS: During induction of anaesthesia with TCI of {{A}} and remifentanil, a significant reduction in propofol infusion {{B}} was achieved without significant complications by prior administration of remifentanil at a target Ce of 4 ng ml(-1).
# ({{A}})(.*)(induc)(.*)({{B}})
# 382 CONCLUSIONS: During induction of anaesthesia with TCI of propofol and remifentanil, a significant reduction in {{A}} infusion {{B}} was achieved without significant complications by prior administration of remifentanil at a target Ce of 4 ng ml(-1).
# ({{A}})(.*)(induc)(.*)({{B}})
# 383 CONCLUSIONS: During induction of anaesthesia with TCI of propofol and {{A}}, a significant reduction in propofol infusion {{B}} was achieved without significant complications by prior administration of remifentanil at a target Ce of 4 ng ml(-1).
# ({{A}})(.*)(induc)(.*)({{B}})
# 384 CONCLUSIONS: During induction of anaesthesia with TCI of propofol and remifentanil, a significant reduction in propofol infusion {{B}} was achieved without significant complications by prior administration of {{A}} at a target Ce of 4 ng ml(-1).
# ({{A}})(.*)(induc)(.*)({{B}})
# 388 {{A}} produced a dose-dependent attenuation of isoproterenol-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' produced a dose-dependent attenuation of isoproterenol-', u'ed ')
# [56, 3]
# 3
# 0 74 {{A}} produced a dose-dependent attenuation of isoproterenol-induced {{B}}
# 1 5 {{A}}
# 2 56  produced a dose-dependent attenuation of isoproterenol-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 393 {{A}} was easy to prepare, stable for 96 h and was used to study its biodistribution in rats with isoproterenol-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' was easy to prepare, stable for 96 h and was used to study its biodistribution in rats with isoproterenol-', u'ed ')
# [107, 3]
# 3
# 0 125 {{A}} was easy to prepare, stable for 96 h and was used to study its biodistribution in rats with isoproterenol-induced {{B}}
# 1 5 {{A}}
# 2 107  was easy to prepare, stable for 96 h and was used to study its biodistribution in rats with isoproterenol-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 406 Pretreatment with the D2 agonist PHNO enhanced nicotine-induced {{B}}, whereas the D1 agonist {{A}} had no effect.
# ({{A}})(.*)(induc)(.*)({{B}})
# 425 METHODS: Three subjects with a history of {{A}} (EMB)-induced {{B}} of short-, intermediate-, and long-term visual deficits were administered a full neuro-ophthalmologic examination including visual acuity, color vision, contrast sensitivity, and fundus examination.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (EMB)-', u'ed ')
# [7, 3]
# 3
# 0 25 {{A}} (EMB)-induced {{B}}
# 1 5 {{A}}
# 2 7  (EMB)-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 426 METHODS: Three subjects with a history of {{A}} (EMB)-induced optic neuropathy of short-, intermediate-, and long-term {{B}} were administered a full neuro-ophthalmologic examination including visual acuity, color vision, contrast sensitivity, and fundus examination.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (EMB)-', u'ed optic neuropathy of short-, intermediate-, and long-term ')
# [7, 60]
# 7
# 0 82 {{A}} (EMB)-induced optic neuropathy of short-, intermediate-, and long-term {{B}}
# 1 5 {{A}}
# 2 7  (EMB)-
# 3 5 induc
# 4 60 ed optic neuropathy of short-, intermediate-, and long-term
# 5 5 {{B}}
# 427 METHODS: Three subjects with a history of ethambutol ({{A}}-induced {{B}} of short-, intermediate-, and long-term visual deficits were administered a full neuro-ophthalmologic examination including visual acuity, color vision, contrast sensitivity, and fundus examination.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u'-', u'ed ')
# [1, 3]
# 1
# 0 19 {{A}}-induced {{B}}
# 1 5 {{A}}
# 2 1 -
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 428 METHODS: Three subjects with a history of ethambutol ({{A}}-induced optic neuropathy of short-, intermediate-, and long-term {{B}} were administered a full neuro-ophthalmologic examination including visual acuity, color vision, contrast sensitivity, and fundus examination.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u'-', u'ed optic neuropathy of short-, intermediate-, and long-term ')
# [1, 60]
# 1
# 0 76 {{A}}-induced optic neuropathy of short-, intermediate-, and long-term {{B}}
# 1 5 {{A}}
# 2 1 -
# 3 5 induc
# 4 60 ed optic neuropathy of short-, intermediate-, and long-term
# 5 5 {{B}}
# 437 {{A}} induced prolonged {{B}} in a patient receiving electroconvulsive therapy.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' ', u'ed prolonged ')
# [1, 13]
# 1
# 0 29 {{A}} induced prolonged {{B}}
# 1 5 {{A}}
# 2 1
# 3 5 induc
# 4 13 ed prolonged
# 5 5 {{B}}
# 438 {{B}} associated with {{A}} administration during saline-induced abortion.
# ({{A}})(.*)(induc)(.*)({{B}})
# 439 Water intoxication associated with {{A}} administration during saline-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' administration during saline-', u'ed ')
# [30, 3]
# 3
# 0 48 {{A}} administration during saline-induced {{B}}
# 1 5 {{A}}
# 2 30  administration during saline-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 450 The protective effect of oral administration of the thiol compound {{A}} (MESNA) against urothelial toxicity induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable {{B}} under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (MESNA) against urothelial toxicity ', u'ed by ifosfamide (IF) was tested in a group of 45 patients with inoperable ')
# [37, 75]
# 37
# 0 127 {{A}} (MESNA) against urothelial toxicity induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable {{B}}
# 1 5 {{A}}
# 2 37  (MESNA) against urothelial toxicity
# 3 5 induc
# 4 75 ed by ifosfamide (IF) was tested in a group of 45 patients with inoperable
# 5 5 {{B}}
# 451 The protective effect of oral administration of the thiol compound {{A}} (MESNA) against {{B}} induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable lung cancer under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 452 The protective effect of oral administration of the thiol compound sodium 2-mercaptoethane sulphonate ({{A}} against urothelial toxicity induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable {{B}} under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' against urothelial toxicity ', u'ed by ifosfamide (IF) was tested in a group of 45 patients with inoperable ')
# [29, 75]
# 29
# 0 119 {{A}} against urothelial toxicity induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable {{B}}
# 1 5 {{A}}
# 2 29  against urothelial toxicity
# 3 5 induc
# 4 75 ed by ifosfamide (IF) was tested in a group of 45 patients with inoperable
# 5 5 {{B}}
# 453 The protective effect of oral administration of the thiol compound sodium 2-mercaptoethane sulphonate ({{A}} against {{B}} induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable lung cancer under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 454 The protective effect of oral administration of the {{A}} compound sodium 2-mercaptoethane sulphonate (MESNA) against urothelial toxicity induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable {{B}} under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' compound sodium 2-mercaptoethane sulphonate (MESNA) against urothelial toxicity ', u'ed by ifosfamide (IF) was tested in a group of 45 patients with inoperable ')
# [81, 75]
# 75
# 0 171 {{A}} compound sodium 2-mercaptoethane sulphonate (MESNA) against urothelial toxicity induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable {{B}}
# 1 5 {{A}}
# 2 81  compound sodium 2-mercaptoethane sulphonate (MESNA) against urothelial toxicity
# 3 5 induc
# 4 75 ed by ifosfamide (IF) was tested in a group of 45 patients with inoperable
# 5 5 {{B}}
# 455 The protective effect of oral administration of the {{A}} compound sodium 2-mercaptoethane sulphonate (MESNA) against {{B}} induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable lung cancer under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 456 The protective effect of oral administration of the thiol compound sodium 2-mercaptoethane sulphonate (MESNA) against urothelial toxicity induced by {{A}} (IF) was tested in a group of 45 patients with inoperable {{B}} under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 457 The protective effect of oral administration of the thiol compound sodium 2-mercaptoethane sulphonate (MESNA) against {{B}} induced by {{A}} (IF) was tested in a group of 45 patients with inoperable lung cancer under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 458 The protective effect of oral administration of the thiol compound sodium 2-mercaptoethane sulphonate (MESNA) against urothelial toxicity induced by ifosfamide ({{A}} was tested in a group of 45 patients with inoperable {{B}} under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 459 The protective effect of oral administration of the thiol compound sodium 2-mercaptoethane sulphonate (MESNA) against {{B}} induced by ifosfamide ({{A}} was tested in a group of 45 patients with inoperable lung cancer under treatment with IF (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 460 The protective effect of oral administration of the thiol compound sodium 2-mercaptoethane sulphonate (MESNA) against urothelial toxicity induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable {{B}} under treatment with {{A}} (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 461 The protective effect of oral administration of the thiol compound sodium 2-mercaptoethane sulphonate (MESNA) against {{B}} induced by ifosfamide (IF) was tested in a group of 45 patients with inoperable lung cancer under treatment with {{A}} (2250 mg/m2 on days 2-5) as part of a polychemotherapy regimen repeated in a 4-week cycle.
# ({{A}})(.*)(induc)(.*)({{B}})
# 490 Effect of {{A}} treatment on collagenase-induced {{B}} in rats.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' treatment on collagenase-', u'ed ')
# [26, 3]
# 3
# 0 44 {{A}} treatment on collagenase-induced {{B}}
# 1 5 {{A}}
# 2 26  treatment on collagenase-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 510 {{B}} induced by antithyroid drugs: four cases including one with cross-reactivity between carbimazole and {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 511 {{B}} induced by antithyroid drugs: four cases including one with cross-reactivity between {{A}} and benzylthiouracil.
# ({{A}})(.*)(induc)(.*)({{B}})
# 517 Remission induction of {{B}} with high-dose intravenous {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 531 Therefore, the present study was carried out to investigate the effect of chronic curcumin administration on {{A}}- and carbamazepine-induced {{B}} and oxidative stress in rats.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u'- and carbamazepine-', u'ed ')
# [20, 3]
# 3
# 0 38 {{A}}- and carbamazepine-induced {{B}}
# 1 5 {{A}}
# 2 20 - and carbamazepine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 532 Therefore, the present study was carried out to investigate the effect of chronic {{A}} administration on phenobarbitone- and carbamazepine-induced {{B}} and oxidative stress in rats.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' administration on phenobarbitone- and carbamazepine-', u'ed ')
# [53, 3]
# 3
# 0 71 {{A}} administration on phenobarbitone- and carbamazepine-induced {{B}}
# 1 5 {{A}}
# 2 53  administration on phenobarbitone- and carbamazepine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 542 Their ester prodrugs 6 and 8 were orally active in three models of {{B}}: reversal of formalin-induced paw licking, {{A}} thermal hyperalgesia, and capsaicin-induced mechanical hyperalgesia.
# ({{A}})(.*)(induc)(.*)({{B}})
# 543 Their ester prodrugs 6 and 8 were orally active in three models of pain: reversal of formalin-induced paw licking, {{A}} {{B}}, and capsaicin-induced mechanical hyperalgesia.
# ({{A}})(.*)(induc)(.*)({{B}})
# 544 Their ester prodrugs 6 and 8 were orally active in three models of pain: reversal of formalin-induced paw licking, {{A}} thermal hyperalgesia, and capsaicin-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' thermal hyperalgesia, and capsaicin-', u'ed ')
# [37, 3]
# 3
# 0 55 {{A}} thermal hyperalgesia, and capsaicin-induced {{B}}
# 1 5 {{A}}
# 2 37  thermal hyperalgesia, and capsaicin-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 545 Their ester prodrugs 6 and 8 were orally active in three models of {{B}}: reversal of {{A}} paw licking, carrageenan-induced thermal hyperalgesia, and capsaicin-induced mechanical hyperalgesia.
# ({{A}})(.*)(induc)(.*)({{B}})
# 546 Their ester prodrugs 6 and 8 were orally active in three models of pain: reversal of {{A}} paw licking, carrageenan-induced {{B}}, and capsaicin-induced mechanical hyperalgesia.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' paw licking, carrageenan-', u'ed ')
# [26, 3]
# 3
# 0 44 {{A}} paw licking, carrageenan-induced {{B}}
# 1 5 {{A}}
# 2 26  paw licking, carrageenan-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 547 Their ester prodrugs 6 and 8 were orally active in three models of pain: reversal of {{A}} paw licking, carrageenan-induced thermal hyperalgesia, and capsaicin-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' paw licking, carrageenan-induced thermal hyperalgesia, and capsaicin-', u'ed ')
# [70, 3]
# 3
# 0 88 {{A}} paw licking, carrageenan-induced thermal hyperalgesia, and capsaicin-induced {{B}}
# 1 5 {{A}}
# 2 70  paw licking, carrageenan-induced thermal hyperalgesia, and capsaicin-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 548 Their ester prodrugs 6 and 8 were orally active in three models of {{B}}: reversal of formalin-induced paw licking, carrageenan-induced thermal hyperalgesia, and {{A}} mechanical hyperalgesia.
# ({{A}})(.*)(induc)(.*)({{B}})
# 549 Their ester prodrugs 6 and 8 were orally active in three models of pain: reversal of formalin-induced paw licking, carrageenan-induced {{B}}, and {{A}} mechanical hyperalgesia.
# ({{A}})(.*)(induc)(.*)({{B}})
# 550 Their ester prodrugs 6 and 8 were orally active in three models of pain: reversal of formalin-induced paw licking, carrageenan-induced thermal hyperalgesia, and {{A}} {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 553 Using macaque monkeys with different types of MPTP-induced parkinsonism, the current study evaluated the degree to which rate of symptom progression, symptom severity, and response to and duration of {{A}} therapy may be involved in the development of {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 554 Using macaque monkeys with different types of MPTP-induced {{B}}, the current study evaluated the degree to which rate of symptom progression, symptom severity, and response to and duration of {{A}} therapy may be involved in the development of LIDs.
# ({{A}})(.*)(induc)(.*)({{B}})
# 565 Effects of {{A}} channel blockers on bupivacaine-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' channel blockers on bupivacaine-', u'ed ')
# [33, 3]
# 3
# 0 51 {{A}} channel blockers on bupivacaine-induced {{B}}
# 1 5 {{A}}
# 2 33  channel blockers on bupivacaine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 583 {{A}} (AZT)-induced {{B}} in mice can be reversed by the administration of IGF-IL-3 (fusion protein of insulin-like growth factor II (IGF II) and interleukin 3).
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (AZT)-', u'ed ')
# [7, 3]
# 3
# 0 25 {{A}} (AZT)-induced {{B}}
# 1 5 {{A}}
# 2 7  (AZT)-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 584 Azidothymidine ({{A}}-induced {{B}} in mice can be reversed by the administration of IGF-IL-3 (fusion protein of insulin-like growth factor II (IGF II) and interleukin 3).
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u'-', u'ed ')
# [1, 3]
# 1
# 0 19 {{A}}-induced {{B}}
# 1 5 {{A}}
# 2 1 -
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 608 {{A}} in doses of 7.5-15 microg/0.5 microl diminished the haloperidol-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' in doses of 7.5-15 microg/0.5 microl diminished the haloperidol-', u'ed ')
# [65, 3]
# 3
# 0 83 {{A}} in doses of 7.5-15 microg/0.5 microl diminished the haloperidol-induced {{B}}
# 1 5 {{A}}
# 2 65  in doses of 7.5-15 microg/0.5 microl diminished the haloperidol-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 613 Compared with sham-operated controls, lesions significantly (p < 0.25) blunted the early (<60 min) free-field locomotor hypoactivity caused by {{A}} (0.5 mg kg(-1), i.m.), enhanced the later (60-120 min) nicotine-induced {{B}}, and raised spontaneous nocturnal activity.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' (0.5 mg kg(-1), i.m.), enhanced the later (60-120 min) nicotine-', u'ed ')
# [65, 3]
# 3
# 0 83 {{A}} (0.5 mg kg(-1), i.m.), enhanced the later (60-120 min) nicotine-induced {{B}}
# 1 5 {{A}}
# 2 65  (0.5 mg kg(-1), i.m.), enhanced the later (60-120 min) nicotine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 614 Compared with sham-operated controls, lesions significantly (p < 0.25) blunted the early (<60 min) free-field {{B}} caused by {{A}} (0.5 mg kg(-1), i.m.), enhanced the later (60-120 min) nicotine-induced hyperactivity, and raised spontaneous nocturnal activity.
# ({{A}})(.*)(induc)(.*)({{B}})
# 635 In behavioral studies, pretreatment of Swiss Webster mice with UMB24 or (+/-)-{{A}} significantly attenuated cocaine-induced {{B}} and locomotor activity, but not lethality.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' significantly attenuated cocaine-', u'ed ')
# [34, 3]
# 3
# 0 52 {{A}} significantly attenuated cocaine-induced {{B}}
# 1 5 {{A}}
# 2 34  significantly attenuated cocaine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 637 In behavioral studies, pretreatment of Swiss Webster mice with {{A}} or (+/-)-SM 21 significantly attenuated cocaine-induced {{B}} and locomotor activity, but not lethality.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' or (+/-)-SM 21 significantly attenuated cocaine-', u'ed ')
# [49, 3]
# 3
# 0 67 {{A}} or (+/-)-SM 21 significantly attenuated cocaine-induced {{B}}
# 1 5 {{A}}
# 2 49  or (+/-)-SM 21 significantly attenuated cocaine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 660 What is less well known is a phenomenon whereby {{A}} may induce a {{B}}, which persists or may progress after stopping the drug.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' may ', u'e a ')
# [5, 4]
# 4
# 0 24 {{A}} may induce a {{B}}
# 1 5 {{A}}
# 2 5  may
# 3 5 induc
# 4 4 e a
# 5 5 {{B}}
# 668 CONCLUSIONS: These results suggest an important role for quantitative and qualitative mtDNA alterations through the reduction of mtDNA-encoded respiratory chain function and induction of superoxide in {{A}} {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 669 CONCLUSIONS: These results suggest an important role for quantitative and qualitative mtDNA alterations through the reduction of mtDNA-encoded respiratory chain function and induction of {{A}} in doxorubicin-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' in doxorubicin-', u'ed ')
# [16, 3]
# 3
# 0 34 {{A}} in doxorubicin-induced {{B}}
# 1 5 {{A}}
# 2 16  in doxorubicin-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 675 The {{B}} induced by {{A}} antagonists has been tested and the possible dopamine subtypes involved in catalepsy was determined.
# ({{A}})(.*)(induc)(.*)({{B}})
# 676 The catalepsy induced by {{A}} antagonists has been tested and the possible dopamine subtypes involved in {{B}} was determined.
# ...
# ({{A}})(.*)(induc)(.*)({{B}})
# 8178 Mature male and female mice from six inbred stains were tested for susceptibility to behavioral {{B}} induced by a single injection of {{A}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8185 Down-regulation of norepinephrine transporter function induced by chronic administration of {{A}} linking to the alteration of sensitivity of local-anesthetics-induced {{B}} and the counteraction by co-administration with local anesthetics.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' linking to the alteration of sensitivity of local-anesthetics-', u'ed ')
# [63, 3]
# 3
# 0 81 {{A}} linking to the alteration of sensitivity of local-anesthetics-induced {{B}}
# 1 5 {{A}}
# 2 63  linking to the alteration of sensitivity of local-anesthetics-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8186 Down-regulation of {{A}} transporter function induced by chronic administration of desipramine linking to the alteration of sensitivity of local-anesthetics-induced {{B}} and the counteraction by co-administration with local anesthetics.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' transporter function induced by chronic administration of desipramine linking to the alteration of sensitivity of local-anesthetics-', u'ed ')
# [133, 3]
# 3
# 0 151 {{A}} transporter function induced by chronic administration of desipramine linking to the alteration of sensitivity of local-anesthetics-induced {{B}}
# 1 5 {{A}}
# 2 133  transporter function induced by chronic administration of desipramine linking to the alteration of sensitivity of local-anesthetics-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8196 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of {{B}} including mouse and rat models of haloperidol-induced catalepsy, mouse model of reserpine-induced akinesia, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and {{A}} non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8197 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of haloperidol-induced catalepsy, mouse model of reserpine-induced {{B}}, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and {{A}} non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8198 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of haloperidol-induced {{B}}, mouse model of reserpine-induced akinesia, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and {{A}} non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8199 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of {{B}} including mouse and rat models of {{A}} catalepsy, mouse model of reserpine-induced akinesia, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8200 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of {{A}} catalepsy, mouse model of reserpine-induced {{B}}, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' catalepsy, mouse model of reserpine-', u'ed ')
# [37, 3]
# 3
# 0 55 {{A}} catalepsy, mouse model of reserpine-induced {{B}}
# 1 5 {{A}}
# 2 37  catalepsy, mouse model of reserpine-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8201 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of {{A}} {{B}}, mouse model of reserpine-induced akinesia, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8202 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of {{B}} including mouse and rat models of haloperidol-induced catalepsy, mouse model of {{A}} akinesia, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8203 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of haloperidol-induced catalepsy, mouse model of {{A}} {{B}}, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8204 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of haloperidol-induced {{B}}, mouse model of {{A}} akinesia, rat 6-hydroxydopamine (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8205 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of {{B}} including mouse and rat models of haloperidol-induced catalepsy, mouse model of reserpine-induced akinesia, rat {{A}} (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8206 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of haloperidol-induced catalepsy, mouse model of reserpine-induced {{B}}, rat {{A}} (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8207 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of haloperidol-induced {{B}}, mouse model of reserpine-induced akinesia, rat {{A}} (6-OHDA) lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8208 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of {{B}} including mouse and rat models of haloperidol-induced catalepsy, mouse model of reserpine-induced akinesia, rat 6-hydroxydopamine ({{A}} lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8209 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of haloperidol-induced catalepsy, mouse model of reserpine-induced {{B}}, rat 6-hydroxydopamine ({{A}} lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8210 Compound 1 is a potent A(2A)/A(1) receptor antagonist in vitro (A(2A) K(i) = 4.1 nM; A(1) K(i) = 17.0 nM) that has excellent activity, after oral administration, across a number of animal models of Parkinson's disease including mouse and rat models of haloperidol-induced {{B}}, mouse model of reserpine-induced akinesia, rat 6-hydroxydopamine ({{A}} lesion model of drug-induced rotation, and MPTP-treated non-human primate model.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8211 Our findings, showing no interaction between {{A}} treatment and attentional modulation suggest that capsaicin-induced secondary hyperalgesia and attention might affect mechanical {{B}} through independent mechanisms.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' treatment and attentional modulation suggest that capsaicin-', u'ed secondary hyperalgesia and attention might affect mechanical ')
# [61, 64]
# 61
# 0 140 {{A}} treatment and attentional modulation suggest that capsaicin-induced secondary hyperalgesia and attention might affect mechanical {{B}}
# 1 5 {{A}}
# 2 61  treatment and attentional modulation suggest that capsaicin-
# 3 5 induc
# 4 64 ed secondary hyperalgesia and attention might affect mechanical
# 5 5 {{B}}
# 8212 Our findings, showing no interaction between {{A}} treatment and attentional modulation suggest that capsaicin-induced secondary {{B}} and attention might affect mechanical pain through independent mechanisms.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' treatment and attentional modulation suggest that capsaicin-', u'ed secondary ')
# [61, 13]
# 13
# 0 89 {{A}} treatment and attentional modulation suggest that capsaicin-induced secondary {{B}}
# 1 5 {{A}}
# 2 61  treatment and attentional modulation suggest that capsaicin-
# 3 5 induc
# 4 13 ed secondary
# 5 5 {{B}}
# 8216 {{A}} induced {{B}}: case report and review of the literature.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' ', u'ed ')
# [1, 3]
# 1
# 0 19 {{A}} induced {{B}}
# 1 5 {{A}}
# 2 1
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8218 The typical {{A}} symptoms of restlessness, constant pacing, purposeless movements of the feet and legs, and marked {{B}} were indistinguishable from those of neuroleptic-induced akathisia.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8219 The typical {{A}} symptoms of {{B}}, constant pacing, purposeless movements of the feet and legs, and marked anxiety were indistinguishable from those of neuroleptic-induced akathisia.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8220 The typical {{A}} symptoms of restlessness, constant pacing, purposeless movements of the feet and legs, and marked anxiety were indistinguishable from those of neuroleptic-induced {{B}}.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' symptoms of restlessness, constant pacing, purposeless movements of the feet and legs, and marked anxiety were indistinguishable from those of neuroleptic-', u'ed ')
# [156, 3]
# 3
# 0 174 {{A}} symptoms of restlessness, constant pacing, purposeless movements of the feet and legs, and marked anxiety were indistinguishable from those of neuroleptic-induced {{B}}
# 1 5 {{A}}
# 2 156  symptoms of restlessness, constant pacing, purposeless movements of the feet and legs, and marked anxiety were indistinguishable from those of neuroleptic-
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8225 Bradykinin receptors antagonists and nitric oxide synthase inhibitors in {{A}} and streptozotocin induced hyperalgesia in chemotherapy and {{B}} rat model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' and streptozotocin ', u'ed hyperalgesia in chemotherapy and ')
# [20, 36]
# 20
# 0 71 {{A}} and streptozotocin induced hyperalgesia in chemotherapy and {{B}}
# 1 5 {{A}}
# 2 20  and streptozotocin
# 3 5 induc
# 4 36 ed hyperalgesia in chemotherapy and
# 5 5 {{B}}
# 8226 Bradykinin receptors antagonists and nitric oxide synthase inhibitors in {{A}} and streptozotocin induced {{B}} in chemotherapy and diabetic neuropathy rat model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' and streptozotocin ', u'ed ')
# [20, 3]
# 3
# 0 38 {{A}} and streptozotocin induced {{B}}
# 1 5 {{A}}
# 2 20  and streptozotocin
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8227 Bradykinin receptors antagonists and nitric oxide synthase inhibitors in vincristine and {{A}} induced hyperalgesia in chemotherapy and {{B}} rat model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' ', u'ed hyperalgesia in chemotherapy and ')
# [1, 36]
# 1
# 0 52 {{A}} induced hyperalgesia in chemotherapy and {{B}}
# 1 5 {{A}}
# 2 1
# 3 5 induc
# 4 36 ed hyperalgesia in chemotherapy and
# 5 5 {{B}}
# 8228 Bradykinin receptors antagonists and nitric oxide synthase inhibitors in vincristine and {{A}} induced {{B}} in chemotherapy and diabetic neuropathy rat model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' ', u'ed ')
# [1, 3]
# 1
# 0 19 {{A}} induced {{B}}
# 1 5 {{A}}
# 2 1
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8229 Bradykinin receptors antagonists and {{A}} synthase inhibitors in vincristine and streptozotocin induced hyperalgesia in chemotherapy and {{B}} rat model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' synthase inhibitors in vincristine and streptozotocin ', u'ed hyperalgesia in chemotherapy and ')
# [55, 36]
# 36
# 0 106 {{A}} synthase inhibitors in vincristine and streptozotocin induced hyperalgesia in chemotherapy and {{B}}
# 1 5 {{A}}
# 2 55  synthase inhibitors in vincristine and streptozotocin
# 3 5 induc
# 4 36 ed hyperalgesia in chemotherapy and
# 5 5 {{B}}
# 8230 Bradykinin receptors antagonists and {{A}} synthase inhibitors in vincristine and streptozotocin induced {{B}} in chemotherapy and diabetic neuropathy rat model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' synthase inhibitors in vincristine and streptozotocin ', u'ed ')
# [55, 3]
# 3
# 0 73 {{A}} synthase inhibitors in vincristine and streptozotocin induced {{B}}
# 1 5 {{A}}
# 2 55  synthase inhibitors in vincristine and streptozotocin
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8231 {{A}} receptors antagonists and nitric oxide synthase inhibitors in vincristine and streptozotocin induced hyperalgesia in chemotherapy and {{B}} rat model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' receptors antagonists and nitric oxide synthase inhibitors in vincristine and streptozotocin ', u'ed hyperalgesia in chemotherapy and ')
# [94, 36]
# 36
# 0 145 {{A}} receptors antagonists and nitric oxide synthase inhibitors in vincristine and streptozotocin induced hyperalgesia in chemotherapy and {{B}}
# 1 5 {{A}}
# 2 94  receptors antagonists and nitric oxide synthase inhibitors in vincristine and streptozotocin
# 3 5 induc
# 4 36 ed hyperalgesia in chemotherapy and
# 5 5 {{B}}
# 8232 {{A}} receptors antagonists and nitric oxide synthase inhibitors in vincristine and streptozotocin induced {{B}} in chemotherapy and diabetic neuropathy rat model.
# ({{A}})(.*)(induc)(.*)({{B}})
# induc
# (u' receptors antagonists and nitric oxide synthase inhibitors in vincristine and streptozotocin ', u'ed ')
# [94, 3]
# 3
# 0 112 {{A}} receptors antagonists and nitric oxide synthase inhibitors in vincristine and streptozotocin induced {{B}}
# 1 5 {{A}}
# 2 94  receptors antagonists and nitric oxide synthase inhibitors in vincristine and streptozotocin
# 3 5 induc
# 4 3 ed
# 5 5 {{B}}
# 8249 In ICH induction using 0.014-unit collagenase, {{A}} enhanced the {{B}} volume 3.4-fold over that seen in control ICH animals and the bleeding 7.6-fold.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8250 In ICH induction using 0.014-unit collagenase, {{A}} enhanced the hematoma volume 3.4-fold over that seen in control ICH animals and the {{B}} 7.6-fold.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8251 In {{B}} induction using 0.014-unit collagenase, {{A}} enhanced the hematoma volume 3.4-fold over that seen in control ICH animals and the bleeding 7.6-fold.
# ({{A}})(.*)(induc)(.*)({{B}})
# 8252 In ICH induction using 0.014-unit collagenase, {{A}} enhanced the hematoma volume 3.4-fold over that seen in control {{B}} animals and the bleeding 7.6-fold.
# ({{A}})(.*)(induc)(.*)({{B}})
